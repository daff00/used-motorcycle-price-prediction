# %% [markdown]
# # Web Scraping Website Momotor.id
# ## Web scraping motor bekas
#
# IS 794 AL - Deep Learning (Lab)
# Kelompok B: <br>
# - Daffa Kaisha Pratama Chandra (00000055770)
# - Justine Donovan (00000063202)
# - Marsella Patricia (00000063226)
# - Reina Ratu Balqis (00000065099)
# ---
#
# Import Library

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
baseurl = "https://www.momotor.id" #base url

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36'}

# %% [markdown]
# ---
# Motor Yamaha Bekas

# %%
url_yamaha = []
data_yamaha =[]

for x in range(1,43): # page 1 sampai n
    offset = (x - 1) * 12  # Calculate the offset
    k = requests.get(f'https://momotor.id/motor-bekas?brands=yamaha&offset={offset}').text
    soup = BeautifulSoup(k, 'html.parser')
    productlist = soup.find_all("div", {"class": "MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-4 css-g8wver"}) # cari card tempat produknya

    for product in productlist: # cari link produk
        link = product.find("a", href=True)
        if link:
            url_yamaha.append(baseurl + link['href'])

# %%
print(len(url_yamaha))
# Out:
# 493

# %%
v = len(url_yamaha) != len(set(url_yamaha))
v
# Out:
# False

# %%
print(url_yamaha[-1])
# Out:
# https://www.momotor.id/motor-bekas/yamaha/yamaha-aerox-155-vva-s?pid=245211

# %%
counter = 0

for link in url_yamaha: #input data
    f = requests.get(link, headers=headers).text
    hun = BeautifulSoup(f, 'html.parser')
    try:
        price = hun.find("p", {"class": "product-price"}).text.replace('\n', "")
    except:
        price = None
    try:
        location = hun.find("h2", {"class" : "product-location"}).text.replace('\n', "")
    except:
        location = None
    try:
        description = hun.find("div", {"class": "description-text"}).text.replace('\n', "")
    except:
        description = None
    try:
        name = hun.find("h1", {"class": "product-name"}).text.replace('\n', "")
    except:
        name = None

    kapasitas_mesin = None
    tahun = None
    transmisi = None
    kilometer = None

    specification_list = hun.find("ul", class_="product-specification-list")

    if specification_list:
        specification_items = specification_list.find_all("li", class_="product-specification-item")

        for item in specification_items:
            label = item.find("p", class_="product-spec-label").text
            value = item.find("p", class_="product-spec-item").text

            if "Kapasitas Mesin" in label:
                kapasitas_mesin = value
            elif "Tahun" in label:
                tahun = value
            elif "Transmisi" in label:
                transmisi = value
            elif "Kilometer" in label:
                kilometer = value

    motor_yamaha = {
        "nama_motor": name,
        "lokasi" : location,
        "harga": price,
        "deskripsi": description,
        "kapasitas_mesin": kapasitas_mesin,
        "tahun": tahun,
        "transmisi": transmisi,
        "kilometer": kilometer
    }

    data_yamaha.append(motor_yamaha)
    counter += 1
    print("completed", counter)
# Out:
# completed 1
# completed 2
# completed 3
# completed 4
# completed 5
# completed 6
# completed 7
# completed 8
# completed 9
# completed 10
# completed 11
# completed 12
# completed 13
# completed 14
# completed 15
# completed 16
# completed 17
# completed 18
# completed 19
# completed 20
# completed 21
# completed 22
# completed 23
# completed 24
# completed 25
# completed 26
# completed 27
# completed 28
# completed 29
# completed 30
# completed 31
# completed 32
# completed 33
# completed 34
# completed 35
# completed 36
# completed 37
# completed 38
# completed 39
# completed 40
# completed 41
# completed 42
# completed 43
# completed 44
# completed 45
# completed 46
# completed 47
# completed 48
# completed 49
# ..                                                 ...             ...   ...
# 488  Motor mulus dan bagus untuk surat-surat lengka...          125 CC  2015
# 489  Motor mulus dan bagus untuk surat-surat lengka...          110 CC  2017
# 490                                               None            None  None
# 491  Motor mulus dan bagus untuk surat-surat lengka...          125 CC  2018
# 492  Motor mulus dan bagus untuk surat-surat lengka...          155 CC  2018
#
#     transmisi        kilometer
# 0        None             None
# 1        None             None
# 2        None             None
# 3        None             None
# 4        None             None
# ..        ...              ...
# 488  Otomatis  10000 - 20000KM
# 489  Otomatis        >30000 KM
# 490      None             None
# 491  Otomatis  10000 - 20000KM
# 492  Otomatis  10000 - 20000KM
#
# [493 rows x 8 columns]

# %%
# Penyesuaian
df_yamaha['url'] = url_yamaha
df_yamaha['merk'] = 'Yamaha'
df_yamaha.shape
# Out:
# (493, 10)

# %% [markdown]
# ---
# Motor Honda Bekas

# %%
url_honda = []
data_honda =[]

for x in range(1,82): # page 1 sampai n
    offset = (x - 1) * 12  # Calculate the offset
    k = requests.get(f'https://momotor.id/motor-bekas?brands=honda&offset={offset}').text
    soup = BeautifulSoup(k, 'html.parser')
    productlist = soup.find_all("div", {"class": "MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-4 css-g8wver"}) # cari card tempat produknya

    for product in productlist: # cari link produk
        link = product.find("a", href=True)
        if link:
            url_honda.append(baseurl + link['href'])

# %%
print(len(url_honda))
# Out:
# 966

# %%
print(url_honda[-1])
# Out:
# https://www.momotor.id/motor-bekas/honda/honda-vario-125-esp-cbs?pid=245206

# %%
counter = 0

for link in url_honda: #input data
    f = requests.get(link, headers=headers).text
    hun = BeautifulSoup(f, 'html.parser')

    try:
        price = hun.find("p", {"class": "product-price"}).text.replace('\n', "")
    except:
        price = None
        
    try:
        location = hun.find("h2", {"class" : "product-location"}).text.replace('\n', "")
    except:
        location = None

    try:
        description = hun.find("div", {"class": "description-text"}).text.replace('\n', "")
    except:
        description = None

    try:
        name = hun.find("h1", {"class": "product-name"}).text.replace('\n', "")
    except:
        name = None

    kapasitas_mesin = None
    tahun = None
    transmisi = None
    kilometer = None

    specification_list = hun.find("ul", class_="product-specification-list")

    if specification_list:
        specification_items = specification_list.find_all("li", class_="product-specification-item")

        for item in specification_items:
            label = item.find("p", class_="product-spec-label").text
            value = item.find("p", class_="product-spec-item").text

            if "Kapasitas Mesin" in label:
                kapasitas_mesin = value
            elif "Tahun" in label:
                tahun = value
            elif "Transmisi" in label:
                transmisi = value
            elif "Kilometer" in label:
                kilometer = value

    motor_honda = {
        "nama_motor": name,
        "lokasi" : location,
        "harga": price,
        "deskripsi": description,
        "kapasitas_mesin": kapasitas_mesin,
        "tahun": tahun,
        "transmisi": transmisi,
        "kilometer": kilometer
    }

    data_honda.append(motor_honda)
    counter += 1
    print("completed", counter)
# Out:
# completed 1
# completed 2
# completed 3
# completed 4
# completed 5
# completed 6
# completed 7
# completed 8
# completed 9
# completed 10
# completed 11
# completed 12
# completed 13
# completed 14
# completed 15
# completed 16
# completed 17
# completed 18
# completed 19
# completed 20
# completed 21
# completed 22
# 2  DEALER MUTIARA MOTORJl. Saluran irigasi gempol...          110 CC  2021
# 3  DEALER MUTIARA MOTORJl. Saluran irigasi gempol...          110 CC  2021
# 4  DEALER MUTIARA MOTORJl. Saluran irigasi gempol...          110 CC  2022
# 5                                               None            None  None
# 6                                               None            None  None
# 7                                               None            None  None
# 8    Ss lengkap  , plat pajak hidup , nego di tempat          150 CC  2019
# 9                      Ss lengkap , plat pajak hidup          125 CC  2018
#
#   transmisi        kilometer
# 0  Otomatis  10000 - 20000KM
# 1  Otomatis  10000 - 20000KM
# 2  Otomatis   5000 - 10000KM
# 3  Otomatis  10000 - 20000KM
# 4  Otomatis   1000 - 5000 KM
# 5      None             None
# 6      None             None
# 7      None             None
# 8    Manual        >30000 KM
# 9    Manual        >30000 KM

# %%
# Penyesuaian
df_honda['url'] = url_honda
df_honda['merk'] = 'Honda'
df_honda.shape
# Out:
# (966, 10)

# %% [markdown]
# ---
# Motor Kawasaki Bekas

# %%
url_kawasaki = []
data_kawasaki =[]


for x in range(1,9): # page 1 sampai n
    offset = (x - 1) * 12  # Calculate the offset
    k = requests.get(f'https://momotor.id/motor-bekas?brands=kawasaki&offset={offset}').text
    soup = BeautifulSoup(k, 'html.parser')
    productlist = soup.find_all("div", {"class": "MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-4 css-g8wver"})

    for product in productlist: # cari link produk
        link = product.find("a", href=True)
        if link:
            url_kawasaki.append(baseurl + link['href'])

# %%
print(len(url_kawasaki))
# Out:
# 96

# %%
v = len(url_kawasaki) != len(set(url_kawasaki))
v
# Out:
# False

# %%
print(url_kawasaki[-1])
# Out:
# https://www.momotor.id/motor-bekas/kawasaki/kawasaki-w-175-cafe?pid=245853

# %%
counter = 0

for link in url_kawasaki: #input data
    f = requests.get(link, headers=headers).text
    hun = BeautifulSoup(f, 'html.parser')

    try:
        price = hun.find("p", {"class": "product-price"}).text.replace('\n', "")
    except:
        price = None
        
    try:
        location = hun.find("h2", {"class" : "product-location"}).text.replace('\n', "")
    except:
        location = None

    try:
        description = hun.find("div", {"class": "description-text"}).text.replace('\n', "")
    except:
        description = None

    try:
        name = hun.find("h1", {"class": "product-name"}).text.replace('\n', "")
    except:
        name = None

    kapasitas_mesin = None
    tahun = None
    transmisi = None
    kilometer = None

    specification_list = hun.find("ul", class_="product-specification-list")

    if specification_list:
        specification_items = specification_list.find_all("li", class_="product-specification-item")

        for item in specification_items:
            label = item.find("p", class_="product-spec-label").text
            value = item.find("p", class_="product-spec-item").text

            if "Kapasitas Mesin" in label:
                kapasitas_mesin = value
            elif "Tahun" in label:
                tahun = value
            elif "Transmisi" in label:
                transmisi = value
            elif "Kilometer" in label:
                kilometer = value

    motor_kawasaki = {
        "nama_motor": name,
        "lokasi" : location,
        "harga": price,
        "deskripsi": description,
        "kapasitas_mesin": kapasitas_mesin,
        "tahun": tahun,
        "transmisi": transmisi,
        "kilometer": kilometer
    }

    data_kawasaki.append(motor_kawasaki)
    counter = counter + 1
    print("completed", counter)
# Out:
# completed 1
# completed 2
# completed 3
# completed 4
# completed 5
# completed 6
# completed 7
# completed 8
# completed 9
# completed 10
# completed 11
# completed 12
# completed 13
# completed 14
# completed 15
# completed 16
# completed 17
# completed 18
# completed 19
# completed 20
# completed 21
# completed 22
# completed 23
# completed 24
# completed 25
# completed 26
# completed 27
# completed 28
# completed 29
# completed 30
# completed 31
# completed 32
# completed 33
# completed 34
# completed 35
# completed 36
# completed 37
# completed 38
# completed 39
# completed 40
# completed 41
# completed 42
# completed 43
# completed 44
# completed 45
# completed 46
# completed 47
# completed 48
# completed 49
# completed 50
# completed 51
# completed 52
# completed 53
# completed 54
# completed 55
# completed 56
# completed 57
# completed 58
# completed 59
# completed 60
# completed 61
# completed 62
# completed 63
# completed 64
# completed 65
# completed 66
# completed 67
# completed 68
# completed 69
# completed 70
# completed 71
# completed 72
# completed 73
# completed 74
# completed 75
# completed 76
# completed 77
# completed 78
# completed 79
# completed 80
# completed 81
# completed 82
# completed 83
# completed 84
# completed 85
# completed 86
# completed 87
# completed 88
# completed 89
# completed 90
# completed 91
# completed 92
# completed 93
# completed 94
# completed 95
# completed 96

# %%
# Convert ke data frame
df_kawasaki = pd.DataFrame(data_kawasaki)
df_kawasaki
# Out:
#                          nama_motor              lokasi         harga  \
# 0                              None                None          None
# 1                              None                None          None
# 2                  Kawasaki Klx 150          Kota Medan  Rp24,500,000
# 3                Kawasaki Ninja 250      Kab. Tangerang  Rp37,000,000
# 4                              None                None          None
# ..                              ...                 ...           ...
# 91        Kawasaki Ninja 250 Abs Se  Kota Jakarta Barat  Rp38,500,000
# 92  Kawasaki Hino Sg 175 Cafe Racer  Kota Jakarta Barat  Rp24,900,000
# 93              Kawasaki W 175 Cafe  Kota Jakarta Barat  Rp23,900,000
# 94             Kawasaki D Tracker X      Kota Tangerang  Rp31,100,000
# 95                             None                None          None
#
#                                             deskripsi kapasitas_mesin tahun  \
# 0                                                None            None  None
# 1                                                None            None  None
# 2   Kawasaki KLX 150 GTahun 2017Surat kendaraan le...          150 CC  2017
# 3   ❗️Ready Stock ❗️Dijual Kawasaki ninja 250 tahu...          250 CC  2015
# 4                                                None            None  None
# ..                                                ...             ...   ...
# 91  Motor mulus dan bagus untuk surat-surat lengka...          250 CC  2016
# 92  Motor mulus dan bagus untuk surat-surat lengka...   DSE4202201 CC  2020
# 93  Motor mulus dan bagus untuk surat-surat lengka...          175 CC  2020
# 94  Motor mulus dan bagus untuk surat-surat lengka...          150 CC  2019
# 95                                               None            None  None
#
#    transmisi        kilometer
# 0       None             None
# 1       None             None
# 2     Manual        >30000 KM
# 3     Manual  10000 - 20000KM
# 4       None             None
# ..       ...              ...
# 91    Manual  10000 - 20000KM
# 92    Manual  10000 - 20000KM
# 93    Manual  10000 - 20000KM
# 94    Manual   5000 - 10000KM
# 95      None             None
#
# [96 rows x 8 columns]

# %%
# Penyesuaian
df_kawasaki['url'] = url_kawasaki
df_kawasaki['merk'] = 'Kawasaki'
df_kawasaki.shape
# Out:
# (96, 10)

# %% [markdown]
# ---
# Motor Suzuki Bekas

# %%
url_suzuki = []
data_suzuki = []

for x in range(1, 3):
    offset = (x - 1) * 12  # Calculate the offset
    k = requests.get(f'https://momotor.id/motor-bekas?brands=suzuki&offset={offset}').text
    soup = BeautifulSoup(k, 'html.parser')
    productlist = soup.find_all("div", {"class": "MuiGrid-root MuiGrid-item MuiGrid-grid-xs-6 MuiGrid-grid-sm-4 css-g8wver"})

    for product in productlist:
        link = product.find("a", href=True)
        if link:
            url_suzuki.append(baseurl + link['href'])

# %%
print(len(url_suzuki))
# Out:
# 23

# %%
print(url_suzuki[-1])
# Out:
# https://www.momotor.id/motor-bekas/suzuki/suzuki-satria-fu-150-mfx?pid=245690

# %%
counter = 0
for link in url_suzuki: #input data
    f = requests.get(link, headers=headers).text
    hun = BeautifulSoup(f, 'html.parser')

    try:
        price = hun.find("p", {"class": "product-price"}).text.replace('\n', "")
    except:
        price = None
        
    try:
        location = hun.find("h2", {"class" : "product-location"}).text.replace('\n', "")
    except:
        location = None

    try:
        description = hun.find("div", {"class": "description-text"}).text.replace('\n', "")
    except:
        description = None

    try:
        name = hun.find("h1", {"class": "product-name"}).text.replace('\n', "")
    except:
        name = None

    kapasitas_mesin = None
    tahun = None
    transmisi = None
    kilometer = None

    specification_list = hun.find("ul", class_="product-specification-list")

    if specification_list:
        specification_items = specification_list.find_all("li", class_="product-specification-item")

        for item in specification_items:
            label = item.find("p", class_="product-spec-label").text
            value = item.find("p", class_="product-spec-item").text

            if "Kapasitas Mesin" in label:
                kapasitas_mesin = value
            elif "Tahun" in label:
                tahun = value
            elif "Transmisi" in label:
                transmisi = value
            elif "Kilometer" in label:
                kilometer = value

    motor_suzuki = {
        "nama_motor": name,
        "lokasi" : location,
        "harga": price,
        "deskripsi": description,
        "kapasitas_mesin": kapasitas_mesin,
        "tahun": tahun,
        "transmisi": transmisi,
        "kilometer": kilometer
    }

    data_suzuki.append(motor_suzuki)
    counter = counter + 1
    print("completed", counter)
# Out:
# completed 1
# completed 2
# completed 3
# completed 4
# completed 5
# completed 6
# completed 7
# completed 8
# completed 9
# completed 10
# completed 11
# completed 12
# completed 13
# completed 14
# completed 15
# completed 16
# completed 17
# completed 18
# completed 19
# completed 20
# completed 21
# completed 22
# completed 23

# %%
# Convert ke data frame
df_suzuki = pd.DataFrame(data_suzuki)
df_suzuki
# Out:
#                     nama_motor                lokasi         harga  \
# 0              Suzuki Gsx R150            Kota Medan  Rp16,900,000
# 1         Suzuki Satria Fu 150  Kota Jakarta Selatan  Rp10,500,000
# 2                         None                  None          None
# 3                         None                  None          None
# 4              Suzuki Gsx R150        Kab. Tangerang  Rp23,500,000
# 5                         None                  None          None
# 6                         None                  None          None
# 7              Suzuki Gsx R150          Kota Bandung  Rp16,500,000
# 8              Suzuki Gsx R150        Kab. Tangerang  Rp23,500,000
# 9        Suzuki Gsx 150 Bandit    Kota Jakarta Barat  Rp18,500,000
# 10         Suzuki Satria F 150    Kota Jakarta Utara  Rp12,500,000
# 11             Suzuki Gsx R150        Kab. Tangerang  Rp17,500,000
# 12                        None                  None          None
# 13                        None                  None          None
# 14             Suzuki Gsx R150    Kota Jakarta Barat  Rp18,500,000
# 15             Suzuki Gsx R150    Kota Jakarta Barat  Rp15,500,000
# 16  Suzuki Satria F150 Fighter    Kota Jakarta Barat   Rp9,850,000
# 17             Suzuki Gsx R150        Kab. Tangerang  Rp23,500,000
# 18                        None                  None          None
# 19                        None                  None          None
# 20             Suzuki Gsx R150            Kab. Bogor  Rp15,500,000
# 21                        None                  None          None
# 22    Suzuki Satria Fu 150 Mfx  Kota Jakarta Selatan  Rp11,850,000
#
#                                             deskripsi kapasitas_mesin tahun  \
# 0   Suzuki GSX-R 150 Keyless Tahun 2017 Pemakaian ...          150 CC  2017
# 1   Motor mulus dan bagus surat2 lengkap dan tidak...          150 CC  2015
# 2                                                None            None  None
# 3                                                None            None  None
# 4   ❗️Ready Stock ❗️Dijual Suzuki GSX R150 tahun 2...          150 CC  2021
# 5                                                None            None  None
# 6                                                None            None  None
# 7   motor bekas berkualitas motor siap pakai ,cash...        150cc CC  2018
# 8   ❗️Ready Stock ❗️Dijual Suzuki gsx r 150 Tahun ...          150 CC  2021
# 9   Motor mulus dan bagus untuk surat-surat lengka...          150 CC  2018
# 10  Dijual Suzuki Satria F 150 Tahun 2017 Surat Su...        150cc CC  2017
# 11  Motor mulus dan bagus untuk surat-surat lengka...          150 CC  2019
# 12                                               None            None  None
# 13                                               None            None  None
# 14  Motor mulus dan bagus untuk surat-surat lengka...          150 CC  2018
# 15  Unit istimewaSurat lengkap akur atas bawahKeli...          150 CC  2017
# 16  Mulus original istimewa gres surat lengkap paj...        150cc CC  2015
# 17  Motor mulus dan bagus untuk surat-surat lengka...          150 CC  2021
# 18                                               None            None  None
# 19                                               None            None  None
# 20  Suzuki GSX R150 Kondisi seperti baru! KM Renda...               -  2017
# 21                                               None            None  None
# 22  Motor mulus dan bagus untuk surat-surat lengka...          150 CC  2017
#
#    transmisi        kilometer
# 0     Manual        >30000 KM
# 1   Otomatis        >30000 KM
# 2       None             None
# 3       None             None
# 4     Manual   5000 - 10000KM
# 5       None             None
# 6       None             None
# 7   Otomatis   1000 - 5000 KM
# 8     Manual   5000 - 10000KM
# 9     Manual        >30000 KM
# 10  Otomatis  10000 - 20000KM
# 11    Manual  10000 - 20000KM
# 12      None             None
# 13      None             None
# 14    Manual        >30000 KM
# 15  Otomatis  10000 - 20000KM
# 16    Manual        >30000 KM
# 17    Manual   5000 - 10000KM
# 18      None             None
# 19      None             None
# 20    Manual   5000 - 10000KM
# 21      None             None
# 22  Otomatis        >30000 KM

# %%
# Penyesuaian
df_suzuki['url'] = url_suzuki
df_suzuki['merk'] = 'Suzuki'
df_suzuki.shape
# Out:
# (23, 10)

# %% [markdown]
# ---
# Export Dataset

# %%
# Export to csv
df_yamaha.to_csv('motor_yamaha_bekas.csv', index=False)
df_honda.to_csv('motor_honda_bekas.csv', index=False)
df_kawasaki.to_csv('motor_kawasaki_bekas.csv', index=False)
df_suzuki.to_csv('motor_suzuki_bekas.csv', index=False)
