# %% [markdown]
# # Deep Learning Neural Network Model for Used Motorcycle Price Prediction
# ## IS794 AL - Deep Learning (Lab)
# Kelompok B: <br>
# - Daffa Kaisha Pratama Chandra (00000055770)
# - Justine Donovan (00000063202)
# - Marsella Patricia (00000063226)
# - Reina Ratu Balqis (00000065099)
# ---
# ### Import Libraries

# %%
# Basic library
import pandas as pd
import numpy as np

# Pre-processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import plotly.express as px
from plotly.subplots import make_subplots

# Handling imbalanced class using RandomOverSampling
from imblearn.over_sampling import RandomOverSampler

# Feature selection dengan random forest regressor
from sklearn.ensemble import RandomForestRegressor

# Deep learning
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# Ignore warning
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ---
# Baca Dataset

# %%
yamaha = pd.read_csv("../Dataset/motor_yamaha_bekas.csv", engine='pyarrow')
honda = pd.read_csv("../Dataset/motor_honda_bekas.csv", engine='pyarrow')
kawasaki = pd.read_csv("../Dataset/motor_kawasaki_bekas.csv", engine='pyarrow')
suzuki = pd.read_csv("../Dataset/motor_suzuki_bekas.csv", engine='pyarrow')

# %% [markdown]
# Penjelasan singkat mengenai dataset yang digunakan: <br>
# Dataset ini merupakan hasil web scraping dari website https://momotor.id/

# %%
print("Shape dari tiap dataset:")
print(f"Dataset Yamaha memiliki {yamaha.shape[1]} kolom dan {yamaha.shape[0]} baris.")
print(f"Dataset Honda memiliki {honda.shape[1]} kolom dan {honda.shape[0]} baris.")
print(f"Dataset Kawasaki memiliki {kawasaki.shape[1]} kolom dan {kawasaki.shape[0]} baris.")
print(f"Dataset Suzuki memiliki {suzuki.shape[1]} kolom dan {suzuki.shape[0]} baris.")
# Out:
# Shape dari tiap dataset:
# Dataset Yamaha memiliki 10 kolom dan 493 baris.
# Dataset Honda memiliki 10 kolom dan 966 baris.
# Dataset Kawasaki memiliki 10 kolom dan 96 baris.
# Dataset Suzuki memiliki 10 kolom dan 23 baris.

# %%
print("Informasi singkat dari tiap dataset:\n")
print("Yamaha:")
print(yamaha.info())
print("\nHonda:")
print(honda.info())
print("\nKawasaki:")
print(kawasaki.info())
print("\nSuzuki:")
print(suzuki.info())
# Out:
# Informasi singkat dari tiap dataset:
#
# Yamaha:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       352 non-null    object
#  1   lokasi           352 non-null    object
#  2   harga            352 non-null    object
#  3   deskripsi        352 non-null    object
#  4   kapasitas_mesin  352 non-null    object
#  5   tahun            352 non-null    float64
#  6   transmisi        352 non-null    object
#  7   kilometer        352 non-null    object
#  8   url              493 non-null    object
#  9   merk             493 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 38.6+ KB
# None
#
# Honda:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       629 non-null    object
#  1   lokasi           629 non-null    object
#  2   harga            629 non-null    object
#  3   deskripsi        629 non-null    object
#  4   kapasitas_mesin  629 non-null    object
#  5   tahun            629 non-null    float64
#  6   transmisi        629 non-null    object
#  7   kilometer        629 non-null    object
#  8   url              966 non-null    object
#  9   merk             966 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 75.6+ KB
# None
#
# Kawasaki:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       48 non-null     object
#  1   lokasi           48 non-null     object
#  2   harga            48 non-null     object
#  3   deskripsi        48 non-null     object
#  4   kapasitas_mesin  48 non-null     object
#  5   tahun            48 non-null     float64
#  6   transmisi        48 non-null     object
#  7   kilometer        48 non-null     object
#  8   url              96 non-null     object
#  9   merk             96 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 7.6+ KB
# None
#
# Suzuki:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       14 non-null     object
#  1   lokasi           14 non-null     object
#  2   harga            14 non-null     object
#  3   deskripsi        14 non-null     object
#  4   kapasitas_mesin  14 non-null     object
#  5   tahun            14 non-null     float64
#  6   transmisi        14 non-null     object
#  7   kilometer        14 non-null     object
#  8   url              23 non-null     object
#  9   merk             23 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 1.9+ KB
# None

# %% [markdown]
# Pre-processing: Data mentah -> Data siap pakai
# Akan dilakukan cek <i> missing values. </i> Jika terdapat <i> missing values, </i> data yang hilang akan diimputasi menggunakan nilai modus.

# %%
# Cek rata-rata missing values pada tiap dataset
brand = ['Yamaha', 'Honda', 'Kawasaki', 'Suzuki']
data = [yamaha, honda, kawasaki, suzuki]

for i, j in zip(brand, data):
    print(f"{i} missing values: \n{np.round(honda.isnull().mean(), 2)*100}")
    print()
# Out:
# Yamaha missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Honda missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Kawasaki missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Suzuki missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64

# %%
# cari modus dari tiap kolom yang terdapat missing values
kolom_null = ['nama_motor', 'lokasi', 'harga', 'deskripsi', 
              'kapasitas_mesin', 'tahun', 'transmisi', 'kilometer']

# %%
# Cari modus dan replace NaN dengan modus
for col in kolom_null:
    # Yamaha
    modus_yamaha = yamaha[col].value_counts().nlargest(3)
    # Honda
    modus_honda = yamaha[col].value_counts().nlargest(3)
    # Kawasaki
    modus_kawasaki = yamaha[col].value_counts().nlargest(3)
    # Suzuki
    modus_suzuki = yamaha[col].value_counts().nlargest(3)
    
    # Check if the mode values exist
    if len(modus_yamaha) >= 2:
        # Extract the mode strings
        modus_ymh1 = modus_yamaha.index[0]
        modus_ymh2 = modus_yamaha.index[1]

        # Define a list of possible string values between the modes
        possible_values_ymh = [modus_ymh1, modus_ymh2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        yamaha[col] = yamaha[col].apply(lambda x: np.random.choice(possible_values_ymh) if pd.isna(x) else x)

    if len(modus_honda) >= 2:
        # Extract the mode strings
        modus_hnd1 = modus_honda.index[0]
        modus_hnd2 = modus_honda.index[1]

        # Define a list of possible string values between the modes
        possible_values_hnd = [modus_hnd1, modus_hnd2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        honda[col] = honda[col].apply(lambda x: np.random.choice(possible_values_hnd) if pd.isna(x) else x)

    if len(modus_kawasaki) >= 2:
        # Extract the mode strings
        modus_kws1 = modus_kawasaki.index[0]
        modus_kws2 = modus_kawasaki.index[1]

        # Define a list of possible string values between the modes
        possible_values_kws = [modus_kws1, modus_kws2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        kawasaki[col] = kawasaki[col].apply(lambda x: np.random.choice(possible_values_kws) if pd.isna(x) else x)

    if len(modus_suzuki) >= 2:
        # Extract the mode strings
        modus_szk1 = modus_suzuki.index[0]
        modus_szk2 = modus_suzuki.index[1]

        # Define a list of possible string values between the modes
        possible_values_szk = [modus_szk1, modus_szk2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        suzuki[col] = suzuki[col].apply(lambda x: np.random.choice(possible_values_szk) if pd.isna(x) else x)

# %%
# Cek missing values lagi
for i, j in zip(brand, data):
    print(f"{i} missing values: \n{np.round(j.isnull().mean(), 2)*100}")
    print()
# Out:
# Yamaha missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Honda missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Kawasaki missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Suzuki missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64

# %%
# Merge dataset
used_motor = pd.concat([yamaha, honda, kawasaki, suzuki])
print("Shape dari dataset yang digabung: ", used_motor.shape)
# Out:
# Shape dari dataset yang digabung:  (1578, 10)

# %% [markdown]
# ---
# #### Data Pre-processing
# Pada tahap ini, akan dilakukan:
# - Oversampling Data yang sedikit dengan Random Oversampling
# - <i>Remove missing values</i>
# - Membersihkan kolom harga
# - Membersihkan kolom kapasitas mesin

# %% [markdown]
# Random Oversampling

# %%
print("Merk Motor:\n",used_motor['merk'].value_counts())
# Out:
# Merk Motor:
#  merk
# Honda       966
# Yamaha      493
# Kawasaki     96
# Suzuki       23
# Name: count, dtype: int64

# %%
class_cnt = [966, 493, 96, 23]

minor_class = ['Yamaha', 'Kawasaki', 'Suzuki']

class_mapping = {'Honda': 0, 'Yamaha': 1, 'Kawasaki': 2, 'Suzuki': 3}
used_motor['ClassEncoded'] = used_motor['merk'].map(class_mapping)

# %%
# Specify the oversampling strategy for each class
sampling_strategy = {
    0: class_cnt[0],  # No oversampling for Honda
    1: class_cnt[0],  # Oversample Yamaha to match Honda
    2: class_cnt[0],  # Oversample Kawasaki to match Honda
    3: class_cnt[0]   # Oversample Suzuki to match Honda
}

# Create the RandomOverSampler with the specified strategy
ros = RandomOverSampler(sampling_strategy=sampling_strategy, random_state=42)

# Extract features and labels
X = used_motor.drop(['merk', 'ClassEncoded'], axis=1)  # Adjust column names accordingly
y = used_motor['ClassEncoded']

# Fit and transform the data
X_resampled, y_resampled = ros.fit_resample(X, y)

# Merge the resampled features and labels back into a DataFrame
resampled_motor = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='ClassEncoded')], axis=1)

# Map the numeric labels back to class names
resampled_motor['merk'] = resampled_motor['ClassEncoded'].map({v: k for k, v in class_mapping.items()})

# Drop the temporary 'ClassEncoded' column
resampled_motor = resampled_motor.drop('ClassEncoded', axis=1)

# Print the counts of each class in the resampled DataFrame
print(resampled_motor['merk'].value_counts())
# Out:
# merk
# Yamaha      966
# Honda       966
# Kawasaki    966
# Suzuki      966
# Name: count, dtype: int64

# %% [markdown]
# ##### Drop variabel yang tidak dibutuhkan

# %%
resampled_motor = resampled_motor.drop(columns=['deskripsi', 'url'])
resampled_motor.head()
# Out:
#              nama_motor              lokasi         harga kapasitas_mesin  \
# 0  Yamaha Aerox 155 Vva      Kab. Tangerang  Rp24,500,000          125 CC
# 1       Yamaha Nmax Abs  Kota Jakarta Barat  Rp23,500,000          125 CC
# 2  Yamaha Aerox 155 Vva      Kab. Tangerang  Rp24,500,000          125 CC
# 3  Yamaha Aerox 155 Vva  Kota Jakarta Barat  Rp24,500,000          155 CC
# 4       Yamaha Nmax Abs  Kota Jakarta Barat  Rp23,500,000          155 CC
#
#     tahun transmisi        kilometer    merk
# 0  2019.0    Manual        >30000 KM  Yamaha
# 1  2019.0  Otomatis  10000 - 20000KM  Yamaha
# 2  2018.0    Manual  10000 - 20000KM  Yamaha
# 3  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 4  2019.0    Manual        >30000 KM  Yamaha

# %%
# Lihat nilai unik dari setiap kolom
kolom = resampled_motor.columns

for i in kolom:
    print(f"Nilai unik dari kolom {i}:")
    print(resampled_motor[i].value_counts())
    print()
# Out:
# Nilai unik dari kolom nama_motor:
# nama_motor
# Yamaha Nmax Abs                      899
# Yamaha Aerox 155 Vva                 763
# Suzuki Gsx R150                      384
# Kawasaki Ninja 250 Fi                 74
# Yamaha Lexi                           56
#                                     ...
# Honda GENIO CBS                        1
# Honda New Scoopy Fashion               1
# Honda New Revo Fi Fit                  1
# Yamaha Gear 125 S-version              1
# Honda Beat Fi Sporty Cbs Iss Plus      1
# Name: count, Length: 154, dtype: int64
#
# Nilai unik dari kolom lokasi:
# lokasi
# Kab. Tangerang            1287
# Kota Jakarta Barat        1220
# Kota Jakarta Selatan       378
# Kota Bandung               349
# Kota Jakarta Timur         191
# Kab. Bogor                 100
# Kota Jakarta Utara          89
# Kota Medan                  82
# Kota Tangerang              53
# Kab. Bandung                51
# Kota  Batam                 25
# Kota Tangerang Selatan      15
# Kota Bekasi                 14
# Kota Depok                   5
# Kota Surabaya                3
# Kab. Deli Serdang            2
# Name: count, dtype: int64
#
# Nilai unik dari kolom harga:
# harga
# Rp23,500,000    929
# Rp24,500,000    803
# Rp18,500,000    114
# Rp16,500,000     90
# Rp17,500,000     88
#                ...
# Rp32,100,000      1
# Rp15,600,000      1
# Rp22,200,000      1
# Rp13,750,000      1
# Rp28,300,000      1
# Name: count, Length: 261, dtype: int64
#
# Nilai unik dari kolom kapasitas_mesin:
# kapasitas_mesin
# 125 CC           1107
# 155 CC            919
# 150 CC            738
# 110 CC            298
# 150cc CC          226
# 250 CC            160
# 155cc CC           74
# 125cc CC           56
# -                  56
# 175 CC             48
# 110cc CC           47
# 250cc CC           46
# 900 CC             17
# 600 CC              9
# 250Cc CC            9
# 115cc CC            8
# 175cc CC            7
# DSE4202201 CC       7
# 160 CC              6
# 125CC CC            5
# 250  CC             4
# 156 CC              4
# 249 CC              2
# 125 cc CC           2
# 156cc CC            2
# 220 CC              2
# 11pcc CC            1
# 115 CC              1
#  CC                 1
# 113cc CC            1
# 1550 CC             1
# Name: count, dtype: int64
#
# Nilai unik dari kolom tahun:
# tahun
# 2018.0    1223
# 2019.0    1207
# 2017.0     423
# 2021.0     402
# 2015.0     217
# 2020.0     181
# 2016.0     156
# 2022.0      55
# Name: count, dtype: int64
#
# Nilai unik dari kolom transmisi:
# transmisi
# Otomatis    2251
# Manual      1613
# Name: count, dtype: int64
#
# Nilai unik dari kolom kilometer:
# kilometer
# 10000 - 20000KM    1617
# >30000 KM          1394
# 1000 - 5000 KM      444
# 5000 - 10000KM      378
# 0 - 1000 KM          31
# Name: count, dtype: int64
#
# Nilai unik dari kolom merk:
# merk
# Yamaha      966
# Honda       966
# Kawasaki    966
# Suzuki      966
# Name: count, dtype: int64

# %% [markdown]
# Kolom kapasitas mesin dan harga belum dalam format yang benar

# %% [markdown]
# ##### Membersihkan kolom harga

# %%
def clean_harga(harga):
    harga_clean = harga.replace("Rp", "").replace(".", "").replace(",", "")
    return harga_clean

resampled_motor['harga'] = resampled_motor['harga'].apply(clean_harga)
resampled_motor['harga'] = resampled_motor['harga'].astype("float")

# %% [markdown]
# ##### Membersihkan kolom kapasitas mesin

# %%
def clean_cc(kapasitas_mesin):
    cc_clean = kapasitas_mesin.replace("cc", "")
    cc_clean2 = cc_clean.replace(" CC", "")
    cc_clean3 = cc_clean2.replace("Cc", "")
    cc_clean4 = cc_clean3.replace("CC", "")
    cc_clean5 = cc_clean4.replace("p", "")
    return cc_clean5

resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].apply(clean_cc)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(['-', ''], 150)
used_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace('1550', 150)
resampled_motor = resampled_motor[resampled_motor['kapasitas_mesin'] != 'DSE4202201']
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].astype('int')
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(11, 110)
print(resampled_motor['kapasitas_mesin'].unique())
# Out:
# [ 125  155  220  150  250  156  110 1550  249  115  160  113  900  175
#   600]

# %% [markdown]
# ---
# #### Exploratory Data Analysis <br>
# Pada tahap EDA, akan dilakukan beberapa tahapan untuk menemukan pola pada data dengan menggunakan statistik dan visualisasi data. Beberapa tahapan yang akan dilakukan sebagai berikut:
# - Melihat informasi data
# - Melihat nilai unik tiap kolom
# - Melihat statistika dasar
# - Visualisasi data

# %%
# Melihat informasi dataset
resampled_motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3857 entries, 0 to 3863
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       3857 non-null   object
#  1   lokasi           3857 non-null   object
#  2   harga            3857 non-null   float64
#  3   kapasitas_mesin  3857 non-null   int32
#  4   tahun            3857 non-null   float64
#  5   transmisi        3857 non-null   object
#  6   kilometer        3857 non-null   object
#  7   merk             3857 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 256.1+ KB

# %%
# Loop melalui tiap kolom dan mencetak nilai unik
unique_value_count ={}
for column in resampled_motor.columns : 
    unique_values = resampled_motor[column].unique()
    unique_count = len(unique_values)
    unique_value_count[column] = unique_count

for column, count in unique_value_count.items():
    print(f"{column} : {count}")
# Out:
# nama_motor : 153
# lokasi : 16
# harga : 260
# kapasitas_mesin : 15
# tahun : 8
# transmisi : 2
# kilometer : 5
# merk : 4

# %%
# Melihat Statistika data numerik
resampled_motor.describe()
# Out:
#               harga  kapasitas_mesin        tahun
# count  3.857000e+03      3857.000000  3857.000000
# mean   2.518297e+07       150.889811  2018.413534
# std    2.473042e+07        66.239006     1.505644
# min    8.550000e+06       110.000000  2015.000000
# 25%    1.850000e+07       125.000000  2018.000000
# 50%    2.350000e+07       150.000000  2018.000000
# 75%    2.450000e+07       155.000000  2019.000000
# max    3.650000e+08      1550.000000  2022.000000

# %%
# Melihat Statistika data kategorikal
resampled_motor.describe(exclude=np.number)
# Out:
#              nama_motor          lokasi transmisi        kilometer    merk
# count              3857            3857      3857             3857    3857
# unique              153              16         2                5       4
# top     Yamaha Nmax Abs  Kab. Tangerang  Otomatis  10000 - 20000KM  Yamaha
# freq                899            1287      2251             1610     966

# %%
# Visualisasi distribusi harga motor semua merk
sns.histplot(resampled_motor['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %%
# Visualisasi distribusi harga tiap merk motor
# Subplot
fig = make_subplots(rows=2, cols=2, subplot_titles=['Honda', 'Yamaha', 'Kawasaki', 'Suzuki'])

# Plot for Honda Turbo aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Honda'], x='harga', nbins=30, color_discrete_sequence=['#ca91eb']).update_traces(histnorm='probability').data[0], row=1, col=1)

# Plot for Yamaha Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Yamaha'], x='harga', nbins=30, color_discrete_sequence=['#eb6426']).update_traces(histnorm='probability').data[0], row=1, col=2)

# Plot for Kawasaki Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Kawasaki'], x='harga', nbins=30, color_discrete_sequence=['#91caeb']).update_traces(histnorm='probability').data[0], row=2, col=1)

# Plot for Suzuki Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Suzuki'], x='harga', nbins=30, color_discrete_sequence=['#265aeb']).update_traces(histnorm='probability').data[0], row=2, col=2)

# Update layout
fig.update_layout(showlegend=False, title_text="Distribusi Harga Tiap Merk Motor")

# Show the plot
fig.show()

# %%
# Visualisasi Rata-Rata Harga Motor

hargapermerk = resampled_motor.groupby("merk")["harga"].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x="merk", y="harga", data=hargapermerk, order=hargapermerk.sort_values('harga', ascending=False)['merk'])
plt.title("Rata-rata Harga Motor Berdasarkan Merk")
plt.xlabel("Merk Motor")
plt.ylabel("Harga Motor")
plt.show()

# %% [markdown]
# Dari visualisasi, terlihat rata-rata harga paling mahal adalah merk motor Kawasaki

# %% [markdown]
# ### Data Preparation

# %%
resampled_motor.head()
# Out:
#              nama_motor              lokasi       harga  kapasitas_mesin  \
# 0  Yamaha Aerox 155 Vva      Kab. Tangerang  24500000.0              125
# 1       Yamaha Nmax Abs  Kota Jakarta Barat  23500000.0              125
# 2  Yamaha Aerox 155 Vva      Kab. Tangerang  24500000.0              125
# 3  Yamaha Aerox 155 Vva  Kota Jakarta Barat  24500000.0              155
# 4       Yamaha Nmax Abs  Kota Jakarta Barat  23500000.0              155
#
#     tahun transmisi        kilometer    merk
# 0  2019.0    Manual        >30000 KM  Yamaha
# 1  2019.0  Otomatis  10000 - 20000KM  Yamaha
# 2  2018.0    Manual  10000 - 20000KM  Yamaha
# 3  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 4  2019.0    Manual        >30000 KM  Yamaha

# %%
resampled_motor.tail()
# Out:
#                       nama_motor              lokasi       harga  \
# 3859             Suzuki Gsx R150          Kab. Bogor  15500000.0
# 3860        Yamaha Aerox 155 Vva      Kab. Tangerang  24500000.0
# 3861             Suzuki Gsx R150          Kota Medan  16900000.0
# 3862  Suzuki Satria F150 Fighter  Kota Jakarta Barat   9850000.0
# 3863  Suzuki Satria F150 Fighter  Kota Jakarta Barat   9850000.0
#
#       kapasitas_mesin   tahun transmisi       kilometer    merk
# 3859              150  2017.0    Manual  5000 - 10000KM  Suzuki
# 3860              125  2019.0  Otomatis       >30000 KM  Suzuki
# 3861              150  2017.0    Manual       >30000 KM  Suzuki
# 3862              150  2015.0    Manual       >30000 KM  Suzuki
# 3863              150  2015.0    Manual       >30000 KM  Suzuki

# %%
resampled_motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3857 entries, 0 to 3863
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       3857 non-null   object
#  1   lokasi           3857 non-null   object
#  2   harga            3857 non-null   float64
#  3   kapasitas_mesin  3857 non-null   int32
#  4   tahun            3857 non-null   float64
#  5   transmisi        3857 non-null   object
#  6   kilometer        3857 non-null   object
#  7   merk             3857 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 256.1+ KB

# %% [markdown]
# ##### Encoding

# %%
# Encoding Manual
# Kolom merk
resampled_motor['merk'] = resampled_motor['merk'].replace({'Yamaha' : 1, 
                                                           'Honda' : 2, 
                                                           'Kawasaki' : 3, 
                                                           'Suzuki' : 4})

# Kolom transmisi
resampled_motor['transmisi'] = resampled_motor['merk'].replace({'Manual' : 1, 
                                                                'Otomatis' : 2})

# Kolom kilometer
resampled_motor['kilometer'] = resampled_motor['kilometer'].replace({'>30000 KM' : 5, 
                                                                     '10000 - 20000KM' : 4,
                                                                     '1000 - 5000 KM' : 3, 
                                                                     '5000 - 10000KM' : 2,
                                                                     '0 - 1000 KM' : 1})

# Kolom lokasi
resampled_motor['lokasi'] = resampled_motor['lokasi'].replace({'Kota Jakarta Barat' : 1,
                                                               'Kab. Tangerang' : 2,
                                                               'Kota Jakarta Selatan' : 3,
                                                               'Kota Bandung' : 4,
                                                               'Kota Jakarta Timur' : 5,
                                                               'Kab. Bogor' : 6,
                                                               'Kota Jakarta Utara' : 7,
                                                               'Kota Medan' : 8,
                                                               'Kota Tangerang' : 9,
                                                               'Kab. Bandung' : 10,
                                                               'Kota  Batam' : 11,
                                                               'Kota Tangerang Selatan' : 12,
                                                               'Kota Bekasi' : 13,
                                                               'Kota Depok' : 14,
                                                               'Kota Surabaya' : 15,
                                                               'Kab. Deli Serdang' : 16
                                                               })

# %% [markdown]
# ##### MinMax Scaler

# %% [markdown]
# ##### Feature Selection

# %%
# Choosing X and y
X = resampled_motor.drop(columns=['harga', 'nama_motor'])
y = resampled_motor['harga']

# %%
# Train test split untuk feature importance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Random forest regressor untuk memilih feature importance
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_fi = rf.feature_importances_

# Define Nama columns
feature_names = X.columns.tolist()

plt.figure(figsize=(10, 6))

# Plotting feature importances
plt.barh(feature_names, rf_fi)
plt.xlabel('Feature Names')
plt.ylabel('Importance')
plt.title('Visualisasi Feature Importance')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---
# #### Modeling
# Pada tahap modeling, akan dilakukan:
# - Seleksi fitur
# - Membangun model RNN
# - Tuning hyperparameter
#
# Seleksi fitur

# %%
# Choosing X and y
X = resampled_motor.drop(columns=['harga', 'nama_motor', 'transmisi'])
y = resampled_motor['harga'].values.reshape(-1,1)

# Standarize
X_scaler = StandardScaler().fit(X)
y_scaler = StandardScaler().fit(y)
X_scaled = X_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y)

# %%
# Train test split untuk feature importance
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.1, random_state=42)
# X_train_scaled = StandardScaler().fit_transform(X_train)
# X_test_scaled = StandardScaler().fit_transform(X_test)

# %% [markdown]
# Modeling
# - Tanpa tuning hyperparameter

# %%
# Build the DNN model
model = Sequential()
model.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 13249 (51.75 KB)
# Trainable params: 13249 (51.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history1 = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 20ms/step - loss: 2.3159 - mean_absolute_error: 0.3252 - val_loss: 2.2147 - val_mean_absolute_error: 0.2890
# Epoch 2/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.9484 - mean_absolute_error: 0.2798 - val_loss: 1.8243 - val_mean_absolute_error: 0.2530
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.7748 - mean_absolute_error: 0.2668 - val_loss: 1.4477 - val_mean_absolute_error: 0.2163
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.3931 - mean_absolute_error: 0.2316 - val_loss: 1.2367 - val_mean_absolute_error: 0.1954
# Epoch 5/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.1943 - mean_absolute_error: 0.2193 - val_loss: 1.0307 - val_mean_absolute_error: 0.1812
# Epoch 6/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1712 - mean_absolute_error: 0.2096 - val_loss: 0.9153 - val_mean_absolute_error: 0.1806
# Epoch 7/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0701 - mean_absolute_error: 0.2114 - val_loss: 0.8429 - val_mean_absolute_error: 0.1806
# Epoch 8/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8255 - mean_absolute_error: 0.1979 - val_loss: 0.7802 - val_mean_absolute_error: 0.1823
# Epoch 9/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7961 - mean_absolute_error: 0.1964 - val_loss: 0.6989 - val_mean_absolute_error: 0.1780
# Epoch 10/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9145 - mean_absolute_error: 0.2047 - val_loss: 0.6950 - val_mean_absolute_error: 0.1889
# Epoch 11/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7535 - mean_absolute_error: 0.1932 - val_loss: 0.6339 - val_mean_absolute_error: 0.1799
# Epoch 12/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7365 - mean_absolute_error: 0.1975 - val_loss: 0.5839 - val_mean_absolute_error: 0.1712
# Epoch 13/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7236 - mean_absolute_error: 0.1960 - val_loss: 0.5542 - val_mean_absolute_error: 0.1726
# Epoch 14/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6316 - mean_absolute_error: 0.1895 - val_loss: 0.5036 - val_mean_absolute_error: 0.1644
# Epoch 15/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7080 - mean_absolute_error: 0.1792 - val_loss: 0.4965 - val_mean_absolute_error: 0.1680
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6184 - mean_absolute_error: 0.1893 - val_loss: 0.5600 - val_mean_absolute_error: 0.1861
# Epoch 17/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6637 - mean_absolute_error: 0.1903 - val_loss: 0.5242 - val_mean_absolute_error: 0.1784
# Epoch 18/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6437 - mean_absolute_error: 0.1892 - val_loss: 0.4556 - val_mean_absolute_error: 0.1592
# Epoch 19/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6913 - mean_absolute_error: 0.1918 - val_loss: 0.4901 - val_mean_absolute_error: 0.1732
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5351 - mean_absolute_error: 0.1820 - val_loss: 0.4117 - val_mean_absolute_error: 0.1554
# Epoch 21/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5333 - mean_absolute_error: 0.1755 - val_loss: 0.3957 - val_mean_absolute_error: 0.1520
# Epoch 22/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4700 - mean_absolute_error: 0.1721 - val_loss: 0.3943 - val_mean_absolute_error: 0.1566
# Epoch 23/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5097 - mean_absolute_error: 0.1749 - val_loss: 0.3573 - val_mean_absolute_error: 0.1413
# Epoch 24/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4904 - mean_absolute_error: 0.1754 - val_loss: 0.3515 - val_mean_absolute_error: 0.1442
# Epoch 25/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4522 - mean_absolute_error: 0.1714 - val_loss: 0.3485 - val_mean_absolute_error: 0.1481
# Epoch 26/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4858 - mean_absolute_error: 0.1739 - val_loss: 0.3211 - val_mean_absolute_error: 0.1355
# Epoch 27/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4319 - mean_absolute_error: 0.1661 - val_loss: 0.3609 - val_mean_absolute_error: 0.1566
# Epoch 28/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4845 - mean_absolute_error: 0.1708 - val_loss: 0.3367 - val_mean_absolute_error: 0.1505
# Epoch 29/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4072 - mean_absolute_error: 0.1652 - val_loss: 0.2998 - val_mean_absolute_error: 0.1387
# Epoch 30/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4606 - mean_absolute_error: 0.1724 - val_loss: 0.3638 - val_mean_absolute_error: 0.1647
# Epoch 31/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4464 - mean_absolute_error: 0.1704 - val_loss: 0.3137 - val_mean_absolute_error: 0.1457
# Epoch 32/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3478 - mean_absolute_error: 0.1631 - val_loss: 0.2784 - val_mean_absolute_error: 0.1309
# Epoch 33/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4692 - mean_absolute_error: 0.1703 - val_loss: 0.3024 - val_mean_absolute_error: 0.1481
# Epoch 34/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4032 - mean_absolute_error: 0.1663 - val_loss: 0.3272 - val_mean_absolute_error: 0.1538
# Epoch 35/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4690 - mean_absolute_error: 0.1734 - val_loss: 0.3313 - val_mean_absolute_error: 0.1577
# Epoch 36/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3883 - mean_absolute_error: 0.1700 - val_loss: 0.2637 - val_mean_absolute_error: 0.1298
# Epoch 37/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3424 - mean_absolute_error: 0.1617 - val_loss: 0.2667 - val_mean_absolute_error: 0.1352
# Epoch 38/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3805 - mean_absolute_error: 0.1635 - val_loss: 0.2594 - val_mean_absolute_error: 0.1339
# Epoch 39/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3659 - mean_absolute_error: 0.1611 - val_loss: 0.2683 - val_mean_absolute_error: 0.1409
# Epoch 40/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3674 - mean_absolute_error: 0.1629 - val_loss: 0.2411 - val_mean_absolute_error: 0.1218
# Epoch 41/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3788 - mean_absolute_error: 0.1592 - val_loss: 0.2500 - val_mean_absolute_error: 0.1345
# Epoch 42/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3399 - mean_absolute_error: 0.1589 - val_loss: 0.2371 - val_mean_absolute_error: 0.1250
# Epoch 43/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2924 - mean_absolute_error: 0.1515 - val_loss: 0.2380 - val_mean_absolute_error: 0.1312
# Epoch 44/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3091 - mean_absolute_error: 0.1547 - val_loss: 0.2399 - val_mean_absolute_error: 0.1337
# Epoch 45/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3083 - mean_absolute_error: 0.1571 - val_loss: 0.2606 - val_mean_absolute_error: 0.1417
# Epoch 46/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3249 - mean_absolute_error: 0.1587 - val_loss: 0.2423 - val_mean_absolute_error: 0.1355
# Epoch 47/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3107 - mean_absolute_error: 0.1528 - val_loss: 0.2390 - val_mean_absolute_error: 0.1335
# Epoch 48/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3689 - mean_absolute_error: 0.1640 - val_loss: 0.2414 - val_mean_absolute_error: 0.1415
# Epoch 49/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2955 - mean_absolute_error: 0.1523 - val_loss: 0.2255 - val_mean_absolute_error: 0.1318
# Epoch 50/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3222 - mean_absolute_error: 0.1560 - val_loss: 0.2085 - val_mean_absolute_error: 0.1174
# Epoch 51/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3634 - mean_absolute_error: 0.1608 - val_loss: 0.2269 - val_mean_absolute_error: 0.1361
# Epoch 52/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3029 - mean_absolute_error: 0.1519 - val_loss: 0.2522 - val_mean_absolute_error: 0.1427
# Epoch 53/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2737 - mean_absolute_error: 0.1527 - val_loss: 0.2063 - val_mean_absolute_error: 0.1214
# Epoch 54/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2735 - mean_absolute_error: 0.1513 - val_loss: 0.2005 - val_mean_absolute_error: 0.1236
# Epoch 55/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3415 - mean_absolute_error: 0.1591 - val_loss: 0.2200 - val_mean_absolute_error: 0.1365
# Epoch 56/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2754 - mean_absolute_error: 0.1537 - val_loss: 0.1922 - val_mean_absolute_error: 0.1178
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2680 - mean_absolute_error: 0.1513 - val_loss: 0.2203 - val_mean_absolute_error: 0.1394
# Epoch 58/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2831 - mean_absolute_error: 0.1547 - val_loss: 0.1920 - val_mean_absolute_error: 0.1215
# Epoch 59/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2731 - mean_absolute_error: 0.1482 - val_loss: 0.1896 - val_mean_absolute_error: 0.1206
# Epoch 60/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2870 - mean_absolute_error: 0.1490 - val_loss: 0.2004 - val_mean_absolute_error: 0.1287
# Epoch 61/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2516 - mean_absolute_error: 0.1488 - val_loss: 0.1856 - val_mean_absolute_error: 0.1216
# Epoch 62/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2289 - mean_absolute_error: 0.1463 - val_loss: 0.1837 - val_mean_absolute_error: 0.1254
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2764 - mean_absolute_error: 0.1485 - val_loss: 0.1862 - val_mean_absolute_error: 0.1259
# Epoch 64/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2568 - mean_absolute_error: 0.1482 - val_loss: 0.1872 - val_mean_absolute_error: 0.1243
# Epoch 65/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2776 - mean_absolute_error: 0.1496 - val_loss: 0.1977 - val_mean_absolute_error: 0.1330
# Epoch 66/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2232 - mean_absolute_error: 0.1444 - val_loss: 0.1748 - val_mean_absolute_error: 0.1176
# Epoch 67/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2694 - mean_absolute_error: 0.1508 - val_loss: 0.1766 - val_mean_absolute_error: 0.1256
# Epoch 68/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2419 - mean_absolute_error: 0.1456 - val_loss: 0.1875 - val_mean_absolute_error: 0.1300
# Epoch 69/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2308 - mean_absolute_error: 0.1458 - val_loss: 0.1662 - val_mean_absolute_error: 0.1164
# Epoch 70/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2804 - mean_absolute_error: 0.1457 - val_loss: 0.1688 - val_mean_absolute_error: 0.1201
# Epoch 71/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2535 - mean_absolute_error: 0.1445 - val_loss: 0.1602 - val_mean_absolute_error: 0.1139
# Epoch 72/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2542 - mean_absolute_error: 0.1487 - val_loss: 0.2000 - val_mean_absolute_error: 0.1364
# Epoch 73/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2283 - mean_absolute_error: 0.1462 - val_loss: 0.1844 - val_mean_absolute_error: 0.1266
# Epoch 74/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2774 - mean_absolute_error: 0.1472 - val_loss: 0.1873 - val_mean_absolute_error: 0.1286
# Epoch 75/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2419 - mean_absolute_error: 0.1497 - val_loss: 0.1619 - val_mean_absolute_error: 0.1205
# Epoch 76/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2220 - mean_absolute_error: 0.1447 - val_loss: 0.1589 - val_mean_absolute_error: 0.1205
# Epoch 77/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2504 - mean_absolute_error: 0.1502 - val_loss: 0.1814 - val_mean_absolute_error: 0.1367
# Epoch 78/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2240 - mean_absolute_error: 0.1470 - val_loss: 0.1537 - val_mean_absolute_error: 0.1183
# Epoch 79/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2414 - mean_absolute_error: 0.1457 - val_loss: 0.2018 - val_mean_absolute_error: 0.1400
# Epoch 80/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2478 - mean_absolute_error: 0.1503 - val_loss: 0.1568 - val_mean_absolute_error: 0.1237
# Epoch 81/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2209 - mean_absolute_error: 0.1426 - val_loss: 0.1471 - val_mean_absolute_error: 0.1155
# Epoch 82/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2140 - mean_absolute_error: 0.1422 - val_loss: 0.1476 - val_mean_absolute_error: 0.1170
# Epoch 83/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2466 - mean_absolute_error: 0.1473 - val_loss: 0.1705 - val_mean_absolute_error: 0.1274
# Epoch 84/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2221 - mean_absolute_error: 0.1450 - val_loss: 0.1551 - val_mean_absolute_error: 0.1236
# Epoch 85/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2454 - mean_absolute_error: 0.1470 - val_loss: 0.1692 - val_mean_absolute_error: 0.1273
# Epoch 86/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2314 - mean_absolute_error: 0.1446 - val_loss: 0.1631 - val_mean_absolute_error: 0.1247
# Epoch 87/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1890 - mean_absolute_error: 0.1421 - val_loss: 0.1451 - val_mean_absolute_error: 0.1159
# Epoch 88/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2025 - mean_absolute_error: 0.1384 - val_loss: 0.1336 - val_mean_absolute_error: 0.1072
# Epoch 89/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2079 - mean_absolute_error: 0.1424 - val_loss: 0.1550 - val_mean_absolute_error: 0.1285
# Epoch 90/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2055 - mean_absolute_error: 0.1437 - val_loss: 0.1437 - val_mean_absolute_error: 0.1203
# Epoch 91/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2502 - mean_absolute_error: 0.1473 - val_loss: 0.1429 - val_mean_absolute_error: 0.1204
# Epoch 92/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2151 - mean_absolute_error: 0.1441 - val_loss: 0.1483 - val_mean_absolute_error: 0.1249
# Epoch 93/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2286 - mean_absolute_error: 0.1449 - val_loss: 0.1310 - val_mean_absolute_error: 0.1114
# Epoch 94/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1863 - mean_absolute_error: 0.1406 - val_loss: 0.1345 - val_mean_absolute_error: 0.1167
# Epoch 95/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1728 - mean_absolute_error: 0.1373 - val_loss: 0.1376 - val_mean_absolute_error: 0.1177
# Epoch 96/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1893 - mean_absolute_error: 0.1374 - val_loss: 0.1267 - val_mean_absolute_error: 0.1118
# Epoch 97/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1960 - mean_absolute_error: 0.1424 - val_loss: 0.1274 - val_mean_absolute_error: 0.1144
# Epoch 98/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1972 - mean_absolute_error: 0.1426 - val_loss: 0.1296 - val_mean_absolute_error: 0.1156
# Epoch 99/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2512 - mean_absolute_error: 0.1513 - val_loss: 0.1246 - val_mean_absolute_error: 0.1141
# Epoch 100/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2159 - mean_absolute_error: 0.1493 - val_loss: 0.1573 - val_mean_absolute_error: 0.1352

# %%
loss = model.evaluate(X_test, y_test)
print(loss)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1573 - mean_absolute_error: 0.1352
# [0.15728306770324707, 0.13515016436576843]

# %%
y_pred = model.predict(X_test)
print(f"R-squared: {np.round(r2_score(y_test, y_pred),2)*100}%")
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
# Out:
# 13/13 [==============================] - 0s 2ms/step
# R-squared: 95.0%
# MAE:  0.13515015729448723
# MSE:  0.06402759151423609

# %%
# let's see the training and validation accuracy by epoch
history_dict = history1.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Tuning Hyperparameter <br>
# import library keras tuner

# %%
import keras_tuner as kt

# %%
# Fungsi untuk membangun model
def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units_1', min_value=32, max_value=256, step=32), 
                    input_shape=(X_train.shape[1],), activation='relu'))
    
    model.add(Dense(units=hp.Int('units_2', min_value=32, max_value=256, step=32), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(rate=hp.Float('dropout_3', min_value=0.2, max_value=0.8, step=0.1)))
    
    model.add(Dense(units=hp.Int('units_3', min_value=32, max_value=256, step=32), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(rate=hp.Float('dropout_3', min_value=0.2, max_value=0.8, step=0.1)))
    
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %%
tuner = kt.RandomSearch(build_model,
                     objective='mean_absolute_error',
                     max_trials=10,
                     executions_per_trial=10,
                     directory='./tuning5')
# Out:
# Reloading Tuner from ./tuning5\untitled_project\tuner0.json

# %%
stop_early = EarlyStopping(monitor='val_loss', patience=10)

# %%
tuner.search(X_train, y_train, 
             epochs=100, batch_size=256, 
             validation_data=(X_test, y_test),
             callbacks=[stop_early])

# %%
best_model = tuner.get_best_models(num_models=1)[0]

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./tuning5\untitled_project
# Showing 10 best trials
# Objective(name="mean_absolute_error", direction="min")
#
# Trial 07 summary
# Hyperparameters:
# units_1: 256
# units_2: 128
# dropout_3: 0.2
# units_3: 160
# Score: 0.09907708019018173
#
# Trial 02 summary
# Hyperparameters:
# units_1: 160
# units_2: 256
# dropout_3: 0.30000000000000004
# units_3: 128
# Score: 0.10591869279742241
#
# Trial 05 summary
# Hyperparameters:
# units_1: 192
# units_2: 96
# dropout_3: 0.30000000000000004
# units_3: 160
# Score: 0.10739048421382905
#
# Trial 03 summary
# Hyperparameters:
# units_1: 256
# units_2: 160
# dropout_3: 0.30000000000000004
# units_3: 96
# Score: 0.10883446484804153
#
# Trial 04 summary
# Hyperparameters:
# units_1: 32
# units_2: 192
# dropout_3: 0.4
# units_3: 256
# Score: 0.11437539905309677
#
# Trial 00 summary
# Hyperparameters:
# units_1: 160
# units_2: 64
# dropout_3: 0.5
# units_3: 160
# Score: 0.12499143406748772
#
# Trial 01 summary
# Hyperparameters:
# units_1: 256
# units_2: 192
# dropout_3: 0.4
# units_3: 32
# Score: 0.12683913633227348
#
# Trial 06 summary
# Hyperparameters:
# units_1: 192
# units_2: 64
# dropout_3: 0.6000000000000001
# units_3: 160
# Score: 0.13915660977363586
#
# Trial 09 summary
# Hyperparameters:
# units_1: 32
# units_2: 160
# dropout_3: 0.7
# units_3: 96
# Score: 0.15445999801158905
#
# Trial 08 summary
# Hyperparameters:
# units_1: 256
# units_2: 224
# dropout_3: 0.8
# units_3: 256
# Score: 0.15948962420225143

# %% [markdown]
# Finalisasi Model

# %%
model3 = Sequential()
model3.add(Dense(256, input_shape=(X_train.shape[1],), activation='relu'))
model3.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.2))
model3.add(Dense(160, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model3.add(Dense(1, activation='linear'))
model3.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               1536
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 160)               20640
#
#  dense_7 (Dense)             (None, 1)                 161
#
# =================================================================
# Total params: 55233 (215.75 KB)
# Trainable params: 55233 (215.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history2 = model3.fit(X_train, y_train, 
             epochs=100, batch_size=256, 
             validation_data=(X_test, y_test), 
             callbacks=[stop_early])
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 17ms/step - loss: 3.6011 - mean_absolute_error: 0.2728 - val_loss: 2.9068 - val_mean_absolute_error: 0.2268
# Epoch 2/100
# 14/14 [==============================] - 0s 6ms/step - loss: 2.5745 - mean_absolute_error: 0.1894 - val_loss: 2.1706 - val_mean_absolute_error: 0.1639
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 2.0497 - mean_absolute_error: 0.1620 - val_loss: 1.7357 - val_mean_absolute_error: 0.1642
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.6484 - mean_absolute_error: 0.1608 - val_loss: 1.3766 - val_mean_absolute_error: 0.1529
# Epoch 5/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.3419 - mean_absolute_error: 0.1532 - val_loss: 1.1381 - val_mean_absolute_error: 0.1495
# Epoch 6/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1177 - mean_absolute_error: 0.1538 - val_loss: 0.9544 - val_mean_absolute_error: 0.1514
# Epoch 7/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.9814 - mean_absolute_error: 0.1689 - val_loss: 0.8319 - val_mean_absolute_error: 0.1752
# Epoch 8/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8352 - mean_absolute_error: 0.1589 - val_loss: 0.6939 - val_mean_absolute_error: 0.1416
# Epoch 9/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7378 - mean_absolute_error: 0.1490 - val_loss: 0.5995 - val_mean_absolute_error: 0.1445
# Epoch 10/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6533 - mean_absolute_error: 0.1420 - val_loss: 0.5333 - val_mean_absolute_error: 0.1365
# Epoch 11/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5938 - mean_absolute_error: 0.1596 - val_loss: 0.5241 - val_mean_absolute_error: 0.1542
# Epoch 12/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5604 - mean_absolute_error: 0.1440 - val_loss: 0.4471 - val_mean_absolute_error: 0.1350
# Epoch 13/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4927 - mean_absolute_error: 0.1438 - val_loss: 0.4165 - val_mean_absolute_error: 0.1353
# Epoch 14/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4611 - mean_absolute_error: 0.1351 - val_loss: 0.3816 - val_mean_absolute_error: 0.1228
# Epoch 15/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4227 - mean_absolute_error: 0.1343 - val_loss: 0.3570 - val_mean_absolute_error: 0.1310
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3937 - mean_absolute_error: 0.1266 - val_loss: 0.3340 - val_mean_absolute_error: 0.1260
# Epoch 17/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3697 - mean_absolute_error: 0.1305 - val_loss: 0.3118 - val_mean_absolute_error: 0.1175
# Epoch 18/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3696 - mean_absolute_error: 0.1258 - val_loss: 0.3286 - val_mean_absolute_error: 0.1389
# Epoch 19/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3212 - mean_absolute_error: 0.1304 - val_loss: 0.2779 - val_mean_absolute_error: 0.1136
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3166 - mean_absolute_error: 0.1193 - val_loss: 0.3000 - val_mean_absolute_error: 0.1359
# Epoch 21/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3015 - mean_absolute_error: 0.1292 - val_loss: 0.2591 - val_mean_absolute_error: 0.1109
# Epoch 22/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2827 - mean_absolute_error: 0.1154 - val_loss: 0.2518 - val_mean_absolute_error: 0.1232
# Epoch 23/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2942 - mean_absolute_error: 0.1365 - val_loss: 0.2399 - val_mean_absolute_error: 0.1177
# Epoch 24/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2654 - mean_absolute_error: 0.1234 - val_loss: 0.2300 - val_mean_absolute_error: 0.1126
# Epoch 25/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2438 - mean_absolute_error: 0.1117 - val_loss: 0.2280 - val_mean_absolute_error: 0.1130
# Epoch 26/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2310 - mean_absolute_error: 0.1103 - val_loss: 0.2102 - val_mean_absolute_error: 0.1039
# Epoch 27/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2255 - mean_absolute_error: 0.1087 - val_loss: 0.2172 - val_mean_absolute_error: 0.1179
# Epoch 28/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2197 - mean_absolute_error: 0.1116 - val_loss: 0.2001 - val_mean_absolute_error: 0.1067
# Epoch 29/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2047 - mean_absolute_error: 0.1084 - val_loss: 0.1893 - val_mean_absolute_error: 0.1032
# Epoch 30/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1970 - mean_absolute_error: 0.1028 - val_loss: 0.1847 - val_mean_absolute_error: 0.1060
# Epoch 31/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1870 - mean_absolute_error: 0.1003 - val_loss: 0.1762 - val_mean_absolute_error: 0.1040
# Epoch 32/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1839 - mean_absolute_error: 0.1028 - val_loss: 0.1699 - val_mean_absolute_error: 0.0968
# Epoch 33/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1767 - mean_absolute_error: 0.1014 - val_loss: 0.1681 - val_mean_absolute_error: 0.1058
# Epoch 34/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1698 - mean_absolute_error: 0.1001 - val_loss: 0.1611 - val_mean_absolute_error: 0.1025
# Epoch 35/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1623 - mean_absolute_error: 0.1006 - val_loss: 0.1538 - val_mean_absolute_error: 0.0977
# Epoch 36/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1594 - mean_absolute_error: 0.0975 - val_loss: 0.1500 - val_mean_absolute_error: 0.1008
# Epoch 37/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1527 - mean_absolute_error: 0.0972 - val_loss: 0.1440 - val_mean_absolute_error: 0.0940
# Epoch 38/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1488 - mean_absolute_error: 0.0966 - val_loss: 0.1412 - val_mean_absolute_error: 0.0942
# Epoch 39/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1432 - mean_absolute_error: 0.0955 - val_loss: 0.1382 - val_mean_absolute_error: 0.1017
# Epoch 40/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1394 - mean_absolute_error: 0.0981 - val_loss: 0.1358 - val_mean_absolute_error: 0.1018
# Epoch 41/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1387 - mean_absolute_error: 0.1019 - val_loss: 0.1314 - val_mean_absolute_error: 0.0985
# Epoch 42/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1333 - mean_absolute_error: 0.0973 - val_loss: 0.1318 - val_mean_absolute_error: 0.1091
# Epoch 43/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1280 - mean_absolute_error: 0.0960 - val_loss: 0.1225 - val_mean_absolute_error: 0.0968
# Epoch 44/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1236 - mean_absolute_error: 0.0935 - val_loss: 0.1231 - val_mean_absolute_error: 0.1001
# Epoch 45/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1224 - mean_absolute_error: 0.0934 - val_loss: 0.1226 - val_mean_absolute_error: 0.1005
# Epoch 46/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1208 - mean_absolute_error: 0.0960 - val_loss: 0.1147 - val_mean_absolute_error: 0.0982
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1140 - mean_absolute_error: 0.0928 - val_loss: 0.1094 - val_mean_absolute_error: 0.0904
# Epoch 48/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1108 - mean_absolute_error: 0.0884 - val_loss: 0.1098 - val_mean_absolute_error: 0.0951
# Epoch 49/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1091 - mean_absolute_error: 0.0893 - val_loss: 0.1094 - val_mean_absolute_error: 0.0984
# Epoch 50/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1086 - mean_absolute_error: 0.0921 - val_loss: 0.1046 - val_mean_absolute_error: 0.0947
# Epoch 51/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1077 - mean_absolute_error: 0.0972 - val_loss: 0.1050 - val_mean_absolute_error: 0.0964
# Epoch 52/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1115 - mean_absolute_error: 0.1035 - val_loss: 0.1054 - val_mean_absolute_error: 0.0996
# Epoch 53/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1052 - mean_absolute_error: 0.0981 - val_loss: 0.0976 - val_mean_absolute_error: 0.0951
# Epoch 54/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1021 - mean_absolute_error: 0.0926 - val_loss: 0.0993 - val_mean_absolute_error: 0.1006
# Epoch 55/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0967 - mean_absolute_error: 0.0900 - val_loss: 0.0949 - val_mean_absolute_error: 0.0951
# Epoch 56/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0952 - mean_absolute_error: 0.0904 - val_loss: 0.0899 - val_mean_absolute_error: 0.0883
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0907 - mean_absolute_error: 0.0856 - val_loss: 0.0886 - val_mean_absolute_error: 0.0890
# Epoch 58/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0912 - mean_absolute_error: 0.0914 - val_loss: 0.0895 - val_mean_absolute_error: 0.0962
# Epoch 59/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0885 - mean_absolute_error: 0.0918 - val_loss: 0.0867 - val_mean_absolute_error: 0.0961
# Epoch 60/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0859 - mean_absolute_error: 0.0884 - val_loss: 0.0859 - val_mean_absolute_error: 0.0926
# Epoch 61/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0860 - mean_absolute_error: 0.0886 - val_loss: 0.0857 - val_mean_absolute_error: 0.0926
# Epoch 62/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0823 - mean_absolute_error: 0.0870 - val_loss: 0.0803 - val_mean_absolute_error: 0.0893
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0803 - mean_absolute_error: 0.0861 - val_loss: 0.0790 - val_mean_absolute_error: 0.0893
# Epoch 64/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0768 - mean_absolute_error: 0.0830 - val_loss: 0.0753 - val_mean_absolute_error: 0.0859
# Epoch 65/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0769 - mean_absolute_error: 0.0875 - val_loss: 0.0803 - val_mean_absolute_error: 0.0980
# Epoch 66/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0754 - mean_absolute_error: 0.0900 - val_loss: 0.0723 - val_mean_absolute_error: 0.0870
# Epoch 67/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0722 - mean_absolute_error: 0.0862 - val_loss: 0.0699 - val_mean_absolute_error: 0.0866
# Epoch 68/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0698 - mean_absolute_error: 0.0811 - val_loss: 0.0713 - val_mean_absolute_error: 0.0918
# Epoch 69/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0691 - mean_absolute_error: 0.0842 - val_loss: 0.0668 - val_mean_absolute_error: 0.0795
# Epoch 70/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0672 - mean_absolute_error: 0.0793 - val_loss: 0.0695 - val_mean_absolute_error: 0.0966
# Epoch 71/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0693 - mean_absolute_error: 0.0881 - val_loss: 0.0708 - val_mean_absolute_error: 0.0949
# Epoch 72/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0718 - mean_absolute_error: 0.0940 - val_loss: 0.0660 - val_mean_absolute_error: 0.0856
# Epoch 73/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0664 - mean_absolute_error: 0.0862 - val_loss: 0.0638 - val_mean_absolute_error: 0.0875
# Epoch 74/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0643 - mean_absolute_error: 0.0862 - val_loss: 0.0637 - val_mean_absolute_error: 0.0917
# Epoch 75/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0622 - mean_absolute_error: 0.0824 - val_loss: 0.0604 - val_mean_absolute_error: 0.0857
# Epoch 76/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0605 - mean_absolute_error: 0.0806 - val_loss: 0.0607 - val_mean_absolute_error: 0.0853
# Epoch 77/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0594 - mean_absolute_error: 0.0792 - val_loss: 0.0608 - val_mean_absolute_error: 0.0854
# Epoch 78/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0597 - mean_absolute_error: 0.0849 - val_loss: 0.0582 - val_mean_absolute_error: 0.0877
# Epoch 79/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0577 - mean_absolute_error: 0.0803 - val_loss: 0.0573 - val_mean_absolute_error: 0.0836
# Epoch 80/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0573 - mean_absolute_error: 0.0806 - val_loss: 0.0577 - val_mean_absolute_error: 0.0890
# Epoch 81/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0600 - mean_absolute_error: 0.0861 - val_loss: 0.0600 - val_mean_absolute_error: 0.0895
# Epoch 82/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0581 - mean_absolute_error: 0.0861 - val_loss: 0.0563 - val_mean_absolute_error: 0.0885
# Epoch 83/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0545 - mean_absolute_error: 0.0798 - val_loss: 0.0544 - val_mean_absolute_error: 0.0865
# Epoch 84/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0542 - mean_absolute_error: 0.0789 - val_loss: 0.0534 - val_mean_absolute_error: 0.0805
# Epoch 85/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0535 - mean_absolute_error: 0.0787 - val_loss: 0.0526 - val_mean_absolute_error: 0.0799
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0523 - mean_absolute_error: 0.0785 - val_loss: 0.0523 - val_mean_absolute_error: 0.0853
# Epoch 87/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0521 - mean_absolute_error: 0.0810 - val_loss: 0.0514 - val_mean_absolute_error: 0.0813
# Epoch 88/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0511 - mean_absolute_error: 0.0794 - val_loss: 0.0556 - val_mean_absolute_error: 0.0990
# Epoch 89/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0577 - mean_absolute_error: 0.0910 - val_loss: 0.0575 - val_mean_absolute_error: 0.0938
# Epoch 90/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0530 - mean_absolute_error: 0.0840 - val_loss: 0.0581 - val_mean_absolute_error: 0.0886
# Epoch 91/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0568 - mean_absolute_error: 0.0884 - val_loss: 0.0596 - val_mean_absolute_error: 0.0951
# Epoch 92/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0552 - mean_absolute_error: 0.0890 - val_loss: 0.0550 - val_mean_absolute_error: 0.1041
# Epoch 93/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0500 - mean_absolute_error: 0.0838 - val_loss: 0.0495 - val_mean_absolute_error: 0.0847
# Epoch 94/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0487 - mean_absolute_error: 0.0825 - val_loss: 0.0503 - val_mean_absolute_error: 0.0920
# Epoch 95/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0482 - mean_absolute_error: 0.0825 - val_loss: 0.0474 - val_mean_absolute_error: 0.0845
# Epoch 96/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0461 - mean_absolute_error: 0.0759 - val_loss: 0.0473 - val_mean_absolute_error: 0.0855
# Epoch 97/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0454 - mean_absolute_error: 0.0773 - val_loss: 0.0455 - val_mean_absolute_error: 0.0808
# Epoch 98/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0448 - mean_absolute_error: 0.0756 - val_loss: 0.0447 - val_mean_absolute_error: 0.0777
# Epoch 99/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0441 - mean_absolute_error: 0.0728 - val_loss: 0.0451 - val_mean_absolute_error: 0.0835
# Epoch 100/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0447 - mean_absolute_error: 0.0798 - val_loss: 0.0429 - val_mean_absolute_error: 0.0739

# %% [markdown]
# ---
# #### Evaluasi

# %%
loss3 = model3.evaluate(X_test, y_test)
print(loss3)
# Out:
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0429 - mean_absolute_error: 0.0739
# [0.04290756210684776, 0.07387900352478027]

# %%
y_pred3 = model3.predict(X_test)
print(f"R-squared: {np.round(r2_score(y_test, y_pred3),2)*100}%")
print("MAE: ", mean_absolute_error(y_test, y_pred3))
print("MSE: ", mean_squared_error(y_test, y_pred3))
# Out:
# 13/13 [==============================] - 0s 2ms/step
# R-squared: 99.0%
# MAE:  0.07387899012123317
# MSE:  0.011371096831867995

# %%
# let's see the training and validation accuracy by epoch
history_dict = history2.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Terlihat model memberikan akurasi yang baik.

# %%
# Visualisasi
y_test_reverse = y_scaler.inverse_transform(y_test)
y_pred_reverse = y_scaler.inverse_transform(y_pred3)

ax = sns.regplot(x=y_test_reverse, y=y_pred_reverse, line_kws={"color": "red"})
plt.title("Predicted vs True Motorcycle Price\n", weight='bold')
plt.xlabel("True Price (in Rp million)")
plt.ylabel("Predicted Price (in Rp million)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### Save model
# Model yang dengan akurasi tertinggi akan disimpan untuk di <i> deploy </i>

# %%
import pickle

pickle.dump(model3, open('../nn_model.pkl','wb'))
pickle.dump(X_scaler, open('../X_scaler.pkl', 'wb'))
pickle.dump(y_scaler, open('../y_scaler.pkl', 'wb'))

# %%
# Tes prediksi

model = pickle.load(open('../nn_model.pkl','rb'))
new_data = X_test[10]
new_data = np.array(new_data).reshape(1,-1)
pred = model.predict([new_data]) #lokasi, kapasitas_mesin, tahun, transmisi, kilometer, merk
pred = y_scaler.inverse_transform(pred)
print(pred)
# Out:
# 1/1 [==============================] - 0s 58ms/step
# [[11173699.]]

# %%
# Export dataset
resampled_motor.to_csv('../Dataset/Dataset_Training.csv')
