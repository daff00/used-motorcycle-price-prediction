# %% [markdown]
# # Deep Learning Neural Network Model for Used Motorcycle Price Prediction
# ## IS794 AL - Deep Learning (Lab)
# Kelompok B: <br>
# - Daffa Kaisha Pratama Chandra (00000055770)
# - Justine Donovan (00000063202)
# - Marsella Patricia (00000063226)
# - Reina Ratu Balqis (00000065099)
# ---
# ### Import Libraries

# %%
# Basic library
import pandas as pd
import numpy as np

# Pre-processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import plotly.express as px
from plotly.subplots import make_subplots

# Handling imbalanced class using RandomOverSampling
from imblearn.over_sampling import RandomOverSampler

# Feature selection dengan random forest regressor
from sklearn.ensemble import RandomForestRegressor

# Deep learning
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# Ignore warning
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ---
# Baca Dataset

# %%
yamaha = pd.read_csv("../Dataset/motor_yamaha_bekas.csv", engine='pyarrow')
honda = pd.read_csv("../Dataset/motor_honda_bekas.csv", engine='pyarrow')
kawasaki = pd.read_csv("../Dataset/motor_kawasaki_bekas.csv", engine='pyarrow')
suzuki = pd.read_csv("../Dataset/motor_suzuki_bekas.csv", engine='pyarrow')

# %% [markdown]
# Penjelasan singkat mengenai dataset yang digunakan: <br>
# Dataset motor bekas yang ada di Indonesia. Terdapat 10 kolom: <br>
# | Feature | Penjelasan |
# |----------|----------|
# | Nama motor| Nama motor yang ditampilkan pada website|
# | lokasi | Lokasi motor dijual |
# | harga | Harga motor dijual |
# | deskripsi | Deskripsi iklan motor |
# | kapasitas_mesin | Kapasitas mesin motor bekas yang dijual (dalam CC) |
# | tahun | Tahun pembuatan motor berkas |
# | transmisi | Jenis transmisi motor bekas yang dijual |
# | kilometer | Jarak tempuh motor bekas yang dijual |
# | url | URL motor pada website https://momotor.id/ |
# | merk | Merk pabrikan motor |
#
# Dataset ini merupakan hasil web scraping dari website https://momotor.id/

# %%
print("Shape dari tiap dataset:")
print(f"Dataset Yamaha memiliki {yamaha.shape[1]} kolom dan {yamaha.shape[0]} baris.")
print(f"Dataset Honda memiliki {honda.shape[1]} kolom dan {honda.shape[0]} baris.")
print(f"Dataset Kawasaki memiliki {kawasaki.shape[1]} kolom dan {kawasaki.shape[0]} baris.")
print(f"Dataset Suzuki memiliki {suzuki.shape[1]} kolom dan {suzuki.shape[0]} baris.")
# Out:
# Shape dari tiap dataset:
# Dataset Yamaha memiliki 10 kolom dan 493 baris.
# Dataset Honda memiliki 10 kolom dan 966 baris.
# Dataset Kawasaki memiliki 10 kolom dan 96 baris.
# Dataset Suzuki memiliki 10 kolom dan 23 baris.

# %%
print("Informasi singkat dari tiap dataset:\n")
print("Yamaha:")
print(yamaha.info())
print("\nHonda:")
print(honda.info())
print("\nKawasaki:")
print(kawasaki.info())
print("\nSuzuki:")
print(suzuki.info())
# Out:
# Informasi singkat dari tiap dataset:
#
# Yamaha:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       352 non-null    object
#  1   lokasi           352 non-null    object
#  2   harga            352 non-null    object
#  3   deskripsi        352 non-null    object
#  4   kapasitas_mesin  352 non-null    object
#  5   tahun            352 non-null    float64
#  6   transmisi        352 non-null    object
#  7   kilometer        352 non-null    object
#  8   url              493 non-null    object
#  9   merk             493 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 38.6+ KB
# None
#
# Honda:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       629 non-null    object
#  1   lokasi           629 non-null    object
#  2   harga            629 non-null    object
#  3   deskripsi        629 non-null    object
#  4   kapasitas_mesin  629 non-null    object
#  5   tahun            629 non-null    float64
#  6   transmisi        629 non-null    object
#  7   kilometer        629 non-null    object
#  8   url              966 non-null    object
#  9   merk             966 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 75.6+ KB
# None
#
# Kawasaki:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       48 non-null     object
#  1   lokasi           48 non-null     object
#  2   harga            48 non-null     object
#  3   deskripsi        48 non-null     object
#  4   kapasitas_mesin  48 non-null     object
#  5   tahun            48 non-null     float64
#  6   transmisi        48 non-null     object
#  7   kilometer        48 non-null     object
#  8   url              96 non-null     object
#  9   merk             96 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 7.6+ KB
# None
#
# Suzuki:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       14 non-null     object
#  1   lokasi           14 non-null     object
#  2   harga            14 non-null     object
#  3   deskripsi        14 non-null     object
#  4   kapasitas_mesin  14 non-null     object
#  5   tahun            14 non-null     float64
#  6   transmisi        14 non-null     object
#  7   kilometer        14 non-null     object
#  8   url              23 non-null     object
#  9   merk             23 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 1.9+ KB
# None

# %% [markdown]
# Pre-processing: Data mentah -> Data siap pakai <br>
# Akan dilakukan cek <i> missing values. </i> Jika terdapat <i> missing values, </i> data yang hilang akan diimputasi menggunakan nilai modus.

# %%
# Cek rata-rata missing values pada tiap dataset
brand = ['Yamaha', 'Honda', 'Kawasaki', 'Suzuki']
data = [yamaha, honda, kawasaki, suzuki]

for i, j in zip(brand, data):
    print(f"{i} missing values: \n{np.round(honda.isnull().mean(), 2)*100}")
    print()
# Out:
# Yamaha missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Honda missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Kawasaki missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Suzuki missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64

# %%
# cari modus dari tiap kolom yang terdapat missing values
kolom_null = ['nama_motor', 'lokasi', 'harga', 'deskripsi', 
              'kapasitas_mesin', 'tahun', 'transmisi', 'kilometer']

# %%
# Cari modus dan replace NaN dengan modus
for col in kolom_null:
    # Yamaha
    modus_yamaha = yamaha[col].value_counts().nlargest(3)
    # Honda
    modus_honda = yamaha[col].value_counts().nlargest(3)
    # Kawasaki
    modus_kawasaki = yamaha[col].value_counts().nlargest(3)
    # Suzuki
    modus_suzuki = yamaha[col].value_counts().nlargest(3)
    
    # Check if the mode values exist
    if len(modus_yamaha) >= 2:
        # Extract the mode strings
        modus_ymh1 = modus_yamaha.index[0]
        modus_ymh2 = modus_yamaha.index[1]

        # Define a list of possible string values between the modes
        possible_values_ymh = [modus_ymh1, modus_ymh2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        yamaha[col] = yamaha[col].apply(lambda x: np.random.choice(possible_values_ymh) if pd.isna(x) else x)

    if len(modus_honda) >= 2:
        # Extract the mode strings
        modus_hnd1 = modus_honda.index[0]
        modus_hnd2 = modus_honda.index[1]

        # Define a list of possible string values between the modes
        possible_values_hnd = [modus_hnd1, modus_hnd2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        honda[col] = honda[col].apply(lambda x: np.random.choice(possible_values_hnd) if pd.isna(x) else x)

    if len(modus_kawasaki) >= 2:
        # Extract the mode strings
        modus_kws1 = modus_kawasaki.index[0]
        modus_kws2 = modus_kawasaki.index[1]

        # Define a list of possible string values between the modes
        possible_values_kws = [modus_kws1, modus_kws2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        kawasaki[col] = kawasaki[col].apply(lambda x: np.random.choice(possible_values_kws) if pd.isna(x) else x)

    if len(modus_suzuki) >= 2:
        # Extract the mode strings
        modus_szk1 = modus_suzuki.index[0]
        modus_szk2 = modus_suzuki.index[1]

        # Define a list of possible string values between the modes
        possible_values_szk = [modus_szk1, modus_szk2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        suzuki[col] = suzuki[col].apply(lambda x: np.random.choice(possible_values_szk) if pd.isna(x) else x)

# %%
# Cek missing values lagi
for i, j in zip(brand, data):
    print(f"{i} missing values: \n{np.round(j.isnull().mean(), 2)*100}")
    print()
# Out:
# Yamaha missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Honda missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Kawasaki missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Suzuki missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64

# %%
# Merge dataset
used_motor = pd.concat([yamaha, honda, kawasaki, suzuki])
print("Shape dari dataset yang digabung: ", used_motor.shape)
# Out:
# Shape dari dataset yang digabung:  (1578, 10)

# %% [markdown]
# ---
# #### Data Pre-processing
# Pada tahap ini, akan dilakukan:
# - Drop kolom yang tidak digunakan
# - Oversampling Data yang sedikit dengan Random Oversampling
# - Membersihkan kolom harga
# - Membersihkan kolom kapasitas mesin

# %% [markdown]
# ##### Drop variabel yang tidak dibutuhkan

# %%
used_motor = used_motor.drop(columns=['deskripsi', 'url'])
used_motor.head()
# Out:
#              nama_motor              lokasi         harga kapasitas_mesin  \
# 0  Yamaha Aerox 155 Vva      Kab. Tangerang  Rp24,500,000          155 CC
# 1  Yamaha Aerox 155 Vva      Kab. Tangerang  Rp24,500,000          155 CC
# 2  Yamaha Aerox 155 Vva      Kab. Tangerang  Rp23,500,000          125 CC
# 3  Yamaha Aerox 155 Vva  Kota Jakarta Barat  Rp24,500,000          125 CC
# 4  Yamaha Aerox 155 Vva  Kota Jakarta Barat  Rp23,500,000          125 CC
#
#     tahun transmisi        kilometer    merk
# 0  2018.0  Otomatis        >30000 KM  Yamaha
# 1  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 2  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 3  2018.0    Manual        >30000 KM  Yamaha
# 4  2019.0  Otomatis        >30000 KM  Yamaha

# %%
# Lihat nilai unik dari setiap kolom
kolom = used_motor.columns

for i in kolom:
    print(f"Nilai unik dari kolom {i}:")
    print(used_motor[i].value_counts())
    print()
# Out:
# Nilai unik dari kolom nama_motor:
# nama_motor
# Yamaha Nmax Abs                  336
# Yamaha Aerox 155 Vva             296
# Honda Beat Cbs Fi                 41
# Honda Vario 150 Esp Exclusive     38
# Honda New Beat Street Esp         35
#                                 ...
# Honda GENIO CBS                    1
# Honda Supra X 125 Cw               1
# Honda New Revo Fi Cw               1
# Honda Beat Fisporty Cw Esp         1
# Suzuki Satria Fu 150 Mfx           1
# Name: count, Length: 154, dtype: int64
#
# Nilai unik dari kolom lokasi:
# lokasi
# Kota Jakarta Barat        490
# Kab. Tangerang            419
# Kota Jakarta Selatan      204
# Kota Bandung              180
# Kota Jakarta Timur         91
# Kab. Bogor                 46
# Kota Jakarta Utara         43
# Kota Medan                 30
# Kota Tangerang             21
# Kab. Bandung               20
# Kota  Batam                10
# Kota Tangerang Selatan      8
# Kota Bekasi                 6
# Kota Depok                  5
# Kota Surabaya               3
# Kab. Deli Serdang           2
# Name: count, dtype: int64
#
# Nilai unik dari kolom harga:
# harga
# Rp23,500,000    296
# Rp24,500,000    286
# Rp16,500,000     40
# Rp17,500,000     30
# Rp21,500,000     28
#                ...
# Rp25,250,000      1
# Rp11,300,000      1
# Rp36,800,000      1
# Rp24,250,000      1
# Rp31,100,000      1
# Name: count, Length: 261, dtype: int64
#
# Nilai unik dari kolom kapasitas_mesin:
# kapasitas_mesin
# 155 CC           431
# 125 CC           410
# 110 CC           281
# 150 CC           183
# 150cc CC          58
# 110cc CC          47
# 155cc CC          41
# 125cc CC          40
# 250 CC            29
# -                 12
# 115cc CC           8
# 250cc CC           8
# 160 CC             6
# 175 CC             5
# 900 CC             2
# 125 cc CC          2
# 115 CC             1
# 600 CC             1
# 113cc CC           1
# 175cc CC           1
# 250Cc CC           1
#  CC                1
# 1550 CC            1
# 11pcc CC           1
# 249 CC             1
# 125CC CC           1
# 156cc CC           1
# 250  CC            1
# 156 CC             1
# 220 CC             1
# DSE4202201 CC      1
# Name: count, dtype: int64
#
# Nilai unik dari kolom tahun:
# tahun
# 2018.0    497
# 2019.0    479
# 2021.0    180
# 2020.0    126
# 2017.0    125
# 2016.0     75
# 2015.0     54
# 2022.0     42
# Name: count, dtype: int64
#
# Nilai unik dari kolom transmisi:
# transmisi
# Otomatis    1149
# Manual       429
# Name: count, dtype: int64
#
# Nilai unik dari kolom kilometer:
# kilometer
# 10000 - 20000KM    661
# >30000 KM          530
# 1000 - 5000 KM     243
# 5000 - 10000KM     129
# 0 - 1000 KM         15
# Name: count, dtype: int64
#
# Nilai unik dari kolom merk:
# merk
# Honda       966
# Yamaha      493
# Kawasaki     96
# Suzuki       23
# Name: count, dtype: int64

# %% [markdown]
# Kolom kapasitas mesin dan harga belum dalam format yang benar

# %% [markdown]
# Random Oversampling

# %%
# Lihat persebaran tiap merk motor
print("Merk Motor:\n",used_motor['merk'].value_counts())
# Out:
# Merk Motor:
#  merk
# Honda       966
# Yamaha      493
# Kawasaki     96
# Suzuki       23
# Name: count, dtype: int64

# %% [markdown]
# Persebaran tiap merk motor tidak merata. Maka akan dilakukan Random Oversampling untuk mengatasi persebaran merk motor yang tidak merata. Akan dilakukan oversampling pada merk motor yang jumlahnya kurang dari merk Honda.

# %%
# Inisialisasi merk yang akan dilakukan random oversampling.
class_cnt = [966, 493, 96, 23]

minor_class = ['Yamaha', 'Kawasaki', 'Suzuki']

class_mapping = {'Honda': 0, 'Yamaha': 1, 'Kawasaki': 2, 'Suzuki': 3}
used_motor['ClassEncoded'] = used_motor['merk'].map(class_mapping)

# %%
# Set strategi oversampling
sampling_strategy = {
    0: class_cnt[0],  # Tidak dilakukan oversampling untuk Honda
    1: class_cnt[0],  # Oversample Yamaha agar balance dengan Honda
    2: class_cnt[0],  # Oversample Kawasaki agar balance dengan Honda
    3: class_cnt[0]   # Oversample Suzuki agar balance dengan Honda
}

# Inisialisasi RandomOverSampler dengan strategi yang telah ditetapkan
ros = RandomOverSampler(sampling_strategy=sampling_strategy, random_state=42)

# Extract features dan labels
X = used_motor.drop(['merk', 'ClassEncoded'], axis=1)
y = used_motor['ClassEncoded']

# Fit transform data
X_resampled, y_resampled = ros.fit_resample(X, y)

# Merge data
resampled_motor = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='ClassEncoded')], axis=1)

# Mapping hasil encoding ke nilai sebenarnya
resampled_motor['merk'] = resampled_motor['ClassEncoded'].map({v: k for k, v in class_mapping.items()})

# Drop temporary 'ClassEncoded' column
resampled_motor = resampled_motor.drop('ClassEncoded', axis=1)

# Print hasil
print(resampled_motor['merk'].value_counts())
# Out:
# merk
# Yamaha      966
# Honda       966
# Kawasaki    966
# Suzuki      966
# Name: count, dtype: int64

# %% [markdown]
# ##### Membersihkan kolom harga

# %%
def clean_harga(harga):
    harga_clean = harga.replace("Rp", "").replace(".", "").replace(",", "")
    return harga_clean

# Bersihkan kolom harga
resampled_motor['harga'] = resampled_motor['harga'].apply(clean_harga)
resampled_motor['harga'] = resampled_motor['harga'].astype("float")

# %% [markdown]
# ##### Membersihkan kolom kapasitas mesin

# %%
def clean_cc(kapasitas_mesin):
    cc_clean = kapasitas_mesin.replace("cc", "")
    cc_clean2 = cc_clean.replace(" CC", "")
    cc_clean3 = cc_clean2.replace("Cc", "")
    cc_clean4 = cc_clean3.replace("CC", "")
    cc_clean5 = cc_clean4.replace("p", "")
    return cc_clean5

# Bersihkan kolom kapasitas mesin
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].apply(clean_cc)
resampled_motor = resampled_motor[resampled_motor['kapasitas_mesin'] != 'DSE4202201']
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(['-', ''], 150)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].astype('int')
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(1550, 150)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(11, 110)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(113, 115)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(156, 155)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(249, 250)
print(resampled_motor['kapasitas_mesin'].unique())
# Out:
# [155 125 220 150 250 110 115 160 900 175 600]

# %% [markdown]
# ---
# #### Exploratory Data Analysis <br>
# Pada tahap EDA, akan dilakukan beberapa tahapan untuk menemukan pola pada data dengan menggunakan statistik dan visualisasi data. Beberapa tahapan yang akan dilakukan sebagai berikut:
# - Melihat informasi data
# - Melihat nilai unik tiap kolom
# - Melihat statistika dasar
# - Visualisasi data

# %%
# Melihat informasi dataset
resampled_motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3857 entries, 0 to 3863
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       3857 non-null   object
#  1   lokasi           3857 non-null   object
#  2   harga            3857 non-null   float64
#  3   kapasitas_mesin  3857 non-null   int32
#  4   tahun            3857 non-null   float64
#  5   transmisi        3857 non-null   object
#  6   kilometer        3857 non-null   object
#  7   merk             3857 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 256.1+ KB

# %%
# Loop melalui tiap kolom dan mencetak nilai unik
unique_value_count ={}
for column in resampled_motor.columns : 
    unique_values = resampled_motor[column].unique()
    unique_count = len(unique_values)
    unique_value_count[column] = unique_count

for column, count in unique_value_count.items():
    print(f"{column} : {count}")
# Out:
# nama_motor : 153
# lokasi : 16
# harga : 260
# kapasitas_mesin : 11
# tahun : 8
# transmisi : 2
# kilometer : 5
# merk : 4

# %%
# Melihat Statistika data numerik
resampled_motor.describe()
# Out:
#               harga  kapasitas_mesin        tahun
# count  3.857000e+03      3857.000000  3857.000000
# mean   2.515601e+07       152.019704  2018.409386
# std    2.473170e+07        62.017675     1.505400
# min    8.550000e+06       110.000000  2015.000000
# 25%    1.850000e+07       125.000000  2018.000000
# 50%    2.350000e+07       150.000000  2018.000000
# 75%    2.450000e+07       155.000000  2019.000000
# max    3.650000e+08       900.000000  2022.000000

# %%
# Melihat Statistika data kategorikal
resampled_motor.describe(exclude=np.number)
# Out:
#              nama_motor              lokasi transmisi        kilometer    merk
# count              3857                3857      3857             3857    3857
# unique              153                  16         2                5       4
# top     Yamaha Nmax Abs  Kota Jakarta Barat  Otomatis  10000 - 20000KM  Yamaha
# freq               1016                1355      2188             1509     966

# %%
# Visualisasi distribusi harga motor semua merk
sns.histplot(resampled_motor['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %% [markdown]
# Terdapat outliers yang cukup banyak pada data. Outliers pada data ini tidak dibersihkan agar model mampu membuat prediksi pada data-data yang belum pernah dilihat sebelumnya.

# %%
# Visualisasi distribusi harga tiap merk motor
# Subplot
fig = make_subplots(rows=2, cols=2, subplot_titles=['Honda', 'Yamaha', 'Kawasaki', 'Suzuki'])

# Plot for Honda Turbo aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Honda'], x='harga', nbins=30, color_discrete_sequence=['#ca91eb']).update_traces(histnorm='probability').data[0], row=1, col=1)

# Plot for Yamaha Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Yamaha'], x='harga', nbins=30, color_discrete_sequence=['#eb6426']).update_traces(histnorm='probability').data[0], row=1, col=2)

# Plot for Kawasaki Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Kawasaki'], x='harga', nbins=30, color_discrete_sequence=['#91caeb']).update_traces(histnorm='probability').data[0], row=2, col=1)

# Plot for Suzuki Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Suzuki'], x='harga', nbins=30, color_discrete_sequence=['#265aeb']).update_traces(histnorm='probability').data[0], row=2, col=2)

# Update layout
fig.update_layout(showlegend=False, title_text="Distribusi Harga Tiap Merk Motor")

# Show the plot
fig.show()

# %% [markdown]
# Distribusi harga motor Honda, Yamaha, dan Suzuki berada pada rentang harga 10 - 100 juta Rupiah. Sedangkan, harga motor Kawasaki berada pada rentang harga 10 - 350 juta rupiah.

# %%
# Visualisasi Rata-Rata Harga Motor
hargapermerk = resampled_motor.groupby("merk")["harga"].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x="merk", y="harga", data=hargapermerk, order=hargapermerk.sort_values('harga', ascending=False)['merk'])
plt.title("Rata-rata Harga Motor Berdasarkan Merk")
plt.xlabel("Merk Motor")
plt.ylabel("Harga Motor")
plt.show()

# %% [markdown]
# Dari visualisasi, terlihat rata-rata harga paling mahal adalah merk motor Kawasaki

# %% [markdown]
# ### Data Preparation

# %%
resampled_motor.head()
# Out:
#              nama_motor              lokasi       harga  kapasitas_mesin  \
# 0  Yamaha Aerox 155 Vva      Kab. Tangerang  24500000.0              155
# 1  Yamaha Aerox 155 Vva      Kab. Tangerang  24500000.0              155
# 2  Yamaha Aerox 155 Vva      Kab. Tangerang  23500000.0              125
# 3  Yamaha Aerox 155 Vva  Kota Jakarta Barat  24500000.0              125
# 4  Yamaha Aerox 155 Vva  Kota Jakarta Barat  23500000.0              125
#
#     tahun transmisi        kilometer    merk
# 0  2018.0  Otomatis        >30000 KM  Yamaha
# 1  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 2  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 3  2018.0    Manual        >30000 KM  Yamaha
# 4  2019.0  Otomatis        >30000 KM  Yamaha

# %%
resampled_motor.tail()
# Out:
#                       nama_motor              lokasi       harga  \
# 3859             Suzuki Gsx R150          Kab. Bogor  15500000.0
# 3860        Yamaha Aerox 155 Vva  Kota Jakarta Barat  23500000.0
# 3861             Suzuki Gsx R150          Kota Medan  16900000.0
# 3862  Suzuki Satria F150 Fighter  Kota Jakarta Barat   9850000.0
# 3863  Suzuki Satria F150 Fighter  Kota Jakarta Barat   9850000.0
#
#       kapasitas_mesin   tahun transmisi       kilometer    merk
# 3859              150  2017.0    Manual  5000 - 10000KM  Suzuki
# 3860              155  2018.0  Otomatis       >30000 KM  Suzuki
# 3861              150  2017.0    Manual       >30000 KM  Suzuki
# 3862              150  2015.0    Manual       >30000 KM  Suzuki
# 3863              150  2015.0    Manual       >30000 KM  Suzuki

# %%
resampled_motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3857 entries, 0 to 3863
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       3857 non-null   object
#  1   lokasi           3857 non-null   object
#  2   harga            3857 non-null   float64
#  3   kapasitas_mesin  3857 non-null   int32
#  4   tahun            3857 non-null   float64
#  5   transmisi        3857 non-null   object
#  6   kilometer        3857 non-null   object
#  7   merk             3857 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 256.1+ KB

# %% [markdown]
# ##### Encoding

# %%
# Encoding Manual
# Kolom merk
resampled_motor['merk'] = resampled_motor['merk'].replace({'Yamaha' : 1, 
                                                           'Honda' : 2, 
                                                           'Kawasaki' : 3, 
                                                           'Suzuki' : 4})

# Kolom transmisi
resampled_motor['transmisi'] = resampled_motor['merk'].replace({'Manual' : 1, 
                                                                'Otomatis' : 2})

# Kolom kilometer
resampled_motor['kilometer'] = resampled_motor['kilometer'].replace({'>30000 KM' : 5, 
                                                                     '10000 - 20000KM' : 4,
                                                                     '1000 - 5000 KM' : 3, 
                                                                     '5000 - 10000KM' : 2,
                                                                     '0 - 1000 KM' : 1})

# Kolom lokasi
resampled_motor['lokasi'] = resampled_motor['lokasi'].replace({'Kota Jakarta Barat' : 1,
                                                               'Kab. Tangerang' : 2,
                                                               'Kota Jakarta Selatan' : 3,
                                                               'Kota Bandung' : 4,
                                                               'Kota Jakarta Timur' : 5,
                                                               'Kab. Bogor' : 6,
                                                               'Kota Jakarta Utara' : 7,
                                                               'Kota Medan' : 8,
                                                               'Kota Tangerang' : 9,
                                                               'Kab. Bandung' : 10,
                                                               'Kota  Batam' : 11,
                                                               'Kota Tangerang Selatan' : 12,
                                                               'Kota Bekasi' : 13,
                                                               'Kota Depok' : 14,
                                                               'Kota Surabaya' : 15,
                                                               'Kab. Deli Serdang' : 16
                                                               })

# %%
# Lihat data setelah di encoding
resampled_motor.head()
# Out:
#              nama_motor  lokasi       harga  kapasitas_mesin   tahun  \
# 0  Yamaha Aerox 155 Vva       2  24500000.0              155  2018.0
# 1  Yamaha Aerox 155 Vva       2  24500000.0              155  2018.0
# 2  Yamaha Aerox 155 Vva       2  23500000.0              125  2018.0
# 3  Yamaha Aerox 155 Vva       1  24500000.0              125  2018.0
# 4  Yamaha Aerox 155 Vva       1  23500000.0              125  2019.0
#
#    transmisi  kilometer  merk
# 0          1          5     1
# 1          1          4     1
# 2          1          4     1
# 3          1          5     1
# 4          1          5     1

# %% [markdown]
# ##### MinMax Scaler

# %% [markdown]
# ##### Feature Selection

# %%
# Memilih X dan y
X = resampled_motor.drop(columns=['harga', 'nama_motor'])
y = resampled_motor['harga']

# %%
# Train test split untuk feature importance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Random forest regressor untuk memilih feature importance
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_fi = rf.feature_importances_

# Define Nama columns
feature_names = X.columns.tolist()

plt.figure(figsize=(10, 6))

# Plotting feature importances
plt.barh(feature_names, rf_fi)
plt.xlabel('Feature Names')
plt.ylabel('Importance')
plt.title('Visualisasi Feature Importance')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---
# #### Modeling
# Pada tahap modeling, akan dilakukan:
# - Seleksi fitur
# - Membangun model RNN
# - Tuning hyperparameter
#
# Seleksi fitur

# %%
# Memilih X and y
X = resampled_motor.drop(columns=['harga', 'nama_motor', 'transmisi'])
y = resampled_motor['harga'].values.reshape(-1,1)

# Standarize
X_scaler = StandardScaler().fit(X)
y_scaler = StandardScaler().fit(y)
X_scaled = X_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y)

# %%
# Train test split untuk modeling Deep Neural Network
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.1, random_state=42)

# %% [markdown]
# Modeling
# - Tanpa tuning hyperparameter

# %%
# DNN model
model = Sequential()
model.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 13249 (51.75 KB)
# Trainable params: 13249 (51.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history1 = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 20ms/step - loss: 2.2377 - mean_absolute_error: 0.3115 - val_loss: 1.9337 - val_mean_absolute_error: 0.2572
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.6866 - mean_absolute_error: 0.2421 - val_loss: 1.4285 - val_mean_absolute_error: 0.1855
# Epoch 3/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.3636 - mean_absolute_error: 0.2161 - val_loss: 1.2048 - val_mean_absolute_error: 0.1657
# Epoch 4/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1943 - mean_absolute_error: 0.1915 - val_loss: 1.0552 - val_mean_absolute_error: 0.1629
# Epoch 5/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1113 - mean_absolute_error: 0.1817 - val_loss: 0.9756 - val_mean_absolute_error: 0.1672
# Epoch 6/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.9449 - mean_absolute_error: 0.1767 - val_loss: 0.8330 - val_mean_absolute_error: 0.1577
# Epoch 7/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8332 - mean_absolute_error: 0.1687 - val_loss: 0.7490 - val_mean_absolute_error: 0.1520
# Epoch 8/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8009 - mean_absolute_error: 0.1691 - val_loss: 0.6904 - val_mean_absolute_error: 0.1518
# Epoch 9/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7452 - mean_absolute_error: 0.1681 - val_loss: 0.6275 - val_mean_absolute_error: 0.1514
# Epoch 10/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6778 - mean_absolute_error: 0.1673 - val_loss: 0.5659 - val_mean_absolute_error: 0.1417
# Epoch 11/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5542 - mean_absolute_error: 0.1541 - val_loss: 0.5144 - val_mean_absolute_error: 0.1408
# Epoch 12/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5282 - mean_absolute_error: 0.1568 - val_loss: 0.4766 - val_mean_absolute_error: 0.1395
# Epoch 13/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5029 - mean_absolute_error: 0.1540 - val_loss: 0.4361 - val_mean_absolute_error: 0.1381
# Epoch 14/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4746 - mean_absolute_error: 0.1483 - val_loss: 0.4220 - val_mean_absolute_error: 0.1394
# Epoch 15/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4329 - mean_absolute_error: 0.1475 - val_loss: 0.3858 - val_mean_absolute_error: 0.1349
# Epoch 16/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4224 - mean_absolute_error: 0.1459 - val_loss: 0.3578 - val_mean_absolute_error: 0.1319
# Epoch 17/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3663 - mean_absolute_error: 0.1414 - val_loss: 0.3349 - val_mean_absolute_error: 0.1323
# Epoch 18/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3533 - mean_absolute_error: 0.1406 - val_loss: 0.3213 - val_mean_absolute_error: 0.1281
# Epoch 19/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3513 - mean_absolute_error: 0.1388 - val_loss: 0.2999 - val_mean_absolute_error: 0.1266
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3224 - mean_absolute_error: 0.1378 - val_loss: 0.3084 - val_mean_absolute_error: 0.1331
# Epoch 21/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3334 - mean_absolute_error: 0.1399 - val_loss: 0.2801 - val_mean_absolute_error: 0.1196
# Epoch 22/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3182 - mean_absolute_error: 0.1367 - val_loss: 0.2879 - val_mean_absolute_error: 0.1351
# Epoch 23/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2978 - mean_absolute_error: 0.1393 - val_loss: 0.2459 - val_mean_absolute_error: 0.1156
# Epoch 24/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2848 - mean_absolute_error: 0.1306 - val_loss: 0.2436 - val_mean_absolute_error: 0.1150
# Epoch 25/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2785 - mean_absolute_error: 0.1326 - val_loss: 0.2295 - val_mean_absolute_error: 0.1204
# Epoch 26/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2720 - mean_absolute_error: 0.1321 - val_loss: 0.2210 - val_mean_absolute_error: 0.1107
# Epoch 27/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2736 - mean_absolute_error: 0.1308 - val_loss: 0.2116 - val_mean_absolute_error: 0.1143
# Epoch 28/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2399 - mean_absolute_error: 0.1252 - val_loss: 0.2049 - val_mean_absolute_error: 0.1133
# Epoch 29/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2492 - mean_absolute_error: 0.1303 - val_loss: 0.1972 - val_mean_absolute_error: 0.1123
# Epoch 30/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2539 - mean_absolute_error: 0.1320 - val_loss: 0.1903 - val_mean_absolute_error: 0.1116
# Epoch 31/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2310 - mean_absolute_error: 0.1309 - val_loss: 0.2003 - val_mean_absolute_error: 0.1223
# Epoch 32/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2035 - mean_absolute_error: 0.1259 - val_loss: 0.1783 - val_mean_absolute_error: 0.1064
# Epoch 33/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2344 - mean_absolute_error: 0.1283 - val_loss: 0.1735 - val_mean_absolute_error: 0.1122
# Epoch 34/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2378 - mean_absolute_error: 0.1308 - val_loss: 0.1938 - val_mean_absolute_error: 0.1261
# Epoch 35/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2178 - mean_absolute_error: 0.1327 - val_loss: 0.1624 - val_mean_absolute_error: 0.1071
# Epoch 36/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2057 - mean_absolute_error: 0.1249 - val_loss: 0.1581 - val_mean_absolute_error: 0.1069
# Epoch 37/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1837 - mean_absolute_error: 0.1228 - val_loss: 0.1534 - val_mean_absolute_error: 0.1060
# Epoch 38/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2001 - mean_absolute_error: 0.1227 - val_loss: 0.1493 - val_mean_absolute_error: 0.1010
# Epoch 39/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1935 - mean_absolute_error: 0.1243 - val_loss: 0.1481 - val_mean_absolute_error: 0.1092
# Epoch 40/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1913 - mean_absolute_error: 0.1276 - val_loss: 0.1457 - val_mean_absolute_error: 0.1115
# Epoch 41/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1774 - mean_absolute_error: 0.1253 - val_loss: 0.1695 - val_mean_absolute_error: 0.1237
# Epoch 42/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1732 - mean_absolute_error: 0.1271 - val_loss: 0.1425 - val_mean_absolute_error: 0.1095
# Epoch 43/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1855 - mean_absolute_error: 0.1243 - val_loss: 0.1337 - val_mean_absolute_error: 0.1064
# Epoch 44/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1676 - mean_absolute_error: 0.1219 - val_loss: 0.1419 - val_mean_absolute_error: 0.1129
# Epoch 45/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1708 - mean_absolute_error: 0.1230 - val_loss: 0.1315 - val_mean_absolute_error: 0.1058
# Epoch 46/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1669 - mean_absolute_error: 0.1203 - val_loss: 0.1224 - val_mean_absolute_error: 0.1017
# Epoch 47/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1732 - mean_absolute_error: 0.1255 - val_loss: 0.1281 - val_mean_absolute_error: 0.1092
# Epoch 48/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1470 - mean_absolute_error: 0.1202 - val_loss: 0.1210 - val_mean_absolute_error: 0.1034
# Epoch 49/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1679 - mean_absolute_error: 0.1218 - val_loss: 0.1428 - val_mean_absolute_error: 0.1207
# Epoch 50/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1721 - mean_absolute_error: 0.1322 - val_loss: 0.1173 - val_mean_absolute_error: 0.1032
# Epoch 51/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1946 - mean_absolute_error: 0.1303 - val_loss: 0.1242 - val_mean_absolute_error: 0.1148
# Epoch 52/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1586 - mean_absolute_error: 0.1264 - val_loss: 0.1130 - val_mean_absolute_error: 0.1076
# Epoch 53/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1514 - mean_absolute_error: 0.1232 - val_loss: 0.1506 - val_mean_absolute_error: 0.1284
# Epoch 54/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1718 - mean_absolute_error: 0.1252 - val_loss: 0.1056 - val_mean_absolute_error: 0.0986
# Epoch 55/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1443 - mean_absolute_error: 0.1209 - val_loss: 0.1054 - val_mean_absolute_error: 0.1021
# Epoch 56/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1560 - mean_absolute_error: 0.1195 - val_loss: 0.1033 - val_mean_absolute_error: 0.1012
# Epoch 57/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1484 - mean_absolute_error: 0.1214 - val_loss: 0.1076 - val_mean_absolute_error: 0.1075
# Epoch 58/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1504 - mean_absolute_error: 0.1229 - val_loss: 0.1008 - val_mean_absolute_error: 0.0996
# Epoch 59/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1372 - mean_absolute_error: 0.1206 - val_loss: 0.1075 - val_mean_absolute_error: 0.1118
# Epoch 60/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1324 - mean_absolute_error: 0.1185 - val_loss: 0.0947 - val_mean_absolute_error: 0.0952
# Epoch 61/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1314 - mean_absolute_error: 0.1168 - val_loss: 0.0968 - val_mean_absolute_error: 0.0994
# Epoch 62/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1423 - mean_absolute_error: 0.1200 - val_loss: 0.0959 - val_mean_absolute_error: 0.1031
# Epoch 63/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1451 - mean_absolute_error: 0.1214 - val_loss: 0.1101 - val_mean_absolute_error: 0.1113
# Epoch 64/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1444 - mean_absolute_error: 0.1218 - val_loss: 0.0940 - val_mean_absolute_error: 0.1031
# Epoch 65/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1166 - mean_absolute_error: 0.1149 - val_loss: 0.0888 - val_mean_absolute_error: 0.0963
# Epoch 66/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1147 - mean_absolute_error: 0.1119 - val_loss: 0.0961 - val_mean_absolute_error: 0.1021
# Epoch 67/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1274 - mean_absolute_error: 0.1179 - val_loss: 0.0922 - val_mean_absolute_error: 0.1065
# Epoch 68/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1220 - mean_absolute_error: 0.1141 - val_loss: 0.0841 - val_mean_absolute_error: 0.0949
# Epoch 69/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1199 - mean_absolute_error: 0.1157 - val_loss: 0.0881 - val_mean_absolute_error: 0.0992
# Epoch 70/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1182 - mean_absolute_error: 0.1148 - val_loss: 0.0866 - val_mean_absolute_error: 0.1028
# Epoch 71/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1125 - mean_absolute_error: 0.1140 - val_loss: 0.0809 - val_mean_absolute_error: 0.0918
# Epoch 72/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1246 - mean_absolute_error: 0.1155 - val_loss: 0.0970 - val_mean_absolute_error: 0.1100
# Epoch 73/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1218 - mean_absolute_error: 0.1160 - val_loss: 0.0861 - val_mean_absolute_error: 0.1016
# Epoch 74/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1294 - mean_absolute_error: 0.1172 - val_loss: 0.0782 - val_mean_absolute_error: 0.0960
# Epoch 75/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1201 - mean_absolute_error: 0.1148 - val_loss: 0.0783 - val_mean_absolute_error: 0.0927
# Epoch 76/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1208 - mean_absolute_error: 0.1125 - val_loss: 0.0799 - val_mean_absolute_error: 0.0962
# Epoch 77/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1306 - mean_absolute_error: 0.1150 - val_loss: 0.0823 - val_mean_absolute_error: 0.1020
# Epoch 78/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1186 - mean_absolute_error: 0.1158 - val_loss: 0.0864 - val_mean_absolute_error: 0.1044
# Epoch 79/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1078 - mean_absolute_error: 0.1156 - val_loss: 0.0765 - val_mean_absolute_error: 0.0980
# Epoch 80/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1175 - mean_absolute_error: 0.1162 - val_loss: 0.0742 - val_mean_absolute_error: 0.0953
# Epoch 81/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1155 - mean_absolute_error: 0.1155 - val_loss: 0.0799 - val_mean_absolute_error: 0.1004
# Epoch 82/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1171 - mean_absolute_error: 0.1150 - val_loss: 0.0744 - val_mean_absolute_error: 0.0946
# Epoch 83/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1065 - mean_absolute_error: 0.1118 - val_loss: 0.0730 - val_mean_absolute_error: 0.0975
# Epoch 84/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1323 - mean_absolute_error: 0.1191 - val_loss: 0.0825 - val_mean_absolute_error: 0.1077
# Epoch 85/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1149 - mean_absolute_error: 0.1206 - val_loss: 0.0761 - val_mean_absolute_error: 0.1034
# Epoch 86/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1171 - mean_absolute_error: 0.1195 - val_loss: 0.0728 - val_mean_absolute_error: 0.0941
# Epoch 87/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1051 - mean_absolute_error: 0.1123 - val_loss: 0.0959 - val_mean_absolute_error: 0.1103
# Epoch 88/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1052 - mean_absolute_error: 0.1157 - val_loss: 0.0701 - val_mean_absolute_error: 0.0916
# Epoch 89/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1135 - mean_absolute_error: 0.1143 - val_loss: 0.0741 - val_mean_absolute_error: 0.1000
# Epoch 90/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1057 - mean_absolute_error: 0.1133 - val_loss: 0.0743 - val_mean_absolute_error: 0.1020
# Epoch 91/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1102 - mean_absolute_error: 0.1172 - val_loss: 0.0700 - val_mean_absolute_error: 0.1019
# Epoch 92/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1042 - mean_absolute_error: 0.1135 - val_loss: 0.0709 - val_mean_absolute_error: 0.0987
# Epoch 93/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1077 - mean_absolute_error: 0.1168 - val_loss: 0.0702 - val_mean_absolute_error: 0.0987
# Epoch 94/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0987 - mean_absolute_error: 0.1098 - val_loss: 0.0707 - val_mean_absolute_error: 0.0951
# Epoch 95/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1020 - mean_absolute_error: 0.1123 - val_loss: 0.0737 - val_mean_absolute_error: 0.1004
# Epoch 96/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1086 - mean_absolute_error: 0.1136 - val_loss: 0.0695 - val_mean_absolute_error: 0.0969
# Epoch 97/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1220 - mean_absolute_error: 0.1161 - val_loss: 0.0690 - val_mean_absolute_error: 0.1036
# Epoch 98/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0939 - mean_absolute_error: 0.1133 - val_loss: 0.0690 - val_mean_absolute_error: 0.0973
# Epoch 99/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1150 - mean_absolute_error: 0.1142 - val_loss: 0.0664 - val_mean_absolute_error: 0.0909
# Epoch 100/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0964 - mean_absolute_error: 0.1080 - val_loss: 0.0619 - val_mean_absolute_error: 0.0905

# %%
loss = model.evaluate(X_test, y_test)
print(loss)
# Out:
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0619 - mean_absolute_error: 0.0905
# [0.0618562288582325, 0.09045104682445526]

# %%
y_pred = model.predict(X_test)
print(f"R-squared: {np.round(r2_score(y_test, y_pred),2)*100}%")
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
# Out:
# 13/13 [==============================] - 0s 1ms/step
# R-squared: 98.0%
# MAE:  0.09045104214173355
# MSE:  0.019187101885564547

# %%
# Lihat Train Val Loss
history_dict = history1.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Tuning Hyperparameter dengan keras_tuner <br>
# import library keras_tuner

# %%
import keras_tuner as kt

# %%
# Fungsi untuk membangun model
def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units_1', min_value=32, max_value=256, step=32), 
                    input_shape=(X_train.shape[1],), activation='relu'))
    
    model.add(Dense(units=hp.Int('units_2', min_value=32, max_value=256, step=32), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    
    model.add(Dense(units=hp.Int('units_3', min_value=32, max_value=256, step=32), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(rate=hp.Float('dropout_3', min_value=0.2, max_value=0.8, step=0.1)))
    
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %%
# Kriteria tuning hyperparameter
tuner = kt.RandomSearch(build_model,
                     objective='mean_absolute_error',
                     max_trials=10,
                     executions_per_trial=10,
                     directory='./tuning6')
# Out:
# Reloading Tuner from ./tuning6\untitled_project\tuner0.json

# %%
# EarlyStopping untuk mencegah overfitting
stop_early = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Tuning hyperparameter
tuner.search(X_train, y_train, 
             epochs=100, batch_size=256, 
             validation_data=(X_test, y_test),
             callbacks=[stop_early])

# %%
# Dapatkan model terbaik
best_model = tuner.get_best_models(num_models=1)[0]

# %%
# Tampilkan hasil tuning hyperparameter
tuner.results_summary()
# Out:
# Results summary
# Results in ./tuning6\untitled_project
# Showing 10 best trials
# Objective(name="mean_absolute_error", direction="min")
#
# Trial 05 summary
# Hyperparameters:
# units_1: 64
# units_2: 64
# units_3: 192
# dropout_3: 0.2
# Score: 0.08699040338397027
#
# Trial 04 summary
# Hyperparameters:
# units_1: 128
# units_2: 64
# units_3: 128
# dropout_3: 0.2
# Score: 0.0874639093875885
#
# Trial 06 summary
# Hyperparameters:
# units_1: 96
# units_2: 64
# units_3: 192
# dropout_3: 0.30000000000000004
# Score: 0.08815891593694687
#
# Trial 08 summary
# Hyperparameters:
# units_1: 96
# units_2: 224
# units_3: 224
# dropout_3: 0.30000000000000004
# Score: 0.08968988880515098
#
# Trial 00 summary
# Hyperparameters:
# units_1: 192
# units_2: 160
# units_3: 160
# dropout_3: 0.4
# Score: 0.09524196162819862
#
# Trial 09 summary
# Hyperparameters:
# units_1: 192
# units_2: 160
# units_3: 256
# dropout_3: 0.6000000000000001
# Score: 0.09882277846336365
#
# Trial 01 summary
# Hyperparameters:
# units_1: 160
# units_2: 32
# units_3: 192
# dropout_3: 0.6000000000000001
# Score: 0.09928671047091484
#
# Trial 07 summary
# Hyperparameters:
# units_1: 224
# units_2: 160
# units_3: 64
# dropout_3: 0.4
# Score: 0.10439535602927208
#
# Trial 03 summary
# Hyperparameters:
# units_1: 64
# units_2: 224
# units_3: 96
# dropout_3: 0.7
# Score: 0.12075637355446815
#
# Trial 02 summary
# Hyperparameters:
# units_1: 256
# units_2: 160
# units_3: 96
# dropout_3: 0.7
# Score: 0.12181028947234154

# %% [markdown]
# Finalisasi Model

# %%
# Bangun model DNN dengan hasil tuning hyperparameter
model3 = Sequential()
model3.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
model3.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model3.add(Dense(192, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model3.add(Dropout(0.2))
model3.add(Dense(1, activation='linear'))
model3.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
# Mendapatkan rangkuman model
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                384
#
#  dense_5 (Dense)             (None, 64)                4160
#
#  dense_6 (Dense)             (None, 192)               12480
#
#  dropout_1 (Dropout)         (None, 192)               0
#
#  dense_7 (Dense)             (None, 1)                 193
#
# =================================================================
# Total params: 17217 (67.25 KB)
# Trainable params: 17217 (67.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training data dengan model yang telah dilakukan tuning hyperparameter
history2 = model3.fit(X_train, y_train, 
             epochs=100, batch_size=256, 
             validation_data=(X_test, y_test), 
             callbacks=[stop_early])
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 15ms/step - loss: 2.2995 - mean_absolute_error: 0.2811 - val_loss: 2.0389 - val_mean_absolute_error: 0.2533
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.6569 - mean_absolute_error: 0.2167 - val_loss: 1.4230 - val_mean_absolute_error: 0.2013
# Epoch 3/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.2459 - mean_absolute_error: 0.1970 - val_loss: 1.1239 - val_mean_absolute_error: 0.1860
# Epoch 4/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0290 - mean_absolute_error: 0.1758 - val_loss: 0.9359 - val_mean_absolute_error: 0.1712
# Epoch 5/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8747 - mean_absolute_error: 0.1696 - val_loss: 0.7907 - val_mean_absolute_error: 0.1604
# Epoch 6/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7371 - mean_absolute_error: 0.1602 - val_loss: 0.6788 - val_mean_absolute_error: 0.1580
# Epoch 7/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6401 - mean_absolute_error: 0.1581 - val_loss: 0.5822 - val_mean_absolute_error: 0.1499
# Epoch 8/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.5509 - mean_absolute_error: 0.1513 - val_loss: 0.5051 - val_mean_absolute_error: 0.1439
# Epoch 9/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4846 - mean_absolute_error: 0.1456 - val_loss: 0.4440 - val_mean_absolute_error: 0.1424
# Epoch 10/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4375 - mean_absolute_error: 0.1416 - val_loss: 0.3955 - val_mean_absolute_error: 0.1374
# Epoch 11/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3784 - mean_absolute_error: 0.1373 - val_loss: 0.3479 - val_mean_absolute_error: 0.1308
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3430 - mean_absolute_error: 0.1342 - val_loss: 0.3109 - val_mean_absolute_error: 0.1251
# Epoch 13/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3067 - mean_absolute_error: 0.1319 - val_loss: 0.2800 - val_mean_absolute_error: 0.1192
# Epoch 14/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2794 - mean_absolute_error: 0.1278 - val_loss: 0.2559 - val_mean_absolute_error: 0.1162
# Epoch 15/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2618 - mean_absolute_error: 0.1265 - val_loss: 0.2381 - val_mean_absolute_error: 0.1189
# Epoch 16/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2394 - mean_absolute_error: 0.1235 - val_loss: 0.2261 - val_mean_absolute_error: 0.1180
# Epoch 17/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2224 - mean_absolute_error: 0.1218 - val_loss: 0.2043 - val_mean_absolute_error: 0.1064
# Epoch 18/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2130 - mean_absolute_error: 0.1169 - val_loss: 0.1928 - val_mean_absolute_error: 0.1130
# Epoch 19/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1995 - mean_absolute_error: 0.1150 - val_loss: 0.1822 - val_mean_absolute_error: 0.1134
# Epoch 20/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1900 - mean_absolute_error: 0.1149 - val_loss: 0.1725 - val_mean_absolute_error: 0.0998
# Epoch 21/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1750 - mean_absolute_error: 0.1099 - val_loss: 0.1645 - val_mean_absolute_error: 0.1041
# Epoch 22/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1668 - mean_absolute_error: 0.1078 - val_loss: 0.1589 - val_mean_absolute_error: 0.1035
# Epoch 23/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1584 - mean_absolute_error: 0.1083 - val_loss: 0.1497 - val_mean_absolute_error: 0.1015
# Epoch 24/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1579 - mean_absolute_error: 0.1089 - val_loss: 0.1457 - val_mean_absolute_error: 0.1017
# Epoch 25/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1595 - mean_absolute_error: 0.1147 - val_loss: 0.1495 - val_mean_absolute_error: 0.1059
# Epoch 26/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1487 - mean_absolute_error: 0.1105 - val_loss: 0.1351 - val_mean_absolute_error: 0.1113
# Epoch 27/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1419 - mean_absolute_error: 0.1091 - val_loss: 0.1274 - val_mean_absolute_error: 0.0976
# Epoch 28/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1365 - mean_absolute_error: 0.1060 - val_loss: 0.1231 - val_mean_absolute_error: 0.1007
# Epoch 29/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1258 - mean_absolute_error: 0.1013 - val_loss: 0.1186 - val_mean_absolute_error: 0.0979
# Epoch 30/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1257 - mean_absolute_error: 0.1033 - val_loss: 0.1147 - val_mean_absolute_error: 0.0956
# Epoch 31/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1172 - mean_absolute_error: 0.1012 - val_loss: 0.1135 - val_mean_absolute_error: 0.0988
# Epoch 32/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1189 - mean_absolute_error: 0.1071 - val_loss: 0.1090 - val_mean_absolute_error: 0.1003
# Epoch 33/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1185 - mean_absolute_error: 0.1081 - val_loss: 0.1058 - val_mean_absolute_error: 0.0983
# Epoch 34/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1108 - mean_absolute_error: 0.1046 - val_loss: 0.1054 - val_mean_absolute_error: 0.1024
# Epoch 35/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1075 - mean_absolute_error: 0.1001 - val_loss: 0.1021 - val_mean_absolute_error: 0.0962
# Epoch 36/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1041 - mean_absolute_error: 0.1020 - val_loss: 0.1006 - val_mean_absolute_error: 0.0990
# Epoch 37/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1049 - mean_absolute_error: 0.1023 - val_loss: 0.0948 - val_mean_absolute_error: 0.0978
# Epoch 38/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0986 - mean_absolute_error: 0.1028 - val_loss: 0.0920 - val_mean_absolute_error: 0.0949
# Epoch 39/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0948 - mean_absolute_error: 0.0989 - val_loss: 0.0915 - val_mean_absolute_error: 0.0987
# Epoch 40/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1049 - mean_absolute_error: 0.1044 - val_loss: 0.0900 - val_mean_absolute_error: 0.0965
# Epoch 41/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0977 - mean_absolute_error: 0.1025 - val_loss: 0.0856 - val_mean_absolute_error: 0.0904
# Epoch 42/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0887 - mean_absolute_error: 0.0949 - val_loss: 0.0847 - val_mean_absolute_error: 0.0948
# Epoch 43/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0849 - mean_absolute_error: 0.0971 - val_loss: 0.0825 - val_mean_absolute_error: 0.0957
# Epoch 44/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0870 - mean_absolute_error: 0.1018 - val_loss: 0.0804 - val_mean_absolute_error: 0.0988
# Epoch 45/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0876 - mean_absolute_error: 0.1007 - val_loss: 0.0777 - val_mean_absolute_error: 0.0910
# Epoch 46/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0816 - mean_absolute_error: 0.0969 - val_loss: 0.0757 - val_mean_absolute_error: 0.0879
# Epoch 47/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0812 - mean_absolute_error: 0.0955 - val_loss: 0.0739 - val_mean_absolute_error: 0.0888
# Epoch 48/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0805 - mean_absolute_error: 0.0947 - val_loss: 0.0731 - val_mean_absolute_error: 0.0908
# Epoch 49/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0774 - mean_absolute_error: 0.0964 - val_loss: 0.0737 - val_mean_absolute_error: 0.0960
# Epoch 50/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0808 - mean_absolute_error: 0.0986 - val_loss: 0.0719 - val_mean_absolute_error: 0.0961
# Epoch 51/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0761 - mean_absolute_error: 0.0954 - val_loss: 0.0692 - val_mean_absolute_error: 0.0874
# Epoch 52/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0753 - mean_absolute_error: 0.0930 - val_loss: 0.0694 - val_mean_absolute_error: 0.0908
# Epoch 53/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0717 - mean_absolute_error: 0.0947 - val_loss: 0.0670 - val_mean_absolute_error: 0.0895
# Epoch 54/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0714 - mean_absolute_error: 0.0927 - val_loss: 0.0652 - val_mean_absolute_error: 0.0896
# Epoch 55/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0731 - mean_absolute_error: 0.0969 - val_loss: 0.0651 - val_mean_absolute_error: 0.0911
# Epoch 56/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0708 - mean_absolute_error: 0.0930 - val_loss: 0.0647 - val_mean_absolute_error: 0.0903
# Epoch 57/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0687 - mean_absolute_error: 0.0938 - val_loss: 0.0638 - val_mean_absolute_error: 0.0885
# Epoch 58/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0737 - mean_absolute_error: 0.0988 - val_loss: 0.0705 - val_mean_absolute_error: 0.0949
# Epoch 59/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0700 - mean_absolute_error: 0.0984 - val_loss: 0.0623 - val_mean_absolute_error: 0.0939
# Epoch 60/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0682 - mean_absolute_error: 0.0945 - val_loss: 0.0618 - val_mean_absolute_error: 0.0907
# Epoch 61/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0663 - mean_absolute_error: 0.0955 - val_loss: 0.0596 - val_mean_absolute_error: 0.0851
# Epoch 62/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0633 - mean_absolute_error: 0.0911 - val_loss: 0.0594 - val_mean_absolute_error: 0.0878
# Epoch 63/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0617 - mean_absolute_error: 0.0904 - val_loss: 0.0587 - val_mean_absolute_error: 0.0878
# Epoch 64/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0674 - mean_absolute_error: 0.0943 - val_loss: 0.0619 - val_mean_absolute_error: 0.1006
# Epoch 65/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0662 - mean_absolute_error: 0.0965 - val_loss: 0.0564 - val_mean_absolute_error: 0.0843
# Epoch 66/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0613 - mean_absolute_error: 0.0912 - val_loss: 0.0571 - val_mean_absolute_error: 0.0873
# Epoch 67/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0629 - mean_absolute_error: 0.0940 - val_loss: 0.0561 - val_mean_absolute_error: 0.0897
# Epoch 68/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0617 - mean_absolute_error: 0.0951 - val_loss: 0.0570 - val_mean_absolute_error: 0.0938
# Epoch 69/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0587 - mean_absolute_error: 0.0902 - val_loss: 0.0560 - val_mean_absolute_error: 0.0930
# Epoch 70/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0590 - mean_absolute_error: 0.0927 - val_loss: 0.0540 - val_mean_absolute_error: 0.0898
# Epoch 71/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0622 - mean_absolute_error: 0.0972 - val_loss: 0.0542 - val_mean_absolute_error: 0.0923
# Epoch 72/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0568 - mean_absolute_error: 0.0895 - val_loss: 0.0548 - val_mean_absolute_error: 0.0912
# Epoch 73/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0596 - mean_absolute_error: 0.0920 - val_loss: 0.0564 - val_mean_absolute_error: 0.0928
# Epoch 74/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0557 - mean_absolute_error: 0.0909 - val_loss: 0.0518 - val_mean_absolute_error: 0.0844
# Epoch 75/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0563 - mean_absolute_error: 0.0894 - val_loss: 0.0523 - val_mean_absolute_error: 0.0886
# Epoch 76/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0552 - mean_absolute_error: 0.0881 - val_loss: 0.0511 - val_mean_absolute_error: 0.0876
# Epoch 77/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0556 - mean_absolute_error: 0.0910 - val_loss: 0.0594 - val_mean_absolute_error: 0.0985
# Epoch 78/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0582 - mean_absolute_error: 0.0925 - val_loss: 0.0499 - val_mean_absolute_error: 0.0821
# Epoch 79/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0523 - mean_absolute_error: 0.0872 - val_loss: 0.0502 - val_mean_absolute_error: 0.0857
# Epoch 80/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0538 - mean_absolute_error: 0.0884 - val_loss: 0.0489 - val_mean_absolute_error: 0.0849
# Epoch 81/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0544 - mean_absolute_error: 0.0891 - val_loss: 0.0491 - val_mean_absolute_error: 0.0871
# Epoch 82/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0555 - mean_absolute_error: 0.0947 - val_loss: 0.0483 - val_mean_absolute_error: 0.0843
# Epoch 83/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0550 - mean_absolute_error: 0.0897 - val_loss: 0.0477 - val_mean_absolute_error: 0.0814
# Epoch 84/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0505 - mean_absolute_error: 0.0860 - val_loss: 0.0506 - val_mean_absolute_error: 0.0880
# Epoch 85/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0549 - mean_absolute_error: 0.0898 - val_loss: 0.0527 - val_mean_absolute_error: 0.0897
# Epoch 86/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0569 - mean_absolute_error: 0.0909 - val_loss: 0.0484 - val_mean_absolute_error: 0.0867
# Epoch 87/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0505 - mean_absolute_error: 0.0861 - val_loss: 0.0489 - val_mean_absolute_error: 0.0841
# Epoch 88/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0537 - mean_absolute_error: 0.0882 - val_loss: 0.0495 - val_mean_absolute_error: 0.0926
# Epoch 89/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0547 - mean_absolute_error: 0.0918 - val_loss: 0.0474 - val_mean_absolute_error: 0.0900
# Epoch 90/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0491 - mean_absolute_error: 0.0884 - val_loss: 0.0461 - val_mean_absolute_error: 0.0831
# Epoch 91/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0507 - mean_absolute_error: 0.0891 - val_loss: 0.0445 - val_mean_absolute_error: 0.0815
# Epoch 92/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0481 - mean_absolute_error: 0.0848 - val_loss: 0.0443 - val_mean_absolute_error: 0.0836
# Epoch 93/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0488 - mean_absolute_error: 0.0855 - val_loss: 0.0443 - val_mean_absolute_error: 0.0866
# Epoch 94/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0490 - mean_absolute_error: 0.0877 - val_loss: 0.0478 - val_mean_absolute_error: 0.0924
# Epoch 95/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0511 - mean_absolute_error: 0.0891 - val_loss: 0.0443 - val_mean_absolute_error: 0.0870
# Epoch 96/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0459 - mean_absolute_error: 0.0844 - val_loss: 0.0428 - val_mean_absolute_error: 0.0819
# Epoch 97/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0479 - mean_absolute_error: 0.0853 - val_loss: 0.0430 - val_mean_absolute_error: 0.0811
# Epoch 98/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0487 - mean_absolute_error: 0.0871 - val_loss: 0.0423 - val_mean_absolute_error: 0.0824
# Epoch 99/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0472 - mean_absolute_error: 0.0854 - val_loss: 0.0488 - val_mean_absolute_error: 0.0904
# Epoch 100/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0488 - mean_absolute_error: 0.0872 - val_loss: 0.0423 - val_mean_absolute_error: 0.0813

# %% [markdown]
# ---
# #### Evaluasi

# %%
# Print loss pada test set
loss3 = model3.evaluate(X_test, y_test)
print(loss3)
# Out:
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0423 - mean_absolute_error: 0.0813
# [0.04228264465928078, 0.08131532371044159]

# %%
# Akurasi Prediksi
y_pred3 = model3.predict(X_test)
print(f"R-squared: {np.round(r2_score(y_test, y_pred3),2)*100}%")
print("MAE: ", mean_absolute_error(y_test, y_pred3))
print("MSE: ", mean_squared_error(y_test, y_pred3))
# Out:
# 13/13 [==============================] - 0s 1ms/step
# R-squared: 99.0%
# MAE:  0.08131533693084535
# MSE:  0.014254210507978808

# %%
# Lihat Train Val Loss
history_dict = history2.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Terlihat model memberikan akurasi yang baik.

# %%
# Visualisasi hasil prediksi
y_test_reverse = y_scaler.inverse_transform(y_test)
y_pred_reverse = y_scaler.inverse_transform(y_pred3)

ax = sns.regplot(x=y_test_reverse, y=y_pred_reverse, line_kws={"color": "red"})
plt.title("Predicted vs True Motorcycle Price\n", weight='bold')
plt.xlabel("True Price (in Rp million)")
plt.ylabel("Predicted Price (in Rp million)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### Save model
# Model yang dengan akurasi tertinggi akan disimpan untuk di <i> deploy </i>

# %%
# Export Model untuk deployment
import pickle

pickle.dump(model3, open('../nn_model.pkl','wb'))
pickle.dump(X_scaler, open('../X_scaler.pkl', 'wb'))
pickle.dump(y_scaler, open('../y_scaler.pkl', 'wb'))

# %%
# Tes prediksi
model = pickle.load(open('../nn_model.pkl','rb'))
new_data = X_test[10]
new_data = np.array(new_data).reshape(1,-1)
pred = model.predict([new_data]) #lokasi, kapasitas_mesin, tahun, transmisi, kilometer, merk
pred = y_scaler.inverse_transform(pred)
print(pred)
# Out:
# 1/1 [==============================] - 0s 86ms/step
# [[10398374.]]

# %%
# Export dataset
resampled_motor.to_csv('../Dataset/Dataset_Training.csv')

# %%
# Extract dependencies
import pipreqsnb
# !pipreqsnb ../Notebook --force
# Out:
# pipreqs  --force ../Notebook
# WARNING: Import named "beautifulsoup4" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "beautifulsoup4" was resolved to "beautifulsoup4:4.12.2" package (https://pypi.org/project/beautifulsoup4/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "pandas" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "pandas" was resolved to "pandas:2.1.3" package (https://pypi.org/project/pandas/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "Requests" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "Requests" was resolved to "requests:2.31.0" package (https://pypi.org/project/requests/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "seaborn" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "seaborn" was resolved to "seaborn:0.13.0" package (https://pypi.org/project/seaborn/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in ../Notebook\requirements.txt
