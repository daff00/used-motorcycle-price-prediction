# %% [markdown]
# # Deep Learning Neural Network Model for Used Motorcycle Price Prediction
# ## IS794 AL - Deep Learning (Lab)
# Kelompok B: <br>
# - Daffa Kaisha Pratama Chandra (00000055770)
# - Justine Donovan (00000063202)
# - Marsella Patricia (00000063226)
# - Reina Ratu Balqis (00000065099)
# ---
# ### Import Libraries

# %%
# Basic library
import pandas as pd
import numpy as np

# Pre-processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import plotly.express as px
from plotly.subplots import make_subplots

# Handling imbalanced class using RandomOverSampling
from imblearn.over_sampling import RandomOverSampler

# Feature selection dengan random forest regressor
from sklearn.ensemble import RandomForestRegressor

# Deep learning
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers

# Ignore warning
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ---
# Baca Dataset

# %%
yamaha = pd.read_csv("../Dataset/motor_yamaha_bekas.csv", engine='pyarrow')
honda = pd.read_csv("../Dataset/motor_honda_bekas.csv", engine='pyarrow')
kawasaki = pd.read_csv("../Dataset/motor_kawasaki_bekas.csv", engine='pyarrow')
suzuki = pd.read_csv("../Dataset/motor_suzuki_bekas.csv", engine='pyarrow')

# %% [markdown]
# Penjelasan singkat mengenai dataset yang digunakan: <br>
# Dataset motor bekas yang ada di Indonesia. Terdapat 10 kolom: <br>
# | Feature | Penjelasan |
# |----------|----------|
# | Nama motor| Nama motor yang ditampilkan pada website|
# | lokasi | Lokasi motor dijual |
# | harga | Lokasi motor dijual |
# | deskripsi | Deskripsi iklan motor |
# | kapasitas_mesin | Kapasitas mesin motor bekas yang dijual (dalam CC) |
# | tahun | Tahun pembuatan motor berkas |
# | transmisi | Jenis transmisi motor bekas yang dijual |
# | kilometer | Jarak tempuh motor bekas yang dijual |
# | url | URL motor pada website https://momotor.id/ |
# | merk | Merk pabrikan motor |
#
# Dataset ini merupakan hasil web scraping dari website https://momotor.id/

# %%
print("Shape dari tiap dataset:")
print(f"Dataset Yamaha memiliki {yamaha.shape[1]} kolom dan {yamaha.shape[0]} baris.")
print(f"Dataset Honda memiliki {honda.shape[1]} kolom dan {honda.shape[0]} baris.")
print(f"Dataset Kawasaki memiliki {kawasaki.shape[1]} kolom dan {kawasaki.shape[0]} baris.")
print(f"Dataset Suzuki memiliki {suzuki.shape[1]} kolom dan {suzuki.shape[0]} baris.")
# Out:
# Shape dari tiap dataset:
# Dataset Yamaha memiliki 10 kolom dan 493 baris.
# Dataset Honda memiliki 10 kolom dan 966 baris.
# Dataset Kawasaki memiliki 10 kolom dan 96 baris.
# Dataset Suzuki memiliki 10 kolom dan 23 baris.

# %%
print("Informasi singkat dari tiap dataset:\n")
print("Yamaha:")
print(yamaha.info())
print("\nHonda:")
print(honda.info())
print("\nKawasaki:")
print(kawasaki.info())
print("\nSuzuki:")
print(suzuki.info())
# Out:
# Informasi singkat dari tiap dataset:
#
# Yamaha:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       352 non-null    object
#  1   lokasi           352 non-null    object
#  2   harga            352 non-null    object
#  3   deskripsi        352 non-null    object
#  4   kapasitas_mesin  352 non-null    object
#  5   tahun            352 non-null    float64
#  6   transmisi        352 non-null    object
#  7   kilometer        352 non-null    object
#  8   url              493 non-null    object
#  9   merk             493 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 38.6+ KB
# None
#
# Honda:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       629 non-null    object
#  1   lokasi           629 non-null    object
#  2   harga            629 non-null    object
#  3   deskripsi        629 non-null    object
#  4   kapasitas_mesin  629 non-null    object
#  5   tahun            629 non-null    float64
#  6   transmisi        629 non-null    object
#  7   kilometer        629 non-null    object
#  8   url              966 non-null    object
#  9   merk             966 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 75.6+ KB
# None
#
# Kawasaki:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       48 non-null     object
#  1   lokasi           48 non-null     object
#  2   harga            48 non-null     object
#  3   deskripsi        48 non-null     object
#  4   kapasitas_mesin  48 non-null     object
#  5   tahun            48 non-null     float64
#  6   transmisi        48 non-null     object
#  7   kilometer        48 non-null     object
#  8   url              96 non-null     object
#  9   merk             96 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 7.6+ KB
# None
#
# Suzuki:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       14 non-null     object
#  1   lokasi           14 non-null     object
#  2   harga            14 non-null     object
#  3   deskripsi        14 non-null     object
#  4   kapasitas_mesin  14 non-null     object
#  5   tahun            14 non-null     float64
#  6   transmisi        14 non-null     object
#  7   kilometer        14 non-null     object
#  8   url              23 non-null     object
#  9   merk             23 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 1.9+ KB
# None

# %% [markdown]
# Pre-processing: Data mentah -> Data siap pakai <br>
# Akan dilakukan cek <i> missing values. </i> Jika terdapat <i> missing values, </i> data yang hilang akan diimputasi menggunakan nilai modus.

# %%
# Cek rata-rata missing values pada tiap dataset
brand = ['Yamaha', 'Honda', 'Kawasaki', 'Suzuki']
data = [yamaha, honda, kawasaki, suzuki]

for i, j in zip(brand, data):
    print(f"{i} missing values: \n{np.round(honda.isnull().mean(), 2)*100}")
    print()
# Out:
# Yamaha missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Honda missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Kawasaki missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64
#
# Suzuki missing values:
# nama_motor         35.0
# lokasi             35.0
# harga              35.0
# deskripsi          35.0
# kapasitas_mesin    35.0
# tahun              35.0
# transmisi          35.0
# kilometer          35.0
# url                 0.0
# merk                0.0
# dtype: float64

# %%
# cari modus dari tiap kolom yang terdapat missing values
kolom_null = ['nama_motor', 'lokasi', 'harga', 'deskripsi', 
              'kapasitas_mesin', 'tahun', 'transmisi', 'kilometer']

# %%
# Cari modus dan replace NaN dengan modus
for col in kolom_null:
    # Yamaha
    modus_yamaha = yamaha[col].value_counts().nlargest(3)
    # Honda
    modus_honda = yamaha[col].value_counts().nlargest(3)
    # Kawasaki
    modus_kawasaki = yamaha[col].value_counts().nlargest(3)
    # Suzuki
    modus_suzuki = yamaha[col].value_counts().nlargest(3)
    
    # Check if the mode values exist
    if len(modus_yamaha) >= 2:
        # Extract the mode strings
        modus_ymh1 = modus_yamaha.index[0]
        modus_ymh2 = modus_yamaha.index[1]

        # Define a list of possible string values between the modes
        possible_values_ymh = [modus_ymh1, modus_ymh2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        yamaha[col] = yamaha[col].apply(lambda x: np.random.choice(possible_values_ymh) if pd.isna(x) else x)

    if len(modus_honda) >= 2:
        # Extract the mode strings
        modus_hnd1 = modus_honda.index[0]
        modus_hnd2 = modus_honda.index[1]

        # Define a list of possible string values between the modes
        possible_values_hnd = [modus_hnd1, modus_hnd2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        honda[col] = honda[col].apply(lambda x: np.random.choice(possible_values_hnd) if pd.isna(x) else x)

    if len(modus_kawasaki) >= 2:
        # Extract the mode strings
        modus_kws1 = modus_kawasaki.index[0]
        modus_kws2 = modus_kawasaki.index[1]

        # Define a list of possible string values between the modes
        possible_values_kws = [modus_kws1, modus_kws2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        kawasaki[col] = kawasaki[col].apply(lambda x: np.random.choice(possible_values_kws) if pd.isna(x) else x)

    if len(modus_suzuki) >= 2:
        # Extract the mode strings
        modus_szk1 = modus_suzuki.index[0]
        modus_szk2 = modus_suzuki.index[1]

        # Define a list of possible string values between the modes
        possible_values_szk = [modus_szk1, modus_szk2]

        # Replace NaN dengan nilai random antara modus pertama/kedua/ketiga
        suzuki[col] = suzuki[col].apply(lambda x: np.random.choice(possible_values_szk) if pd.isna(x) else x)

# %%
# Cek missing values lagi
for i, j in zip(brand, data):
    print(f"{i} missing values: \n{np.round(j.isnull().mean(), 2)*100}")
    print()
# Out:
# Yamaha missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Honda missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Kawasaki missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64
#
# Suzuki missing values:
# nama_motor         0.0
# lokasi             0.0
# harga              0.0
# deskripsi          0.0
# kapasitas_mesin    0.0
# tahun              0.0
# transmisi          0.0
# kilometer          0.0
# url                0.0
# merk               0.0
# dtype: float64

# %%
# Merge dataset
used_motor = pd.concat([yamaha, honda, kawasaki, suzuki])
print("Shape dari dataset yang digabung: ", used_motor.shape)
# Out:
# Shape dari dataset yang digabung:  (1578, 10)

# %% [markdown]
# ---
# #### Data Pre-processing
# Pada tahap ini, akan dilakukan:
# - Drop kolom yang tidak digunakan
# - Oversampling Data yang sedikit dengan Random Oversampling
# - Membersihkan kolom harga
# - Membersihkan kolom kapasitas mesin

# %% [markdown]
# ##### Drop variabel yang tidak dibutuhkan

# %%
used_motor = used_motor.drop(columns=['deskripsi', 'url'])
used_motor.head()
# Out:
#              nama_motor              lokasi         harga kapasitas_mesin  \
# 0  Yamaha Aerox 155 Vva  Kota Jakarta Barat  Rp24,500,000          155 CC
# 1  Yamaha Aerox 155 Vva      Kab. Tangerang  Rp24,500,000          155 CC
# 2  Yamaha Aerox 155 Vva  Kota Jakarta Barat  Rp23,500,000          155 CC
# 3       Yamaha Nmax Abs  Kota Jakarta Barat  Rp24,500,000          155 CC
# 4       Yamaha Nmax Abs      Kab. Tangerang  Rp23,500,000          155 CC
#
#     tahun transmisi        kilometer    merk
# 0  2019.0  Otomatis        >30000 KM  Yamaha
# 1  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 2  2019.0    Manual  10000 - 20000KM  Yamaha
# 3  2018.0  Otomatis        >30000 KM  Yamaha
# 4  2019.0    Manual        >30000 KM  Yamaha

# %%
# Lihat nilai unik dari setiap kolom
kolom = used_motor.columns

for i in kolom:
    print(f"Nilai unik dari kolom {i}:")
    print(used_motor[i].value_counts())
    print()
# Out:
# Nilai unik dari kolom nama_motor:
# nama_motor
# Yamaha Nmax Abs                  336
# Yamaha Aerox 155 Vva             296
# Honda Beat Cbs Fi                 41
# Honda Vario 150 Esp Exclusive     38
# Honda New Beat Street Esp         35
#                                 ...
# Honda GENIO CBS                    1
# Honda Supra X 125 Cw               1
# Honda New Revo Fi Cw               1
# Honda Beat Fisporty Cw Esp         1
# Suzuki Satria Fu 150 Mfx           1
# Name: count, Length: 154, dtype: int64
#
# Nilai unik dari kolom lokasi:
# lokasi
# Kota Jakarta Barat        478
# Kab. Tangerang            431
# Kota Jakarta Selatan      204
# Kota Bandung              180
# Kota Jakarta Timur         91
# Kab. Bogor                 46
# Kota Jakarta Utara         43
# Kota Medan                 30
# Kota Tangerang             21
# Kab. Bandung               20
# Kota  Batam                10
# Kota Tangerang Selatan      8
# Kota Bekasi                 6
# Kota Depok                  5
# Kota Surabaya               3
# Kab. Deli Serdang           2
# Name: count, dtype: int64
#
# Nilai unik dari kolom harga:
# harga
# Rp24,500,000    305
# Rp23,500,000    277
# Rp16,500,000     40
# Rp17,500,000     30
# Rp21,500,000     28
#                ...
# Rp25,250,000      1
# Rp11,300,000      1
# Rp36,800,000      1
# Rp24,250,000      1
# Rp31,100,000      1
# Name: count, Length: 261, dtype: int64
#
# Nilai unik dari kolom kapasitas_mesin:
# kapasitas_mesin
# 155 CC           425
# 125 CC           416
# 110 CC           281
# 150 CC           183
# 150cc CC          58
# 110cc CC          47
# 155cc CC          41
# 125cc CC          40
# 250 CC            29
# -                 12
# 115cc CC           8
# 250cc CC           8
# 160 CC             6
# 175 CC             5
# 900 CC             2
# 125 cc CC          2
# 115 CC             1
# 600 CC             1
# 113cc CC           1
# 175cc CC           1
# 250Cc CC           1
#  CC                1
# 1550 CC            1
# 11pcc CC           1
# 249 CC             1
# 125CC CC           1
# 156cc CC           1
# 250  CC            1
# 156 CC             1
# 220 CC             1
# DSE4202201 CC      1
# Name: count, dtype: int64
#
# Nilai unik dari kolom tahun:
# tahun
# 2018.0    489
# 2019.0    487
# 2021.0    180
# 2020.0    126
# 2017.0    125
# 2016.0     75
# 2015.0     54
# 2022.0     42
# Name: count, dtype: int64
#
# Nilai unik dari kolom transmisi:
# transmisi
# Otomatis    1140
# Manual       438
# Name: count, dtype: int64
#
# Nilai unik dari kolom kilometer:
# kilometer
# 10000 - 20000KM    648
# >30000 KM          543
# 1000 - 5000 KM     243
# 5000 - 10000KM     129
# 0 - 1000 KM         15
# Name: count, dtype: int64
#
# Nilai unik dari kolom merk:
# merk
# Honda       966
# Yamaha      493
# Kawasaki     96
# Suzuki       23
# Name: count, dtype: int64

# %% [markdown]
# Kolom kapasitas mesin dan harga belum dalam format yang benar

# %% [markdown]
# Random Oversampling

# %%
print("Merk Motor:\n",used_motor['merk'].value_counts())
# Out:
# Merk Motor:
#  merk
# Honda       966
# Yamaha      493
# Kawasaki     96
# Suzuki       23
# Name: count, dtype: int64

# %%
class_cnt = [966, 493, 96, 23]

minor_class = ['Yamaha', 'Kawasaki', 'Suzuki']

class_mapping = {'Honda': 0, 'Yamaha': 1, 'Kawasaki': 2, 'Suzuki': 3}
used_motor['ClassEncoded'] = used_motor['merk'].map(class_mapping)

# %%
# Set strategi oversampling
sampling_strategy = {
    0: class_cnt[0],  # Tidak dilakukan oversampling untuk Honda
    1: class_cnt[0],  # Oversample Yamaha agar balance dengan Honda
    2: class_cnt[0],  # Oversample Kawasaki agar balance dengan Honda
    3: class_cnt[0]   # Oversample Suzuki agar balance dengan Honda
}

# Inisialisasi RandomOverSampler dengan strategi yang telah ditetapkan
ros = RandomOverSampler(sampling_strategy=sampling_strategy, random_state=42)

# Extract features dan labels
X = used_motor.drop(['merk', 'ClassEncoded'], axis=1)
y = used_motor['ClassEncoded']

# Fit transform data
X_resampled, y_resampled = ros.fit_resample(X, y)

# Merge data
resampled_motor = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.Series(y_resampled, name='ClassEncoded')], axis=1)

# Mapping hasil encoding ke nilai sebenarnya
resampled_motor['merk'] = resampled_motor['ClassEncoded'].map({v: k for k, v in class_mapping.items()})

# Drop temporary 'ClassEncoded' column
resampled_motor = resampled_motor.drop('ClassEncoded', axis=1)

# Print hasil
print(resampled_motor['merk'].value_counts())
# Out:
# merk
# Yamaha      966
# Honda       966
# Kawasaki    966
# Suzuki      966
# Name: count, dtype: int64

# %% [markdown]
# ##### Membersihkan kolom harga

# %%
def clean_harga(harga):
    harga_clean = harga.replace("Rp", "").replace(".", "").replace(",", "")
    return harga_clean

# Bersihkan kolom harga
resampled_motor['harga'] = resampled_motor['harga'].apply(clean_harga)
resampled_motor['harga'] = resampled_motor['harga'].astype("float")

# %% [markdown]
# ##### Membersihkan kolom kapasitas mesin

# %%
def clean_cc(kapasitas_mesin):
    cc_clean = kapasitas_mesin.replace("cc", "")
    cc_clean2 = cc_clean.replace(" CC", "")
    cc_clean3 = cc_clean2.replace("Cc", "")
    cc_clean4 = cc_clean3.replace("CC", "")
    cc_clean5 = cc_clean4.replace("p", "")
    return cc_clean5

# Bersihkan kolom kapasitas mesin
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].apply(clean_cc)
resampled_motor = resampled_motor[resampled_motor['kapasitas_mesin'] != 'DSE4202201']
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(['-', ''], 150)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].astype('int')
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(1550, 150)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(11, 110)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(113, 115)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(156, 155)
resampled_motor['kapasitas_mesin'] = resampled_motor['kapasitas_mesin'].replace(249, 250)
print(resampled_motor['kapasitas_mesin'].unique())
# Out:
# [155 125 220 150 250 110 115 160 900 175 600]

# %% [markdown]
# ---
# #### Exploratory Data Analysis <br>
# Pada tahap EDA, akan dilakukan beberapa tahapan untuk menemukan pola pada data dengan menggunakan statistik dan visualisasi data. Beberapa tahapan yang akan dilakukan sebagai berikut:
# - Melihat informasi data
# - Melihat nilai unik tiap kolom
# - Melihat statistika dasar
# - Visualisasi data

# %%
# Melihat informasi dataset
resampled_motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3857 entries, 0 to 3863
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       3857 non-null   object
#  1   lokasi           3857 non-null   object
#  2   harga            3857 non-null   float64
#  3   kapasitas_mesin  3857 non-null   int32
#  4   tahun            3857 non-null   float64
#  5   transmisi        3857 non-null   object
#  6   kilometer        3857 non-null   object
#  7   merk             3857 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 256.1+ KB

# %%
# Loop melalui tiap kolom dan mencetak nilai unik
unique_value_count ={}
for column in resampled_motor.columns : 
    unique_values = resampled_motor[column].unique()
    unique_count = len(unique_values)
    unique_value_count[column] = unique_count

for column, count in unique_value_count.items():
    print(f"{column} : {count}")
# Out:
# nama_motor : 153
# lokasi : 16
# harga : 260
# kapasitas_mesin : 11
# tahun : 8
# transmisi : 2
# kilometer : 5
# merk : 4

# %%
# Melihat Statistika data numerik
resampled_motor.describe()
# Out:
#               harga  kapasitas_mesin        tahun
# count  3.857000e+03      3857.000000  3857.000000
# mean   2.518894e+07       152.361939  2018.408867
# std    2.473013e+07        61.950348     1.505369
# min    8.550000e+06       110.000000  2015.000000
# 25%    1.850000e+07       125.000000  2018.000000
# 50%    2.350000e+07       150.000000  2018.000000
# 75%    2.450000e+07       155.000000  2019.000000
# max    3.650000e+08       900.000000  2022.000000

# %%
# Melihat Statistika data kategorikal
resampled_motor.describe(exclude=np.number)
# Out:
#              nama_motor              lokasi transmisi  kilometer    merk
# count              3857                3857      3857       3857    3857
# unique              153                  16         2          5       4
# top     Yamaha Nmax Abs  Kota Jakarta Barat  Otomatis  >30000 KM  Yamaha
# freq                834                1338      2145       1541     966

# %%
# Visualisasi distribusi harga motor semua merk
sns.histplot(resampled_motor['harga'], kde=True)
# Out:
# <Axes: xlabel='harga', ylabel='Count'>

# %% [markdown]
# Terdapat outliers yang cukup banyak pada data. Outliers pada data ini tidak dibersihkan agar model mampu membuat prediksi dengan lebih akurat.

# %%
# Visualisasi distribusi harga tiap merk motor
# Subplot
fig = make_subplots(rows=2, cols=2, subplot_titles=['Honda', 'Yamaha', 'Kawasaki', 'Suzuki'])

# Plot for Honda Turbo aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Honda'], x='harga', nbins=30, color_discrete_sequence=['#ca91eb']).update_traces(histnorm='probability').data[0], row=1, col=1)

# Plot for Yamaha Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Yamaha'], x='harga', nbins=30, color_discrete_sequence=['#eb6426']).update_traces(histnorm='probability').data[0], row=1, col=2)

# Plot for Kawasaki Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Kawasaki'], x='harga', nbins=30, color_discrete_sequence=['#91caeb']).update_traces(histnorm='probability').data[0], row=2, col=1)

# Plot for Suzuki Std aspiration
fig.add_trace(px.histogram(resampled_motor[resampled_motor['merk'] == 'Suzuki'], x='harga', nbins=30, color_discrete_sequence=['#265aeb']).update_traces(histnorm='probability').data[0], row=2, col=2)

# Update layout
fig.update_layout(showlegend=False, title_text="Distribusi Harga Tiap Merk Motor")

# Show the plot
fig.show()

# %% [markdown]
# Distribusi harga motor Honda, Yamaha, dan Suzuki berada pada rentang harga 10 - 100 juta Rupiah. Sedangkan, harga motor Kawasaki berada pada rentang harga 10 - 350 juta rupiah.

# %%
# Visualisasi Rata-Rata Harga Motor
hargapermerk = resampled_motor.groupby("merk")["harga"].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x="merk", y="harga", data=hargapermerk, order=hargapermerk.sort_values('harga', ascending=False)['merk'])
plt.title("Rata-rata Harga Motor Berdasarkan Merk")
plt.xlabel("Merk Motor")
plt.ylabel("Harga Motor")
plt.show()

# %% [markdown]
# Dari visualisasi, terlihat rata-rata harga paling mahal adalah merk motor Kawasaki

# %% [markdown]
# ### Data Preparation

# %%
resampled_motor.head()
# Out:
#              nama_motor              lokasi       harga  kapasitas_mesin  \
# 0  Yamaha Aerox 155 Vva  Kota Jakarta Barat  24500000.0              155
# 1  Yamaha Aerox 155 Vva      Kab. Tangerang  24500000.0              155
# 2  Yamaha Aerox 155 Vva  Kota Jakarta Barat  23500000.0              155
# 3       Yamaha Nmax Abs  Kota Jakarta Barat  24500000.0              155
# 4       Yamaha Nmax Abs      Kab. Tangerang  23500000.0              155
#
#     tahun transmisi        kilometer    merk
# 0  2019.0  Otomatis        >30000 KM  Yamaha
# 1  2018.0  Otomatis  10000 - 20000KM  Yamaha
# 2  2019.0    Manual  10000 - 20000KM  Yamaha
# 3  2018.0  Otomatis        >30000 KM  Yamaha
# 4  2019.0    Manual        >30000 KM  Yamaha

# %%
resampled_motor.tail()
# Out:
#                       nama_motor              lokasi       harga  \
# 3859             Suzuki Gsx R150          Kab. Bogor  15500000.0
# 3860        Yamaha Aerox 155 Vva  Kota Jakarta Barat  23500000.0
# 3861             Suzuki Gsx R150          Kota Medan  16900000.0
# 3862  Suzuki Satria F150 Fighter  Kota Jakarta Barat   9850000.0
# 3863  Suzuki Satria F150 Fighter  Kota Jakarta Barat   9850000.0
#
#       kapasitas_mesin   tahun transmisi        kilometer    merk
# 3859              150  2017.0    Manual   5000 - 10000KM  Suzuki
# 3860              155  2019.0  Otomatis  10000 - 20000KM  Suzuki
# 3861              150  2017.0    Manual        >30000 KM  Suzuki
# 3862              150  2015.0    Manual        >30000 KM  Suzuki
# 3863              150  2015.0    Manual        >30000 KM  Suzuki

# %%
resampled_motor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3857 entries, 0 to 3863
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_motor       3857 non-null   object
#  1   lokasi           3857 non-null   object
#  2   harga            3857 non-null   float64
#  3   kapasitas_mesin  3857 non-null   int32
#  4   tahun            3857 non-null   float64
#  5   transmisi        3857 non-null   object
#  6   kilometer        3857 non-null   object
#  7   merk             3857 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 256.1+ KB

# %% [markdown]
# ##### Encoding

# %%
# Encoding Manual
# Kolom merk
resampled_motor['merk'] = resampled_motor['merk'].replace({'Yamaha' : 1, 
                                                           'Honda' : 2, 
                                                           'Kawasaki' : 3, 
                                                           'Suzuki' : 4})

# Kolom transmisi
resampled_motor['transmisi'] = resampled_motor['merk'].replace({'Manual' : 1, 
                                                                'Otomatis' : 2})

# Kolom kilometer
resampled_motor['kilometer'] = resampled_motor['kilometer'].replace({'>30000 KM' : 5, 
                                                                     '10000 - 20000KM' : 4,
                                                                     '1000 - 5000 KM' : 3, 
                                                                     '5000 - 10000KM' : 2,
                                                                     '0 - 1000 KM' : 1})

# Kolom lokasi
resampled_motor['lokasi'] = resampled_motor['lokasi'].replace({'Kota Jakarta Barat' : 1,
                                                               'Kab. Tangerang' : 2,
                                                               'Kota Jakarta Selatan' : 3,
                                                               'Kota Bandung' : 4,
                                                               'Kota Jakarta Timur' : 5,
                                                               'Kab. Bogor' : 6,
                                                               'Kota Jakarta Utara' : 7,
                                                               'Kota Medan' : 8,
                                                               'Kota Tangerang' : 9,
                                                               'Kab. Bandung' : 10,
                                                               'Kota  Batam' : 11,
                                                               'Kota Tangerang Selatan' : 12,
                                                               'Kota Bekasi' : 13,
                                                               'Kota Depok' : 14,
                                                               'Kota Surabaya' : 15,
                                                               'Kab. Deli Serdang' : 16
                                                               })

# %% [markdown]
# ##### MinMax Scaler

# %% [markdown]
# ##### Feature Selection

# %%
# Memilih X dan y
X = resampled_motor.drop(columns=['harga', 'nama_motor'])
y = resampled_motor['harga']

# %%
# Train test split untuk feature importance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Random forest regressor untuk memilih feature importance
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_fi = rf.feature_importances_

# Define Nama columns
feature_names = X.columns.tolist()

plt.figure(figsize=(10, 6))

# Plotting feature importances
plt.barh(feature_names, rf_fi)
plt.xlabel('Feature Names')
plt.ylabel('Importance')
plt.title('Visualisasi Feature Importance')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ---
# #### Modeling
# Pada tahap modeling, akan dilakukan:
# - Seleksi fitur
# - Membangun model RNN
# - Tuning hyperparameter
#
# Seleksi fitur

# %%
# Memilih X and y
X = resampled_motor.drop(columns=['harga', 'nama_motor', 'transmisi'])
y = resampled_motor['harga'].values.reshape(-1,1)

# Standarize
X_scaler = StandardScaler().fit(X)
y_scaler = StandardScaler().fit(y)
X_scaled = X_scaler.fit_transform(X)
y_scaled = y_scaler.fit_transform(y)

# %%
# Train test split untuk modeling Deep Neural Network
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.1, random_state=42)

# %% [markdown]
# Modeling
# - Tanpa tuning hyperparameter

# %%
# Build the DNN model
model = Sequential()
model.add(Dense(128, input_shape=(X_train.shape[1],), activation='relu'))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               768
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 13249 (51.75 KB)
# Trainable params: 13249 (51.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history1 = model.fit(X_train, y_train, epochs=100, batch_size=256, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 2s 27ms/step - loss: 2.2370 - mean_absolute_error: 0.3502 - val_loss: 2.0165 - val_mean_absolute_error: 0.3046
# Epoch 2/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1.7971 - mean_absolute_error: 0.2981 - val_loss: 1.5635 - val_mean_absolute_error: 0.2374
# Epoch 3/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1.4695 - mean_absolute_error: 0.2583 - val_loss: 1.2313 - val_mean_absolute_error: 0.1882
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.2156 - mean_absolute_error: 0.2242 - val_loss: 1.0807 - val_mean_absolute_error: 0.1849
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.1497 - mean_absolute_error: 0.2118 - val_loss: 0.9631 - val_mean_absolute_error: 0.1817
# Epoch 6/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.9732 - mean_absolute_error: 0.2058 - val_loss: 0.8728 - val_mean_absolute_error: 0.1818
# Epoch 7/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.9080 - mean_absolute_error: 0.1997 - val_loss: 0.7833 - val_mean_absolute_error: 0.1766
# Epoch 8/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.8144 - mean_absolute_error: 0.1932 - val_loss: 0.7126 - val_mean_absolute_error: 0.1750
# Epoch 9/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.7950 - mean_absolute_error: 0.1945 - val_loss: 0.6586 - val_mean_absolute_error: 0.1708
# Epoch 10/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.7780 - mean_absolute_error: 0.1906 - val_loss: 0.6056 - val_mean_absolute_error: 0.1718
# Epoch 11/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.6484 - mean_absolute_error: 0.1860 - val_loss: 0.5441 - val_mean_absolute_error: 0.1661
# Epoch 12/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6124 - mean_absolute_error: 0.1836 - val_loss: 0.5117 - val_mean_absolute_error: 0.1658
# Epoch 13/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6496 - mean_absolute_error: 0.1832 - val_loss: 0.4981 - val_mean_absolute_error: 0.1616
# Epoch 14/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5652 - mean_absolute_error: 0.1801 - val_loss: 0.4855 - val_mean_absolute_error: 0.1666
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5309 - mean_absolute_error: 0.1789 - val_loss: 0.4339 - val_mean_absolute_error: 0.1520
# Epoch 16/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4475 - mean_absolute_error: 0.1639 - val_loss: 0.3952 - val_mean_absolute_error: 0.1486
# Epoch 17/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.4425 - mean_absolute_error: 0.1649 - val_loss: 0.3861 - val_mean_absolute_error: 0.1543
# Epoch 18/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5111 - mean_absolute_error: 0.1777 - val_loss: 0.3856 - val_mean_absolute_error: 0.1560
# Epoch 19/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4002 - mean_absolute_error: 0.1650 - val_loss: 0.3602 - val_mean_absolute_error: 0.1468
# Epoch 20/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4460 - mean_absolute_error: 0.1655 - val_loss: 0.3404 - val_mean_absolute_error: 0.1403
# Epoch 21/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3998 - mean_absolute_error: 0.1622 - val_loss: 0.3166 - val_mean_absolute_error: 0.1377
# Epoch 22/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3852 - mean_absolute_error: 0.1611 - val_loss: 0.3081 - val_mean_absolute_error: 0.1386
# Epoch 23/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3834 - mean_absolute_error: 0.1667 - val_loss: 0.2938 - val_mean_absolute_error: 0.1362
# Epoch 24/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3897 - mean_absolute_error: 0.1613 - val_loss: 0.2906 - val_mean_absolute_error: 0.1334
# Epoch 25/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3342 - mean_absolute_error: 0.1529 - val_loss: 0.2723 - val_mean_absolute_error: 0.1306
# Epoch 26/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3210 - mean_absolute_error: 0.1502 - val_loss: 0.2618 - val_mean_absolute_error: 0.1285
# Epoch 27/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3238 - mean_absolute_error: 0.1520 - val_loss: 0.2543 - val_mean_absolute_error: 0.1281
# Epoch 28/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3425 - mean_absolute_error: 0.1579 - val_loss: 0.2604 - val_mean_absolute_error: 0.1344
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3235 - mean_absolute_error: 0.1524 - val_loss: 0.2599 - val_mean_absolute_error: 0.1357
# Epoch 30/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3248 - mean_absolute_error: 0.1543 - val_loss: 0.2399 - val_mean_absolute_error: 0.1318
# Epoch 31/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3145 - mean_absolute_error: 0.1554 - val_loss: 0.2353 - val_mean_absolute_error: 0.1297
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3374 - mean_absolute_error: 0.1581 - val_loss: 0.2193 - val_mean_absolute_error: 0.1211
# Epoch 33/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2897 - mean_absolute_error: 0.1506 - val_loss: 0.2124 - val_mean_absolute_error: 0.1197
# Epoch 34/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2806 - mean_absolute_error: 0.1469 - val_loss: 0.2150 - val_mean_absolute_error: 0.1266
# Epoch 35/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3052 - mean_absolute_error: 0.1527 - val_loss: 0.2170 - val_mean_absolute_error: 0.1306
# Epoch 36/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2753 - mean_absolute_error: 0.1475 - val_loss: 0.2083 - val_mean_absolute_error: 0.1328
# Epoch 37/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2576 - mean_absolute_error: 0.1509 - val_loss: 0.2577 - val_mean_absolute_error: 0.1487
# Epoch 38/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2965 - mean_absolute_error: 0.1553 - val_loss: 0.1896 - val_mean_absolute_error: 0.1170
# Epoch 39/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2545 - mean_absolute_error: 0.1480 - val_loss: 0.1892 - val_mean_absolute_error: 0.1243
# Epoch 40/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2517 - mean_absolute_error: 0.1474 - val_loss: 0.1890 - val_mean_absolute_error: 0.1219
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2618 - mean_absolute_error: 0.1479 - val_loss: 0.1871 - val_mean_absolute_error: 0.1263
# Epoch 42/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2798 - mean_absolute_error: 0.1437 - val_loss: 0.1926 - val_mean_absolute_error: 0.1267
# Epoch 43/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2538 - mean_absolute_error: 0.1491 - val_loss: 0.1745 - val_mean_absolute_error: 0.1193
# Epoch 44/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2240 - mean_absolute_error: 0.1418 - val_loss: 0.1680 - val_mean_absolute_error: 0.1160
# Epoch 45/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2548 - mean_absolute_error: 0.1473 - val_loss: 0.1789 - val_mean_absolute_error: 0.1277
# Epoch 46/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2361 - mean_absolute_error: 0.1458 - val_loss: 0.1608 - val_mean_absolute_error: 0.1164
# Epoch 47/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2791 - mean_absolute_error: 0.1506 - val_loss: 0.1836 - val_mean_absolute_error: 0.1352
# Epoch 48/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2548 - mean_absolute_error: 0.1528 - val_loss: 0.1713 - val_mean_absolute_error: 0.1249
# Epoch 49/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2328 - mean_absolute_error: 0.1482 - val_loss: 0.1603 - val_mean_absolute_error: 0.1197
# Epoch 50/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.2158 - mean_absolute_error: 0.1466 - val_loss: 0.1670 - val_mean_absolute_error: 0.1229
# Epoch 51/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2126 - mean_absolute_error: 0.1451 - val_loss: 0.1515 - val_mean_absolute_error: 0.1140
# Epoch 52/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2210 - mean_absolute_error: 0.1428 - val_loss: 0.1861 - val_mean_absolute_error: 0.1383
# Epoch 53/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2421 - mean_absolute_error: 0.1536 - val_loss: 0.1474 - val_mean_absolute_error: 0.1144
# Epoch 54/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2075 - mean_absolute_error: 0.1390 - val_loss: 0.1463 - val_mean_absolute_error: 0.1149
# Epoch 55/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1879 - mean_absolute_error: 0.1384 - val_loss: 0.1421 - val_mean_absolute_error: 0.1144
# Epoch 56/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1799 - mean_absolute_error: 0.1431 - val_loss: 0.1413 - val_mean_absolute_error: 0.1171
# Epoch 57/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1881 - mean_absolute_error: 0.1405 - val_loss: 0.1425 - val_mean_absolute_error: 0.1197
# Epoch 58/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1786 - mean_absolute_error: 0.1366 - val_loss: 0.1344 - val_mean_absolute_error: 0.1124
# Epoch 59/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2420 - mean_absolute_error: 0.1441 - val_loss: 0.1536 - val_mean_absolute_error: 0.1293
# Epoch 60/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1802 - mean_absolute_error: 0.1447 - val_loss: 0.1726 - val_mean_absolute_error: 0.1329
# Epoch 61/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1771 - mean_absolute_error: 0.1409 - val_loss: 0.1291 - val_mean_absolute_error: 0.1082
# Epoch 62/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2000 - mean_absolute_error: 0.1402 - val_loss: 0.1501 - val_mean_absolute_error: 0.1252
# Epoch 63/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2134 - mean_absolute_error: 0.1477 - val_loss: 0.1237 - val_mean_absolute_error: 0.1061
# Epoch 64/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1944 - mean_absolute_error: 0.1404 - val_loss: 0.1305 - val_mean_absolute_error: 0.1136
# Epoch 65/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2193 - mean_absolute_error: 0.1425 - val_loss: 0.1354 - val_mean_absolute_error: 0.1158
# Epoch 66/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2034 - mean_absolute_error: 0.1436 - val_loss: 0.1396 - val_mean_absolute_error: 0.1236
# Epoch 67/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1576 - mean_absolute_error: 0.1358 - val_loss: 0.1387 - val_mean_absolute_error: 0.1177
# Epoch 68/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2177 - mean_absolute_error: 0.1392 - val_loss: 0.1275 - val_mean_absolute_error: 0.1166
# Epoch 69/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.2230 - mean_absolute_error: 0.1486 - val_loss: 0.1441 - val_mean_absolute_error: 0.1315
# Epoch 70/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1894 - mean_absolute_error: 0.1427 - val_loss: 0.1152 - val_mean_absolute_error: 0.1057
# Epoch 71/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1577 - mean_absolute_error: 0.1319 - val_loss: 0.1264 - val_mean_absolute_error: 0.1192
# Epoch 72/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1852 - mean_absolute_error: 0.1405 - val_loss: 0.1097 - val_mean_absolute_error: 0.1081
# Epoch 73/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.1760 - mean_absolute_error: 0.1402 - val_loss: 0.1477 - val_mean_absolute_error: 0.1300
# Epoch 74/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2493 - mean_absolute_error: 0.1478 - val_loss: 0.1094 - val_mean_absolute_error: 0.1094
# Epoch 75/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2065 - mean_absolute_error: 0.1486 - val_loss: 0.1483 - val_mean_absolute_error: 0.1339
# Epoch 76/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1635 - mean_absolute_error: 0.1393 - val_loss: 0.1059 - val_mean_absolute_error: 0.1036
# Epoch 77/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1592 - mean_absolute_error: 0.1372 - val_loss: 0.1074 - val_mean_absolute_error: 0.1104
# Epoch 78/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1904 - mean_absolute_error: 0.1386 - val_loss: 0.1040 - val_mean_absolute_error: 0.1062
# Epoch 79/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2145 - mean_absolute_error: 0.1443 - val_loss: 0.1492 - val_mean_absolute_error: 0.1394
# Epoch 80/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1986 - mean_absolute_error: 0.1453 - val_loss: 0.1099 - val_mean_absolute_error: 0.1099
# Epoch 81/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1704 - mean_absolute_error: 0.1387 - val_loss: 0.0995 - val_mean_absolute_error: 0.1029
# Epoch 82/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1493 - mean_absolute_error: 0.1335 - val_loss: 0.1113 - val_mean_absolute_error: 0.1140
# Epoch 83/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1855 - mean_absolute_error: 0.1418 - val_loss: 0.1082 - val_mean_absolute_error: 0.1093
# Epoch 84/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1606 - mean_absolute_error: 0.1345 - val_loss: 0.1010 - val_mean_absolute_error: 0.1055
# Epoch 85/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1540 - mean_absolute_error: 0.1312 - val_loss: 0.0967 - val_mean_absolute_error: 0.1056
# Epoch 86/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1622 - mean_absolute_error: 0.1323 - val_loss: 0.1085 - val_mean_absolute_error: 0.1140
# Epoch 87/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1693 - mean_absolute_error: 0.1399 - val_loss: 0.1161 - val_mean_absolute_error: 0.1213
# Epoch 88/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1571 - mean_absolute_error: 0.1377 - val_loss: 0.1024 - val_mean_absolute_error: 0.1082
# Epoch 89/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1647 - mean_absolute_error: 0.1354 - val_loss: 0.0933 - val_mean_absolute_error: 0.0999
# Epoch 90/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1933 - mean_absolute_error: 0.1417 - val_loss: 0.1229 - val_mean_absolute_error: 0.1311
# Epoch 91/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2350 - mean_absolute_error: 0.1495 - val_loss: 0.0945 - val_mean_absolute_error: 0.1026
# Epoch 92/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1701 - mean_absolute_error: 0.1428 - val_loss: 0.1061 - val_mean_absolute_error: 0.1269
# Epoch 93/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1711 - mean_absolute_error: 0.1418 - val_loss: 0.1214 - val_mean_absolute_error: 0.1205
# Epoch 94/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1777 - mean_absolute_error: 0.1412 - val_loss: 0.1051 - val_mean_absolute_error: 0.1121
# Epoch 95/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.1664 - mean_absolute_error: 0.1402 - val_loss: 0.1125 - val_mean_absolute_error: 0.1112
# Epoch 96/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1686 - mean_absolute_error: 0.1369 - val_loss: 0.0891 - val_mean_absolute_error: 0.1045
# Epoch 97/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1856 - mean_absolute_error: 0.1411 - val_loss: 0.0945 - val_mean_absolute_error: 0.1126
# Epoch 98/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1734 - mean_absolute_error: 0.1380 - val_loss: 0.0917 - val_mean_absolute_error: 0.1060
# Epoch 99/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1717 - mean_absolute_error: 0.1390 - val_loss: 0.0891 - val_mean_absolute_error: 0.1086
# Epoch 100/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1331 - mean_absolute_error: 0.1310 - val_loss: 0.1226 - val_mean_absolute_error: 0.1215

# %%
loss = model.evaluate(X_test, y_test)
print(loss)
# Out:
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1226 - mean_absolute_error: 0.1215
# [0.1226101815700531, 0.12149790674448013]

# %%
y_pred = model.predict(X_test)
print(f"R-squared: {np.round(r2_score(y_test, y_pred),2)*100}%")
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("MSE: ", mean_squared_error(y_test, y_pred))
# Out:
# 13/13 [==============================] - 0s 2ms/step
# R-squared: 95.0%
# MAE:  0.12149790903462847
# MSE:  0.06401454098917386

# %%
# let's see the training and validation accuracy by epoch
history_dict = history1.history
loss_values = history_dict['loss'] # you can change this
val_loss_values = history_dict['val_loss'] # you can also change this
epochs = range(1, len(loss_values) + 1) # range of X (no. of epochs)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Tuning Hyperparameter dengan keras_tuner <br>
# import library keras_tuner

# %%
import keras_tuner as kt

# %%
# Fungsi untuk membangun model
def build_model(hp):
    model = Sequential()
    model.add(Dense(units=hp.Int('units_1', min_value=32, max_value=256, step=32), 
                    input_shape=(X_train.shape[1],), activation='relu'))
    
    model.add(Dense(units=hp.Int('units_2', min_value=32, max_value=256, step=32), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(rate=hp.Float('dropout_3', min_value=0.2, max_value=0.8, step=0.1)))
    
    model.add(Dense(units=hp.Int('units_3', min_value=32, max_value=256, step=32), activation='relu', kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(rate=hp.Float('dropout_3', min_value=0.2, max_value=0.8, step=0.1)))
    
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
    return model

# %%
# Kriteria tuning hyperparameter
tuner = kt.RandomSearch(build_model,
                     objective='mean_absolute_error',
                     max_trials=10,
                     executions_per_trial=10,
                     directory='./tuning5')
# Out:
# Reloading Tuner from ./tuning5\untitled_project\tuner0.json

# %%
# EarlyStopping untuk mencegah overfitting
stop_early = EarlyStopping(monitor='val_loss', patience=10)

# %%
# Tuning hyperparameter
tuner.search(X_train, y_train, 
             epochs=100, batch_size=256, 
             validation_data=(X_test, y_test),
             callbacks=[stop_early])

# %%
# Dapatkan model terbaik
best_model = tuner.get_best_models(num_models=1)[0]

# %%
# Tampilkan hasil tuning hyperparameter
tuner.results_summary()
# Out:
# Results summary
# Results in ./tuning5\untitled_project
# Showing 10 best trials
# Objective(name="mean_absolute_error", direction="min")
#
# Trial 07 summary
# Hyperparameters:
# units_1: 256
# units_2: 128
# dropout_3: 0.2
# units_3: 160
# Score: 0.09907708019018173
#
# Trial 02 summary
# Hyperparameters:
# units_1: 160
# units_2: 256
# dropout_3: 0.30000000000000004
# units_3: 128
# Score: 0.10591869279742241
#
# Trial 05 summary
# Hyperparameters:
# units_1: 192
# units_2: 96
# dropout_3: 0.30000000000000004
# units_3: 160
# Score: 0.10739048421382905
#
# Trial 03 summary
# Hyperparameters:
# units_1: 256
# units_2: 160
# dropout_3: 0.30000000000000004
# units_3: 96
# Score: 0.10883446484804153
#
# Trial 04 summary
# Hyperparameters:
# units_1: 32
# units_2: 192
# dropout_3: 0.4
# units_3: 256
# Score: 0.11437539905309677
#
# Trial 00 summary
# Hyperparameters:
# units_1: 160
# units_2: 64
# dropout_3: 0.5
# units_3: 160
# Score: 0.12499143406748772
#
# Trial 01 summary
# Hyperparameters:
# units_1: 256
# units_2: 192
# dropout_3: 0.4
# units_3: 32
# Score: 0.12683913633227348
#
# Trial 06 summary
# Hyperparameters:
# units_1: 192
# units_2: 64
# dropout_3: 0.6000000000000001
# units_3: 160
# Score: 0.13915660977363586
#
# Trial 09 summary
# Hyperparameters:
# units_1: 32
# units_2: 160
# dropout_3: 0.7
# units_3: 96
# Score: 0.15445999801158905
#
# Trial 08 summary
# Hyperparameters:
# units_1: 256
# units_2: 224
# dropout_3: 0.8
# units_3: 256
# Score: 0.15948962420225143

# %% [markdown]
# Finalisasi Model

# %%
# Bangun model dengan hasil tuning hyperparameter
model3 = Sequential()
model3.add(Dense(256, input_shape=(X_train.shape[1],), activation='relu'))
model3.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.2))
model3.add(Dense(160, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model3.add(Dense(1, activation='linear'))
model3.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
# Mendapatkan rangkuman model
model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 256)               1536
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dense_6 (Dense)             (None, 160)               20640
#
#  dense_7 (Dense)             (None, 1)                 161
#
# =================================================================
# Total params: 55233 (215.75 KB)
# Trainable params: 55233 (215.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training data dengan model yang telah dilakukan tuning hyperparameter
history2 = model3.fit(X_train, y_train, 
             epochs=100, batch_size=256, 
             validation_data=(X_test, y_test), 
             callbacks=[stop_early])
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 21ms/step - loss: 3.4589 - mean_absolute_error: 0.2495 - val_loss: 2.7825 - val_mean_absolute_error: 0.2086
# Epoch 2/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2.4176 - mean_absolute_error: 0.1839 - val_loss: 2.0921 - val_mean_absolute_error: 0.1691
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.8561 - mean_absolute_error: 0.1577 - val_loss: 1.6249 - val_mean_absolute_error: 0.1543
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.4455 - mean_absolute_error: 0.1530 - val_loss: 1.2688 - val_mean_absolute_error: 0.1507
# Epoch 5/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1419 - mean_absolute_error: 0.1470 - val_loss: 1.0046 - val_mean_absolute_error: 0.1408
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.9124 - mean_absolute_error: 0.1437 - val_loss: 0.8049 - val_mean_absolute_error: 0.1376
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.7384 - mean_absolute_error: 0.1397 - val_loss: 0.6557 - val_mean_absolute_error: 0.1317
# Epoch 8/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6055 - mean_absolute_error: 0.1324 - val_loss: 0.5489 - val_mean_absolute_error: 0.1329
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5127 - mean_absolute_error: 0.1290 - val_loss: 0.4593 - val_mean_absolute_error: 0.1320
# Epoch 10/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.4320 - mean_absolute_error: 0.1270 - val_loss: 0.3979 - val_mean_absolute_error: 0.1189
# Epoch 11/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.3747 - mean_absolute_error: 0.1162 - val_loss: 0.3455 - val_mean_absolute_error: 0.1168
# Epoch 12/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3279 - mean_absolute_error: 0.1212 - val_loss: 0.3088 - val_mean_absolute_error: 0.1355
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.2918 - mean_absolute_error: 0.1204 - val_loss: 0.2697 - val_mean_absolute_error: 0.1099
# Epoch 14/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2602 - mean_absolute_error: 0.1070 - val_loss: 0.2449 - val_mean_absolute_error: 0.1040
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.2388 - mean_absolute_error: 0.1086 - val_loss: 0.2244 - val_mean_absolute_error: 0.1075
# Epoch 16/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.2269 - mean_absolute_error: 0.1188 - val_loss: 0.2069 - val_mean_absolute_error: 0.1174
# Epoch 17/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.2017 - mean_absolute_error: 0.1113 - val_loss: 0.1924 - val_mean_absolute_error: 0.1078
# Epoch 18/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1853 - mean_absolute_error: 0.1041 - val_loss: 0.1765 - val_mean_absolute_error: 0.1013
# Epoch 19/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1726 - mean_absolute_error: 0.1031 - val_loss: 0.1629 - val_mean_absolute_error: 0.1054
# Epoch 20/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1606 - mean_absolute_error: 0.1021 - val_loss: 0.1530 - val_mean_absolute_error: 0.0969
# Epoch 21/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1489 - mean_absolute_error: 0.0993 - val_loss: 0.1424 - val_mean_absolute_error: 0.0995
# Epoch 22/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1396 - mean_absolute_error: 0.0964 - val_loss: 0.1339 - val_mean_absolute_error: 0.1001
# Epoch 23/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1339 - mean_absolute_error: 0.1002 - val_loss: 0.1260 - val_mean_absolute_error: 0.0949
# Epoch 24/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.1263 - mean_absolute_error: 0.0993 - val_loss: 0.1196 - val_mean_absolute_error: 0.0941
# Epoch 25/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1182 - mean_absolute_error: 0.0959 - val_loss: 0.1137 - val_mean_absolute_error: 0.0981
# Epoch 26/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1118 - mean_absolute_error: 0.0947 - val_loss: 0.1063 - val_mean_absolute_error: 0.0891
# Epoch 27/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1053 - mean_absolute_error: 0.0917 - val_loss: 0.1009 - val_mean_absolute_error: 0.0890
# Epoch 28/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.1021 - mean_absolute_error: 0.0946 - val_loss: 0.1016 - val_mean_absolute_error: 0.0998
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0981 - mean_absolute_error: 0.0966 - val_loss: 0.0929 - val_mean_absolute_error: 0.0905
# Epoch 30/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0926 - mean_absolute_error: 0.0910 - val_loss: 0.0884 - val_mean_absolute_error: 0.0902
# Epoch 31/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0896 - mean_absolute_error: 0.0937 - val_loss: 0.0859 - val_mean_absolute_error: 0.0911
# Epoch 32/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0853 - mean_absolute_error: 0.0915 - val_loss: 0.0861 - val_mean_absolute_error: 0.1002
# Epoch 33/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0829 - mean_absolute_error: 0.0942 - val_loss: 0.0820 - val_mean_absolute_error: 0.0963
# Epoch 34/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0794 - mean_absolute_error: 0.0915 - val_loss: 0.0754 - val_mean_absolute_error: 0.0858
# Epoch 35/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0760 - mean_absolute_error: 0.0878 - val_loss: 0.0723 - val_mean_absolute_error: 0.0868
# Epoch 36/100
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0759 - mean_absolute_error: 0.0929 - val_loss: 0.0724 - val_mean_absolute_error: 0.0955
# Epoch 37/100
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0729 - mean_absolute_error: 0.0922 - val_loss: 0.0694 - val_mean_absolute_error: 0.0951
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0695 - mean_absolute_error: 0.0899 - val_loss: 0.0704 - val_mean_absolute_error: 0.1036
# Epoch 39/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0681 - mean_absolute_error: 0.0919 - val_loss: 0.0651 - val_mean_absolute_error: 0.0907
# Epoch 40/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0644 - mean_absolute_error: 0.0840 - val_loss: 0.0626 - val_mean_absolute_error: 0.0894
# Epoch 41/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0633 - mean_absolute_error: 0.0859 - val_loss: 0.0612 - val_mean_absolute_error: 0.0860
# Epoch 42/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0619 - mean_absolute_error: 0.0845 - val_loss: 0.0607 - val_mean_absolute_error: 0.0883
# Epoch 43/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0620 - mean_absolute_error: 0.0875 - val_loss: 0.0618 - val_mean_absolute_error: 0.0971
# Epoch 44/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0603 - mean_absolute_error: 0.0900 - val_loss: 0.0576 - val_mean_absolute_error: 0.0897
# Epoch 45/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0577 - mean_absolute_error: 0.0881 - val_loss: 0.0580 - val_mean_absolute_error: 0.0890
# Epoch 46/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0561 - mean_absolute_error: 0.0855 - val_loss: 0.0554 - val_mean_absolute_error: 0.0905
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0558 - mean_absolute_error: 0.0884 - val_loss: 0.0547 - val_mean_absolute_error: 0.0935
# Epoch 48/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0540 - mean_absolute_error: 0.0872 - val_loss: 0.0523 - val_mean_absolute_error: 0.0860
# Epoch 49/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0542 - mean_absolute_error: 0.0891 - val_loss: 0.0547 - val_mean_absolute_error: 0.0915
# Epoch 50/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0526 - mean_absolute_error: 0.0874 - val_loss: 0.0511 - val_mean_absolute_error: 0.0871
# Epoch 51/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0503 - mean_absolute_error: 0.0825 - val_loss: 0.0488 - val_mean_absolute_error: 0.0806
# Epoch 52/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0491 - mean_absolute_error: 0.0804 - val_loss: 0.0478 - val_mean_absolute_error: 0.0810
# Epoch 53/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0496 - mean_absolute_error: 0.0850 - val_loss: 0.0471 - val_mean_absolute_error: 0.0807
# Epoch 54/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0483 - mean_absolute_error: 0.0812 - val_loss: 0.0467 - val_mean_absolute_error: 0.0826
# Epoch 55/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0475 - mean_absolute_error: 0.0826 - val_loss: 0.0490 - val_mean_absolute_error: 0.0837
# Epoch 56/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0491 - mean_absolute_error: 0.0898 - val_loss: 0.0456 - val_mean_absolute_error: 0.0821
# Epoch 57/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0472 - mean_absolute_error: 0.0843 - val_loss: 0.0449 - val_mean_absolute_error: 0.0844
# Epoch 58/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0464 - mean_absolute_error: 0.0847 - val_loss: 0.0452 - val_mean_absolute_error: 0.0850
# Epoch 59/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0456 - mean_absolute_error: 0.0812 - val_loss: 0.0457 - val_mean_absolute_error: 0.0891
# Epoch 60/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0453 - mean_absolute_error: 0.0839 - val_loss: 0.0438 - val_mean_absolute_error: 0.0823
# Epoch 61/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0439 - mean_absolute_error: 0.0819 - val_loss: 0.0428 - val_mean_absolute_error: 0.0817
# Epoch 62/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0430 - mean_absolute_error: 0.0783 - val_loss: 0.0429 - val_mean_absolute_error: 0.0844
# Epoch 63/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0425 - mean_absolute_error: 0.0795 - val_loss: 0.0418 - val_mean_absolute_error: 0.0832
# Epoch 64/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0418 - mean_absolute_error: 0.0781 - val_loss: 0.0411 - val_mean_absolute_error: 0.0795
# Epoch 65/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0410 - mean_absolute_error: 0.0775 - val_loss: 0.0411 - val_mean_absolute_error: 0.0803
# Epoch 66/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0421 - mean_absolute_error: 0.0823 - val_loss: 0.0450 - val_mean_absolute_error: 0.0884
# Epoch 67/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0424 - mean_absolute_error: 0.0854 - val_loss: 0.0407 - val_mean_absolute_error: 0.0823
# Epoch 68/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0418 - mean_absolute_error: 0.0820 - val_loss: 0.0403 - val_mean_absolute_error: 0.0819
# Epoch 69/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0407 - mean_absolute_error: 0.0812 - val_loss: 0.0418 - val_mean_absolute_error: 0.0897
# Epoch 70/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0410 - mean_absolute_error: 0.0847 - val_loss: 0.0385 - val_mean_absolute_error: 0.0781
# Epoch 71/100
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0389 - mean_absolute_error: 0.0780 - val_loss: 0.0383 - val_mean_absolute_error: 0.0784
# Epoch 72/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0386 - mean_absolute_error: 0.0780 - val_loss: 0.0378 - val_mean_absolute_error: 0.0760
# Epoch 73/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0378 - mean_absolute_error: 0.0760 - val_loss: 0.0371 - val_mean_absolute_error: 0.0766
# Epoch 74/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0381 - mean_absolute_error: 0.0780 - val_loss: 0.0376 - val_mean_absolute_error: 0.0819
# Epoch 75/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0378 - mean_absolute_error: 0.0782 - val_loss: 0.0383 - val_mean_absolute_error: 0.0838
# Epoch 76/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0375 - mean_absolute_error: 0.0771 - val_loss: 0.0367 - val_mean_absolute_error: 0.0807
# Epoch 77/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0373 - mean_absolute_error: 0.0794 - val_loss: 0.0400 - val_mean_absolute_error: 0.0945
# Epoch 78/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0379 - mean_absolute_error: 0.0840 - val_loss: 0.0362 - val_mean_absolute_error: 0.0806
# Epoch 79/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0360 - mean_absolute_error: 0.0757 - val_loss: 0.0356 - val_mean_absolute_error: 0.0782
# Epoch 80/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0351 - mean_absolute_error: 0.0742 - val_loss: 0.0348 - val_mean_absolute_error: 0.0774
# Epoch 81/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0350 - mean_absolute_error: 0.0753 - val_loss: 0.0346 - val_mean_absolute_error: 0.0755
# Epoch 82/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0344 - mean_absolute_error: 0.0726 - val_loss: 0.0346 - val_mean_absolute_error: 0.0798
# Epoch 83/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0351 - mean_absolute_error: 0.0770 - val_loss: 0.0377 - val_mean_absolute_error: 0.0837
# Epoch 84/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0397 - mean_absolute_error: 0.0908 - val_loss: 0.0397 - val_mean_absolute_error: 0.1015
# Epoch 85/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0363 - mean_absolute_error: 0.0823 - val_loss: 0.0376 - val_mean_absolute_error: 0.0890
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0362 - mean_absolute_error: 0.0828 - val_loss: 0.0344 - val_mean_absolute_error: 0.0802
# Epoch 87/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0337 - mean_absolute_error: 0.0741 - val_loss: 0.0337 - val_mean_absolute_error: 0.0784
# Epoch 88/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0330 - mean_absolute_error: 0.0741 - val_loss: 0.0329 - val_mean_absolute_error: 0.0768
# Epoch 89/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0330 - mean_absolute_error: 0.0742 - val_loss: 0.0334 - val_mean_absolute_error: 0.0766
# Epoch 90/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0325 - mean_absolute_error: 0.0722 - val_loss: 0.0325 - val_mean_absolute_error: 0.0778
# Epoch 91/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0326 - mean_absolute_error: 0.0739 - val_loss: 0.0324 - val_mean_absolute_error: 0.0747
# Epoch 92/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0319 - mean_absolute_error: 0.0710 - val_loss: 0.0320 - val_mean_absolute_error: 0.0762
# Epoch 93/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0321 - mean_absolute_error: 0.0739 - val_loss: 0.0314 - val_mean_absolute_error: 0.0725
# Epoch 94/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0314 - mean_absolute_error: 0.0722 - val_loss: 0.0309 - val_mean_absolute_error: 0.0745
# Epoch 95/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0311 - mean_absolute_error: 0.0719 - val_loss: 0.0311 - val_mean_absolute_error: 0.0762
# Epoch 96/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0310 - mean_absolute_error: 0.0726 - val_loss: 0.0306 - val_mean_absolute_error: 0.0741
# Epoch 97/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0313 - mean_absolute_error: 0.0747 - val_loss: 0.0318 - val_mean_absolute_error: 0.0769
# Epoch 98/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0324 - mean_absolute_error: 0.0783 - val_loss: 0.0320 - val_mean_absolute_error: 0.0814
# Epoch 99/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0324 - mean_absolute_error: 0.0768 - val_loss: 0.0324 - val_mean_absolute_error: 0.0836
# Epoch 100/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0364 - mean_absolute_error: 0.0872 - val_loss: 0.0373 - val_mean_absolute_error: 0.0909

# %% [markdown]
# ---
# #### Evaluasi

# %%
# Print loss pada test set
loss3 = model3.evaluate(X_test, y_test)
print(loss3)
# Out:
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0373 - mean_absolute_error: 0.0909
# [0.03733783960342407, 0.0909346416592598]

# %%
# Akurasi Prediksi
y_pred3 = model3.predict(X_test)
print(f"R-squared: {np.round(r2_score(y_test, y_pred3),2)*100}%")
print("MAE: ", mean_absolute_error(y_test, y_pred3))
print("MSE: ", mean_squared_error(y_test, y_pred3))
# Out:
# 13/13 [==============================] - 0s 2ms/step
# R-squared: 98.0%
# MAE:  0.09093464041271344
# MSE:  0.017726031719518358

# %%
# Lihat Training loss dan validation loss
history_dict = history2.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, label='Training loss')
plt.plot(epochs, val_loss_values, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Terlihat model memberikan akurasi yang baik.

# %%
# Visualisasi hasil prediksi
y_test_reverse = y_scaler.inverse_transform(y_test)
y_pred_reverse = y_scaler.inverse_transform(y_pred3)

ax = sns.regplot(x=y_test_reverse, y=y_pred_reverse, line_kws={"color": "red"})
plt.title("Predicted vs True Motorcycle Price\n", weight='bold')
plt.xlabel("True Price (in Rp million)")
plt.ylabel("Predicted Price (in Rp million)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# #### Save model
# Model yang dengan akurasi tertinggi akan disimpan untuk di <i> deploy </i>

# %%
# Export Model untuk deployment
import pickle

# pickle.dump(model3, open('../nn_model.pkl','wb'))
# pickle.dump(X_scaler, open('../X_scaler.pkl', 'wb'))
# pickle.dump(y_scaler, open('../y_scaler.pkl', 'wb'))

# %%
# Tes prediksi
model = pickle.load(open('../nn_model.pkl','rb'))
new_data = X_test[10]
new_data = np.array(new_data).reshape(1,-1)
pred = model.predict([new_data]) #lokasi, kapasitas_mesin, tahun, transmisi, kilometer, merk
pred = y_scaler.inverse_transform(pred)
print(pred)
# Out:
# 1/1 [==============================] - 0s 67ms/step
# [[9534769.]]

# %%
# Export dataset
# resampled_motor.to_csv('../Dataset/Dataset_Training.csv')

# %%
# Extract dependencies
# import pipreqsnb
# !pipreqsnb ../Notebook --force
